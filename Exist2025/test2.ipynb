# %% [markdown]
# # RUNS: hate-speech-CNERG/bert-base-uncased-hatexplain

# %% [markdown]
# ## Colab load

# %%
# !git clone https://github.com/dierop/ALCLabs
# Out:
# Cloning into 'ALCLabs'...
# remote: Enumerating objects: 286, done.
# remote: Counting objects: 100% (286/286), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 286 (delta 151), reused 217 (delta 89), pack-reused 0 (from 0)
# Receiving objects: 100% (286/286), 4.37 MiB | 9.88 MiB/s, done.
# Resolving deltas: 100% (151/151), done.

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
cd ALCLabs/Exist2025/
# Out:
# /content/ALCLabs/Exist2025

# %%
ls
# Out:
# data/                       task3_2_hard_ScalaR_1.json  trainer_output/
# dataloader.py               task3_2_soft_ScalaR_1.json  train.py
# __pycache__/                task3_3_hard_ScalaR_1.json  wandb/
# task3_1_hard_ScalaR_1.json  task3_3_soft_ScalaR_1.json
# task3_1_soft_ScalaR_1.json  test.ipynb

# %% [markdown]
# ## Temp fix

# %%
from train import BertTrainerWrapper

# %%
from transformers import (
    AutoTokenizer, AutoModelForSequenceClassification,
    TrainingArguments, Trainer
)
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (
    f1_score, log_loss, accuracy_score
)
from datasets import Dataset

import torch
import numpy as np

from dataloader import load_data_json
from typing import List, Dict, Any
import json

from transformers import (
    AutoTokenizer, AutoModelForSequenceClassification,
    TrainingArguments, Trainer
)
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score, accuracy_score, log_loss
from datasets import Dataset
from collections import Counter, defaultdict
import torch, numpy as np, pandas as pd
from scipy.special import expit
from typing import List, Dict, Any
import json

class Test:
    def __init__(self, df=None, label_name="label1", soft=False,
                 model_name="bert-base-multilingual-cased"):
        if df is None:
            df = load_data_json("data/EXIST2025_training_videos.json", soft=soft)
        self.df = df.dropna(subset=[label_name]).reset_index(drop=True)
        self.label_name = label_name
        self.soft = soft
        self.model_name = model_name

        self.label_encoder = None
        self.keys = None
        self.num_labels = None
        self.problem_type = None

        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = None
        self.dataset = None
        self.trainer = None

    # ------------------------------------------------------------------
    # 1. PREPARAR ETIQUETAS
    # ------------------------------------------------------------------
    def prepare_labels(self, threshold=0.5):
        col = self.df[self.label_name]

        # -------- SOFT -------------------------------------------------
        if self.soft:
            # dict → vector
            if isinstance(col.iloc[0], dict):
                self.keys = sorted(set().union(*col.apply(lambda x: x.keys())))
                self.df["labels"] = col.apply(
                    lambda d: [d.get(k, 0.0) for k in self.keys])
                self.num_labels = len(self.keys)
                self.problem_type = "multi_label_classification"

            # float → regresión binaria
            else:
                self.df["labels"] = col.astype(float)
                self.num_labels = 1
                self.problem_type = "regression"

            return  # fin SOFT

        # -------- HARD -------------------------------------------------
        # HARD MULTI-LABEL  (lista de etiquetas)
        if isinstance(col.iloc[0], (list, set)):
            # multi-label hard  → vector multihot float
            self.keys = sorted(set().union(*col))

            def to_multihot(lst):
                return [float(1) if k in lst else float(0) for k in self.keys]  # 🆕 float

            self.df["labels"] = col.apply(to_multihot)
            self.num_labels   = len(self.keys)
            self.problem_type = "multi_label_classification"

        # HARD SINGLE-LABEL  (cadena)
        else:
            self.label_encoder = LabelEncoder()
            self.df["labels"] = self.label_encoder.fit_transform(col)
            self.num_labels = len(self.label_encoder.classes_)
            self.problem_type = "single_label_classification"

    # ------------------------------------------------------------------
    # 2. TOKENIZAR
    # ------------------------------------------------------------------
    def tokenize_dataset(self):
        ds = Dataset.from_pandas(self.df[["text", "labels"]])
        ds = ds.train_test_split(test_size=0.15, shuffle=True)
        ds = ds.map(lambda x: self.tokenizer(
            x["text"], truncation=True, padding="max_length",
            max_length=128), batched=False)
        self.dataset = ds

    # ------------------------------------------------------------------
    # 3. CONSTRUIR MODELO
    # ------------------------------------------------------------------
    def build_model(self):
        self.model = AutoModelForSequenceClassification.from_pretrained(
            self.model_name,
            num_labels=self.num_labels,
            problem_type=self.problem_type,
            ignore_mismatched_sizes=True
        )

    # ------------------------------------------------------------------
    # 4. ENTRENAR
    # ------------------------------------------------------------------
    def train(self, epochs=3, batch_size=8, lr=2e-5, eval_batch_size=2,
              eval_accumulation_steps=32):
        self.prepare_labels()
        self.tokenize_dataset()
        self.build_model()

        args = TrainingArguments(
            eval_strategy="epoch",
            learning_rate=lr,
            per_device_train_batch_size=batch_size,
            num_train_epochs=epochs,
            weight_decay=0.01,
            per_device_eval_batch_size = eval_batch_size,
            eval_accumulation_steps    = eval_accumulation_steps,
        )

        self.trainer = Trainer(
            model=self.model,
            args=args,
            train_dataset=self.dataset['train'],
            eval_dataset=self.dataset['test'],
            tokenizer=self.tokenizer,
            compute_metrics=self.compute_metrics
        )

        self.trainer.train()

    # ------------------------------------------------------------------
    # 5. MÉTRICAS
    # ------------------------------------------------------------------
    def compute_metrics(self, eval_pred, th=0.5):
      logits = eval_pred.predictions        # shape (N, K)
      labels = eval_pred.label_ids
      if isinstance(logits, (tuple, list)):
        logits = logits[0]

      # Si es lista de lotes, concaténalos
      if isinstance(logits, (list, tuple)) and isinstance(logits[0], np.ndarray):
          logits = np.concatenate(logits, axis=0)

      # ----- SOFT ------------------------------------------------------
      if self.soft:
          probs = expit(logits)            # sin torch, sin GPU

          if self.num_labels == 1:
              y_true = labels.squeeze()
              y_pred = probs.squeeze()
              y_true_h = (y_true >= th).astype(int)
              y_pred_h = (y_pred >= th).astype(int)

              return {
                  "mae":     float(np.mean(np.abs(y_pred - y_true))),
                  "logloss": float(log_loss(y_true_h, y_pred)),
                  "f1_micro": float(f1_score(y_true_h, y_pred_h, average="micro")),
                  "f1_macro": float(f1_score(y_true_h, y_pred_h, average="macro")),
              }

          # multilabel
          y_true   = labels
          y_pred   = probs
          y_true_h = (y_true >= th).astype(int)
          y_pred_h = (y_pred >= th).astype(int)

          ce = np.mean([log_loss(y_true_h[:, k], y_pred[:, k])
                        for k in range(self.num_labels)])

          return {
              "mae":       float(np.mean(np.abs(y_pred - y_true))),
              "logloss":   float(ce),
              "f1_micro":  float(f1_score(y_true_h.reshape(-1),
                                          y_pred_h.reshape(-1),
                                          average="micro", zero_division=0)),
              "f1_macro":  float(f1_score(y_true_h,
                                          y_pred_h,
                                          average="macro", zero_division=0)),
          }

      # ----- HARD MULTILABEL ------------------------------------------
      if self.problem_type == "multi_label_classification":
          probs = expit(logits)
          y_pred = (probs >= th).astype(int)
          micro  = f1_score(labels.reshape(-1), y_pred.reshape(-1),
                            average="micro", zero_division=0)
          macro  = f1_score(labels, y_pred,
                            average="macro", zero_division=0)
          return {"f1_micro": float(micro), "f1_macro": float(macro)}

      # ----- HARD SINGLE-LABEL ----------------------------------------
      preds = np.argmax(logits, axis=-1)
      return {"accuracy": float(accuracy_score(labels, preds))}

    # ------------------------------------------------------------------
    # 6. PREDICT FLEXIBLE
    # ------------------------------------------------------------------
    @torch.no_grad()
    def predict(self, texts, threshold=0.5, return_probabilities=True):
        if isinstance(texts, str):
            texts = [texts]

        toks = self.tokenizer(
            texts, return_tensors="pt",
            truncation=True, padding="max_length", max_length=128
        )
        device = next(self.model.parameters()).device
        toks = {k: v.to(device) for k, v in toks.items()}
        self.model.eval()

        logits = self.model(**toks).logits

        # ---------- soft ---------------------------------------------
        if self.soft:
            # binario soft
            if self.num_labels == 1:
                probs = torch.sigmoid(logits).squeeze().cpu().tolist()
                return probs if return_probabilities else [
                    int(p >= threshold) for p in probs
                ]
            # multilabel soft
            probs = torch.sigmoid(logits).cpu().numpy()
            outputs = []
            for vec in probs:
                d = {k: float(v) for k, v in zip(self.keys, vec)}
                if return_probabilities:
                    outputs.append(d)
                else:
                    sel = [k for k, p in d.items() if p >= threshold] or \
                          [max(d, key=d.get)]
                    outputs.append(sel)
            return outputs

        # ---------- hard ---------------------------------------------
        if self.problem_type == "multi_label_classification":
            probs = torch.sigmoid(logits).cpu().numpy()
            outputs = []
            for vec in probs:
                labels = [k for k, v in zip(self.keys, vec) if v >= threshold]
                outputs.append(labels or [self.keys[np.argmax(vec)]])
            return outputs
        else:
            pred_ids = logits.argmax(-1).cpu().numpy()
            return self.label_encoder.inverse_transform(pred_ids)


    def build_submission(
        self,
        threshold: float = 0.5,
        test_case: str = "EXIST2025",
        return_probabilities: bool = True,
        model_name: str = None,
        task_name: str = "task3_3",
        team_name: str = "ScalaR",
        run:int=1,
    ) -> List[Dict[str, Any]]:
        """
        label_name ..... 'label1', 'label2' o 'label3'
        threshold ...... umbral para convertir prob→etiqueta (solo hard multietiqueta)
        test_case ...... literal a incluir en cada JSON
        return_probabilities
            soft=True  -> dict de probabilidades (como tus ejemplos) si True,
                        lista de etiquetas si False
            soft=False -> se ignora; siempre lista/str de etiquetas duras
        """
        # ------------------------------------------------------
        # 1. Normalizar samples a lista ordenada [ {"id":..,"text":..}, ... ]
        # ------------------------------------------------------
        data=load_data_json("data/EXIST2025_training_videos.json")

        # DAta is a pandas dataframe

        texts = data['text'].tolist()
        ids = data['id'].tolist()
        # ------------------------------------------------------
        # 2. Inferencia
        # ------------------------------------------------------
        preds = [self.predict(
            p,
            threshold=threshold,
            return_probabilities=return_probabilities
        ) for p in texts]

        # ------------------------------------------------------
        # 3. Empaquetar resultado por muestra
        # ------------------------------------------------------
        outputs = []
        for s, p in zip(ids, preds):
            # p puede ser:
            #   • dict  -> probabilidades por clase
            #   • list  -> lista de etiquetas duras
            #   • int/str -> etiqueta única (hard-single)
            #   • float -> prob. binaria (soft escalar)
            value: Any
            if isinstance(p, list):
                value = p
                if isinstance(p[0], dict):
                    # soft multi-label
                    # if k=='-' convertimos a 'NO'
                    value = {k if k != "-" else 'NO': v for k, v in p[0].items()}

            elif isinstance(p,  str):
                value = p
            elif isinstance(p, np.ndarray):
                value=  p[0]
                value = 'NO' if value  == '-' else value

            outputs.append(
                {
                    "test_case": test_case,
                    "id": s,
                    "value": value,
                }
            )

        output_file = f'{task_name}_{"soft" if self.soft else "hard"}_{team_name}_{run}.json'
        with open(output_file, "w") as f:
            json.dump(outputs, f, indent=4, ensure_ascii=False)
        print(f"Submission saved to {output_file}")
        return outputs

# %% [markdown]
# ## Soft

# %%
bert1 = Test(soft=True, model_name="hate-speech-CNERG/bert-base-uncased-hatexplain", label_name="label1")
bert1.train(epochs=3)
bert1.build_submission(task_name="task3_1",run=2)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Map:   0%|          | 0/2145 [00:00<?, ? examples/s]
# Map:   0%|          | 0/379 [00:00<?, ? examples/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hate-speech-CNERG/bert-base-uncased-hatexplain and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([3, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([3]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-4-54a9ba2e44c6>:136: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   self.trainer = Trainer(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: diegorospagan (diegorospagan-universitat-polit-cnica-de-val-ncia) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/ALCLabs/Exist2025/wandb/run-20250511_145559-orw7j0w0</code>
# Syncing run <strong><a href='https://wandb.ai/diegorospagan-universitat-polit-cnica-de-val-ncia/huggingface/runs/orw7j0w0' target="_blank">trainer_output</a></strong> to <a href='https://wandb.ai/diegorospagan-universitat-polit-cnica-de-val-ncia/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/diegorospagan-universitat-polit-cnica-de-val-ncia/huggingface' target="_blank">https://wandb.ai/diegorospagan-universitat-polit-cnica-de-val-ncia/huggingface</a>
#  View run at <a href='https://wandb.ai/diegorospagan-universitat-polit-cnica-de-val-ncia/huggingface/runs/orw7j0w0' target="_blank">https://wandb.ai/diegorospagan-universitat-polit-cnica-de-val-ncia/huggingface/runs/orw7j0w0</a>
# BertSdpaSelfAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support non-absolute `position_embedding_type` or `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
#     <div>
#
#       <progress value='807' max='807' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [807/807 03:47, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mae</th>
#       <th>Logloss</th>
#       <th>F1 Micro</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.634674</td>
#       <td>0.372965</td>
#       <td>0.635147</td>
#       <td>0.622691</td>
#       <td>0.614152</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.646400</td>
#       <td>0.624521</td>
#       <td>0.342619</td>
#       <td>0.621247</td>
#       <td>0.658311</td>
#       <td>0.654270</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.646400</td>
#       <td>0.631771</td>
#       <td>0.332298</td>
#       <td>0.626889</td>
#       <td>0.671504</td>
#       <td>0.670955</td>
#     </tr>
#   </tbody>
# </table><p>
# Submission saved to task3_1_soft_ScalaR_2.json
# [{'test_case': 'EXIST2025',
#   'id': '120001',
#   'value': {'NO': 0.854523777961731, 'YES': 0.134112149477005}},
#  {'test_case': 'EXIST2025',
#   'id': '120002',
#   'value': {'NO': 0.5989495515823364, 'YES': 0.4302096366882324}},
#  {'test_case': 'EXIST2025',
#   'id': '120003',
#   'value': {'NO': 0.2501389980316162, 'YES': 0.7219666242599487}},
#  {'test_case': 'EXIST2025',
#   'id': '120004',
#   'value': {'NO': 0.22631269693374634, 'YES': 0.7692561149597168}},
#  {'test_case': 'EXIST2025',
#   'id': '120005',
#   'value': {'NO': 0.826419472694397, 'YES': 0.18121089041233063}},
#  {'test_case': 'EXIST2025',
#   'id': '120006',
#   'value': {'NO': 0.2964475154876709, 'YES': 0.6951873302459717}},
#  {'test_case': 'EXIST2025',
#   'id': '120007',
#   'value': {'NO': 0.16292542219161987, 'YES': 0.825683057308197}},
#  {'test_case': 'EXIST2025',
#   'id': '120008',
#   'value': {'NO': 0.1506296694278717, 'YES': 0.831970751285553}},
#  {'test_case': 'EXIST2025',
#   'id': '120009',
#   'value': {'NO': 0.2976810038089752, 'YES': 0.6908223628997803}},
#  {'test_case': 'EXIST2025',
#   'id': '120010',
#   'value': {'NO': 0.2746466100215912, 'YES': 0.7094405889511108}},
#  {'test_case': 'EXIST2025',
#   'id': '120011',
#   'value': {'NO': 0.28598135709762573, 'YES': 0.7267203330993652}},
#  {'test_case': 'EXIST2025',
#   'id': '120012',
#   'value': {'NO': 0.7142279744148254, 'YES': 0.28107404708862305}},
#  {'test_case': 'EXIST2025',
#   'id': '120013',
#   'value': {'NO': 0.28487706184387207, 'YES': 0.7148094177246094}},
#  {'test_case': 'EXIST2025',
#   'id': '120014',
#   'value': {'NO': 0.2548307776451111, 'YES': 0.7563837766647339}},
#  {'test_case': 'EXIST2025',
#   'id': '120015',
#   'value': {'NO': 0.6807661056518555, 'YES': 0.3139539062976837}},
#  {'test_case': 'EXIST2025',
#   'id': '120016',
#   'value': {'NO': 0.15233512222766876, 'YES': 0.8346806168556213}},
#  {'test_case': 'EXIST2025',
#   'id': '120017',
#   'value': {'NO': 0.7745361924171448, 'YES': 0.2095414698123932}},
#  {'test_case': 'EXIST2025',
#   'id': '120018',
#   'value': {'NO': 0.8196841478347778, 'YES': 0.17774087190628052}},
#  {'test_case': 'EXIST2025',
#   'id': '120019',
#   'value': {'NO': 0.8582165837287903, 'YES': 0.1344970017671585}},
#  {'test_case': 'EXIST2025',
#   'id': '120020',
#   'value': {'NO': 0.7822519540786743, 'YES': 0.18937350809574127}},
#  {'test_case': 'EXIST2025',
#   'id': '120021',
#   'value': {'NO': 0.5757834315299988, 'YES': 0.513048529624939}},
#  {'test_case': 'EXIST2025',
#   'id': '120022',
#   'value': {'NO': 0.17409811913967133, 'YES': 0.8124920129776001}},
#  {'test_case': 'EXIST2025',
#   'id': '120023',
#   'value': {'NO': 0.7154718041419983, 'YES': 0.25527408719062805}},
#  {'test_case': 'EXIST2025',
#   'id': '120024',
#   'value': {'NO': 0.7225260138511658, 'YES': 0.2818904221057892}},
#  {'test_case': 'EXIST2025',
#   'id': '120025',
#   'value': {'NO': 0.22677142918109894, 'YES': 0.7630588412284851}},
#  {'test_case': 'EXIST2025',
#   'id': '120026',
#   'value': {'NO': 0.20881465077400208, 'YES': 0.7753804326057434}},
#  {'test_case': 'EXIST2025',
#   'id': '120027',
#   'value': {'NO': 0.40390175580978394, 'YES': 0.6110085248947144}},
#  {'test_case': 'EXIST2025',
#   'id': '120028',
#   'value': {'NO': 0.4699116051197052, 'YES': 0.5323795676231384}},
#  {'test_case': 'EXIST2025',
#   'id': '120029',
#   'value': {'NO': 0.5052328109741211, 'YES': 0.5300166010856628}},
#  {'test_case': 'EXIST2025',
#   'id': '120030',
#   'value': {'NO': 0.20068950951099396, 'YES': 0.7920570373535156}},
#  {'test_case': 'EXIST2025',
#   'id': '120031',
#   'value': {'NO': 0.1629168540239334, 'YES': 0.8171949982643127}},
#  {'test_case': 'EXIST2025',
#   'id': '120032',
#   'value': {'NO': 0.7760380506515503, 'YES': 0.2381066530942917}},
#  {'test_case': 'EXIST2025',
#   'id': '120033',
#   'value': {'NO': 0.6576119065284729, 'YES': 0.36555588245391846}},
#  {'test_case': 'EXIST2025',
#   'id': '120034',
#   'value': {'NO': 0.7278122305870056, 'YES': 0.266059011220932}},
#  {'test_case': 'EXIST2025',
#   'id': '120035',
#   'value': {'NO': 0.2178526073694229, 'YES': 0.7761934399604797}},
#  {'test_case': 'EXIST2025',
#   'id': '120036',
#   'value': {'NO': 0.8584067225456238, 'YES': 0.12841574847698212}},
#  {'test_case': 'EXIST2025',
#   'id': '120037',
#   'value': {'NO': 0.2689661681652069, 'YES': 0.7385024428367615}},
#  {'test_case': 'EXIST2025',
#   'id': '120038',
#   'value': {'NO': 0.8399485945701599, 'YES': 0.15425194799900055}},
#  {'test_case': 'EXIST2025',
#   'id': '120039',
#   'value': {'NO': 0.7354254126548767, 'YES': 0.24849754571914673}},
#  {'test_case': 'EXIST2025',
#   'id': '120040',
#   'value': {'NO': 0.28530997037887573, 'YES': 0.7136269807815552}},
#  {'test_case': 'EXIST2025',
#   'id': '120041',
#   'value': {'NO': 0.5792326331138611, 'YES': 0.44610223174095154}},
#  {'test_case': 'EXIST2025',
#   'id': '120042',
#   'value': {'NO': 0.14313849806785583, 'YES': 0.8439481258392334}},
#  {'test_case': 'EXIST2025',
#   'id': '120043',
#   'value': {'NO': 0.461635023355484, 'YES': 0.49402350187301636}},
#  {'test_case': 'EXIST2025',
#   'id': '120044',
#   'value': {'NO': 0.30875086784362793, 'YES': 0.6792502999305725}},
#  {'test_case': 'EXIST2025',
#   'id': '120045',
#   'value': {'NO': 0.1493554264307022, 'YES': 0.8373169302940369}},
#  {'test_case': 'EXIST2025',
#   'id': '120046',
#   'value': {'NO': 0.749521017074585, 'YES': 0.23644018173217773}},
#  {'test_case': 'EXIST2025',
#   'id': '120047',
#   'value': {'NO': 0.1804824322462082, 'YES': 0.8022468686103821}},
#  {'test_case': 'EXIST2025',
#   'id': '120048',
#   'value': {'NO': 0.17666096985340118, 'YES': 0.8153870105743408}},
#  {'test_case': 'EXIST2025',
#   'id': '120049',
#   'value': {'NO': 0.7744967341423035, 'YES': 0.23094896972179413}},
#  {'test_case': 'EXIST2025',
#   'id': '120050',
#   'value': {'NO': 0.20073802769184113, 'YES': 0.7986673712730408}},
#  {'test_case': 'EXIST2025',
#   'id': '120051',
#   'value': {'NO': 0.18668341636657715, 'YES': 0.8023101687431335}},
#  {'test_case': 'EXIST2025',
#   'id': '120052',
#   'value': {'NO': 0.8419695496559143, 'YES': 0.13723480701446533}},
#  {'test_case': 'EXIST2025',
#   'id': '120053',
#   'value': {'NO': 0.7550256252288818, 'YES': 0.22747893631458282}},
#  {'test_case': 'EXIST2025',
#   'id': '120054',
#   'value': {'NO': 0.8694425821304321, 'YES': 0.11360933631658554}},
#  {'test_case': 'EXIST2025',
#   'id': '120055',
#   'value': {'NO': 0.22077246010303497, 'YES': 0.7502762675285339}},
#  {'test_case': 'EXIST2025',
#   'id': '120056',
#   'value': {'NO': 0.1386810690164566, 'YES': 0.8509817719459534}},
#  {'test_case': 'EXIST2025',
#   'id': '120057',
#   'value': {'NO': 0.14529433846473694, 'YES': 0.8447200059890747}},
#  {'test_case': 'EXIST2025',
#   'id': '120058',
#   'value': {'NO': 0.1455908715724945, 'YES': 0.8437604308128357}},
#  {'test_case': 'EXIST2025',
#   'id': '120059',
#   'value': {'NO': 0.8144370317459106, 'YES': 0.17820382118225098}},
#  {'test_case': 'EXIST2025',
#   'id': '120060',
#   'value': {'NO': 0.28075817227363586, 'YES': 0.714907169342041}},
#  {'test_case': 'EXIST2025',
#   'id': '120061',
#   'value': {'NO': 0.22107943892478943, 'YES': 0.7748883366584778}},
#  {'test_case': 'EXIST2025',
#   'id': '120062',
#   'value': {'NO': 0.1852509081363678, 'YES': 0.8052102327346802}},
#  {'test_case': 'EXIST2025',
#   'id': '120063',
#   'value': {'NO': 0.3694203495979309, 'YES': 0.6553505659103394}},
#  {'test_case': 'EXIST2025',
#   'id': '120064',
#   'value': {'NO': 0.2129417359828949, 'YES': 0.7623207569122314}},
#  {'test_case': 'EXIST2025',
#   'id': '120065',
#   'value': {'NO': 0.6093557476997375, 'YES': 0.36834636330604553}},
#  {'test_case': 'EXIST2025',
#   'id': '120066',
#   'value': {'NO': 0.144234299659729, 'YES': 0.8491271138191223}},
#  {'test_case': 'EXIST2025',
#   'id': '120067',
#   'value': {'NO': 0.2353278547525406, 'YES': 0.763286828994751}},
#  {'test_case': 'EXIST2025',
#   'id': '120068',
#   'value': {'NO': 0.25556132197380066, 'YES': 0.741669774055481}},
#  {'test_case': 'EXIST2025',
#   'id': '120069',
#   'value': {'NO': 0.14235305786132812, 'YES': 0.8483281135559082}},
#  {'test_case': 'EXIST2025',
#   'id': '120070',
#   'value': {'NO': 0.1986706405878067, 'YES': 0.7928128242492676}},
#  {'test_case': 'EXIST2025',
#   'id': '120071',
#   'value': {'NO': 0.18902930617332458, 'YES': 0.785057008266449}},
#  {'test_case': 'EXIST2025',
#   'id': '120072',
#   'value': {'NO': 0.6253486275672913, 'YES': 0.36962804198265076}},
#  {'test_case': 'EXIST2025',
#   'id': '120073',
#   'value': {'NO': 0.8373411893844604, 'YES': 0.15373702347278595}},
#  {'test_case': 'EXIST2025',
#   'id': '120074',
#   'value': {'NO': 0.25453200936317444, 'YES': 0.73787522315979}},
#  {'test_case': 'EXIST2025',
#   'id': '120075',
#   'value': {'NO': 0.8542563915252686, 'YES': 0.1546912044286728}},
#  {'test_case': 'EXIST2025',
#   'id': '120076',
#   'value': {'NO': 0.3290305435657501, 'YES': 0.6854906678199768}},
#  {'test_case': 'EXIST2025',
#   'id': '120077',
#   'value': {'NO': 0.5504856109619141, 'YES': 0.572443425655365}},
#  {'test_case': 'EXIST2025',
#   'id': '120078',
#   'value': {'NO': 0.28885379433631897, 'YES': 0.6879726052284241}},
#  {'test_case': 'EXIST2025',
#   'id': '120079',
#   'value': {'NO': 0.4402921497821808, 'YES': 0.5243518352508545}},
#  {'test_case': 'EXIST2025',
#   'id': '120080',
#   'value': {'NO': 0.15142549574375153, 'YES': 0.839883029460907}},
#  {'test_case': 'EXIST2025',
#   'id': '120081',
#   'value': {'NO': 0.8278945684432983, 'YES': 0.16594256460666656}},
#  {'test_case': 'EXIST2025',
#   'id': '120082',
#   'value': {'NO': 0.5492829084396362, 'YES': 0.4057435989379883}},
#  {'test_case': 'EXIST2025',
#   'id': '120083',
#   'value': {'NO': 0.20494039356708527, 'YES': 0.7881289124488831}},
#  {'test_case': 'EXIST2025',
#   'id': '120084',
#   'value': {'NO': 0.5926927924156189, 'YES': 0.4602472484111786}},
#  {'test_case': 'EXIST2025',
#   'id': '120085',
#   'value': {'NO': 0.7867290377616882, 'YES': 0.19726616144180298}},
#  {'test_case': 'EXIST2025',
#   'id': '120086',
#   'value': {'NO': 0.7230251431465149, 'YES': 0.30279475450515747}},
#  {'test_case': 'EXIST2025',
#   'id': '120087',
#   'value': {'NO': 0.8615006804466248, 'YES': 0.1285596489906311}},
#  {'test_case': 'EXIST2025',
#   'id': '120088',
#   'value': {'NO': 0.16016077995300293, 'YES': 0.8312284350395203}},
#  {'test_case': 'EXIST2025',
#   'id': '120089',
#   'value': {'NO': 0.19394171237945557, 'YES': 0.7979785203933716}},
#  {'test_case': 'EXIST2025',
#   'id': '120090',
#   'value': {'NO': 0.20425716042518616, 'YES': 0.76078200340271}},
#  {'test_case': 'EXIST2025',
#   'id': '120091',
#   'value': {'NO': 0.14302624762058258, 'YES': 0.8446714878082275}},
#  {'test_case': 'EXIST2025',
#   'id': '120092',
#   'value': {'NO': 0.35106760263442993, 'YES': 0.6467273235321045}},
#  {'test_case': 'EXIST2025',
#   'id': '120093',
#   'value': {'NO': 0.21917939186096191, 'YES': 0.752021849155426}},
#  {'test_case': 'EXIST2025',
#   'id': '120094',
#   'value': {'NO': 0.4077616035938263, 'YES': 0.5717992782592773}},
#  {'test_case': 'EXIST2025',
#   'id': '120095',
#   'value': {'NO': 0.16910502314567566, 'YES': 0.812188446521759}},
#  {'test_case': 'EXIST2025',
#   'id': '120096',
#   'value': {'NO': 0.14808043837547302, 'YES': 0.8383859395980835}},
#  {'test_case': 'EXIST2025',
#   'id': '120097',
#   'value': {'NO': 0.8197713494300842, 'YES': 0.1682358831167221}},
#  {'test_case': 'EXIST2025',
#   'id': '120098',
#   'value': {'NO': 0.23572060465812683, 'YES': 0.7640740275382996}},
#  {'test_case': 'EXIST2025',
#   'id': '120099',
#   'value': {'NO': 0.6702213287353516, 'YES': 0.3205709755420685}},
#  {'test_case': 'EXIST2025',
#   'id': '120100',
#   'value': {'NO': 0.24009782075881958, 'YES': 0.7523203492164612}},
#  {'test_case': 'EXIST2025',
#   'id': '120101',
#   'value': {'NO': 0.8204455971717834, 'YES': 0.15332172811031342}},
#  {'test_case': 'EXIST2025',
#   'id': '120102',
#   'value': {'NO': 0.36542361974716187, 'YES': 0.6227276921272278}},
#  {'test_case': 'EXIST2025',
#   'id': '120103',
#   'value': {'NO': 0.5054602026939392, 'YES': 0.510783314704895}},
#  {'test_case': 'EXIST2025',
#   'id': '120104',
#   'value': {'NO': 0.1971539705991745, 'YES': 0.7936537861824036}},
#  {'test_case': 'EXIST2025',
#   'id': '120105',
#   'value': {'NO': 0.15152496099472046, 'YES': 0.8242300748825073}},
#  {'test_case': 'EXIST2025',
#   'id': '120106',
#   'value': {'NO': 0.19545041024684906, 'YES': 0.7893320918083191}},
#  {'test_case': 'EXIST2025',
#   'id': '120107',
#   'value': {'NO': 0.7715299129486084, 'YES': 0.24069444835186005}},
#  {'test_case': 'EXIST2025',
#   'id': '120108',
#   'value': {'NO': 0.14622536301612854, 'YES': 0.8425664901733398}},
#  {'test_case': 'EXIST2025',
#   'id': '120109',
#   'value': {'NO': 0.30923205614089966, 'YES': 0.6938150525093079}},
#  {'test_case': 'EXIST2025',
#   'id': '120110',
#   'value': {'NO': 0.3548337519168854, 'YES': 0.6589183211326599}},
#  {'test_case': 'EXIST2025',
#   'id': '120111',
#   'value': {'NO': 0.3448786735534668, 'YES': 0.6453080177307129}},
#  {'test_case': 'EXIST2025',
#   'id': '120112',
#   'value': {'NO': 0.21300865709781647, 'YES': 0.7677667737007141}},
#  {'test_case': 'EXIST2025',
#   'id': '120113',
#   'value': {'NO': 0.2871493697166443, 'YES': 0.7174069881439209}},
#  {'test_case': 'EXIST2025',
#   'id': '120114',
#   'value': {'NO': 0.28437140583992004, 'YES': 0.7032939195632935}},
#  {'test_case': 'EXIST2025',
#   'id': '120115',
#   'value': {'NO': 0.3179485499858856, 'YES': 0.6723136901855469}},
#  {'test_case': 'EXIST2025',
#   'id': '120116',
#   'value': {'NO': 0.4180646538734436, 'YES': 0.6136211156845093}},
#  {'test_case': 'EXIST2025',
#   'id': '120117',
#   'value': {'NO': 0.8491483926773071, 'YES': 0.15124766528606415}},
#  {'test_case': 'EXIST2025',
#   'id': '120118',
#   'value': {'NO': 0.16373306512832642, 'YES': 0.8240650296211243}},
#  {'test_case': 'EXIST2025',
#   'id': '120119',
#   'value': {'NO': 0.8235198855400085, 'YES': 0.18119607865810394}},
#  {'test_case': 'EXIST2025',
#   'id': '120120',
#   'value': {'NO': 0.37089747190475464, 'YES': 0.6440750956535339}},
#  {'test_case': 'EXIST2025',
#   'id': '120121',
#   'value': {'NO': 0.20702053606510162, 'YES': 0.7891472578048706}},
#  {'test_case': 'EXIST2025',
#   'id': '120122',
#   'value': {'NO': 0.47927695512771606, 'YES': 0.5377474427223206}},
#  {'test_case': 'EXIST2025',
#   'id': '120123',
#   'value': {'NO': 0.8125486969947815, 'YES': 0.17429693043231964}},
#  {'test_case': 'EXIST2025',
#   'id': '120124',
#   'value': {'NO': 0.3557947874069214, 'YES': 0.6487637162208557}},
#  {'test_case': 'EXIST2025',
#   'id': '120125',
#   'value': {'NO': 0.3829357922077179, 'YES': 0.633752703666687}},
#  {'test_case': 'EXIST2025',
#   'id': '120126',
#   'value': {'NO': 0.1786341816186905, 'YES': 0.8059197068214417}},
#  {'test_case': 'EXIST2025',
#   'id': '120127',
#   'value': {'NO': 0.134450301527977, 'YES': 0.8542376756668091}},
#  {'test_case': 'EXIST2025',
#   'id': '120128',
#   'value': {'NO': 0.13670200109481812, 'YES': 0.8533967137336731}},
#  {'test_case': 'EXIST2025',
#   'id': '120129',
#   'value': {'NO': 0.13720139861106873, 'YES': 0.8464317917823792}},
#  {'test_case': 'EXIST2025',
#   'id': '120130',
#   'value': {'NO': 0.17283062636852264, 'YES': 0.8170354962348938}},
#  {'test_case': 'EXIST2025',
#   'id': '120131',
#   'value': {'NO': 0.16945455968379974, 'YES': 0.8129281401634216}},
#  {'test_case': 'EXIST2025',
#   'id': '120132',
#   'value': {'NO': 0.16474825143814087, 'YES': 0.8270030617713928}},
#  {'test_case': 'EXIST2025',
#   'id': '120133',
#   'value': {'NO': 0.26332321763038635, 'YES': 0.7157773375511169}},
#  {'test_case': 'EXIST2025',
#   'id': '120134',
#   'value': {'NO': 0.14676237106323242, 'YES': 0.841835618019104}},
#  {'test_case': 'EXIST2025',
#   'id': '120135',
#   'value': {'NO': 0.19960759580135345, 'YES': 0.7884742021560669}},
#  {'test_case': 'EXIST2025',
#   'id': '120136',
#   'value': {'NO': 0.5715643167495728, 'YES': 0.41357338428497314}},
#  {'test_case': 'EXIST2025',
#   'id': '120137',
#   'value': {'NO': 0.7610788345336914, 'YES': 0.23412036895751953}},
#  {'test_case': 'EXIST2025',
#   'id': '120138',
#   'value': {'NO': 0.6106138229370117, 'YES': 0.44868484139442444}},
#  {'test_case': 'EXIST2025',
#   'id': '120139',
#   'value': {'NO': 0.1500946283340454, 'YES': 0.838037371635437}},
#  {'test_case': 'EXIST2025',
#   'id': '120140',
#   'value': {'NO': 0.14321021735668182, 'YES': 0.8451331853866577}},
#  {'test_case': 'EXIST2025',
#   'id': '120141',
#   'value': {'NO': 0.7719564437866211, 'YES': 0.2200128138065338}},
#  {'test_case': 'EXIST2025',
#   'id': '120142',
#   'value': {'NO': 0.1773996204137802, 'YES': 0.8213478326797485}},
#  {'test_case': 'EXIST2025',
#   'id': '120143',
#   'value': {'NO': 0.20781546831130981, 'YES': 0.7763406038284302}},
#  {'test_case': 'EXIST2025',
#   'id': '120144',
#   'value': {'NO': 0.8508826494216919, 'YES': 0.14963090419769287}},
#  {'test_case': 'EXIST2025',
#   'id': '120145',
#   'value': {'NO': 0.19330793619155884, 'YES': 0.7900379300117493}},
#  {'test_case': 'EXIST2025',
#   'id': '120146',
#   'value': {'NO': 0.8573688268661499, 'YES': 0.1292521208524704}},
#  {'test_case': 'EXIST2025',
#   'id': '120147',
#   'value': {'NO': 0.5610840320587158, 'YES': 0.49222034215927124}},
#  {'test_case': 'EXIST2025',
#   'id': '120148',
#   'value': {'NO': 0.7762008309364319, 'YES': 0.21557192504405975}},
#  {'test_case': 'EXIST2025',
#   'id': '120149',
#   'value': {'NO': 0.8389252424240112, 'YES': 0.15222954750061035}},
#  {'test_case': 'EXIST2025',
#   'id': '120150',
#   'value': {'NO': 0.6090137958526611, 'YES': 0.3897720277309418}},
#  {'test_case': 'EXIST2025',
#   'id': '120151',
#   'value': {'NO': 0.8631182312965393, 'YES': 0.13892632722854614}},
#  {'test_case': 'EXIST2025',
#   'id': '120152',
#   'value': {'NO': 0.6738470196723938, 'YES': 0.3228289783000946}},
#  {'test_case': 'EXIST2025',
#   'id': '120153',
#   'value': {'NO': 0.7450435161590576, 'YES': 0.24330492317676544}},
#  {'test_case': 'EXIST2025',
#   'id': '120154',
#   'value': {'NO': 0.7735872268676758, 'YES': 0.21223421394824982}},
#  {'test_case': 'EXIST2025',
#   'id': '120155',
#   'value': {'NO': 0.7782636284828186, 'YES': 0.20734433829784393}},
#  {'test_case': 'EXIST2025',
#   'id': '120156',
#   'value': {'NO': 0.234235480427742, 'YES': 0.7661126852035522}},
#  {'test_case': 'EXIST2025',
#   'id': '120157',
#   'value': {'NO': 0.843609631061554, 'YES': 0.16373887658119202}},
#  {'test_case': 'EXIST2025',
#   'id': '120158',
#   'value': {'NO': 0.597424328327179, 'YES': 0.3947879672050476}},
#  {'test_case': 'EXIST2025',
#   'id': '120159',
#   'value': {'NO': 0.23503218591213226, 'YES': 0.7511417865753174}},
#  {'test_case': 'EXIST2025',
#   'id': '120160',
#   'value': {'NO': 0.18626181781291962, 'YES': 0.7899847626686096}},
#  {'test_case': 'EXIST2025',
#   'id': '120161',
#   'value': {'NO': 0.6983048915863037, 'YES': 0.34767067432403564}},
#  {'test_case': 'EXIST2025',
#   'id': '120162',
#   'value': {'NO': 0.2261035293340683, 'YES': 0.7567930221557617}},
#  {'test_case': 'EXIST2025',
#   'id': '120163',
#   'value': {'NO': 0.6292079091072083, 'YES': 0.3576933741569519}},
#  {'test_case': 'EXIST2025',
#   'id': '120164',
#   'value': {'NO': 0.8836166858673096, 'YES': 0.10875674337148666}},
#  {'test_case': 'EXIST2025',
#   'id': '120165',
#   'value': {'NO': 0.7229025363922119, 'YES': 0.27669960260391235}},
#  {'test_case': 'EXIST2025',
#   'id': '120166',
#   'value': {'NO': 0.6215934753417969, 'YES': 0.3331207036972046}},
#  {'test_case': 'EXIST2025',
#   'id': '120167',
#   'value': {'NO': 0.24664466083049774, 'YES': 0.7313095927238464}},
#  {'test_case': 'EXIST2025',
#   'id': '120168',
#   'value': {'NO': 0.5779203176498413, 'YES': 0.4007009267807007}},
#  {'test_case': 'EXIST2025',
#   'id': '120169',
#   'value': {'NO': 0.24634337425231934, 'YES': 0.7666399478912354}},
#  {'test_case': 'EXIST2025',
#   'id': '120170',
#   'value': {'NO': 0.8631535768508911, 'YES': 0.12082846462726593}},
#  {'test_case': 'EXIST2025',
#   'id': '120171',
#   'value': {'NO': 0.845077633857727, 'YES': 0.1539732962846756}},
#  {'test_case': 'EXIST2025',
#   'id': '120172',
#   'value': {'NO': 0.6515023708343506, 'YES': 0.3032548725605011}},
#  {'test_case': 'EXIST2025',
#   'id': '120173',
#   'value': {'NO': 0.8359909057617188, 'YES': 0.14640110731124878}},
#  {'test_case': 'EXIST2025',
#   'id': '120174',
#   'value': {'NO': 0.6427916884422302, 'YES': 0.3623495399951935}},
#  {'test_case': 'EXIST2025',
#   'id': '120175',
#   'value': {'NO': 0.8200855255126953, 'YES': 0.17481641471385956}},
#  {'test_case': 'EXIST2025',
#   'id': '120176',
#   'value': {'NO': 0.8302031755447388, 'YES': 0.17366431653499603}},
#  {'test_case': 'EXIST2025',
#   'id': '120177',
#   'value': {'NO': 0.8411704897880554, 'YES': 0.15826785564422607}},
#  {'test_case': 'EXIST2025',
#   'id': '120178',
#   'value': {'NO': 0.8058973550796509, 'YES': 0.1997866928577423}},
#  {'test_case': 'EXIST2025',
#   'id': '120179',
#   'value': {'NO': 0.829896092414856, 'YES': 0.16915373504161835}},
#  {'test_case': 'EXIST2025',
#   'id': '120180',
#   'value': {'NO': 0.7351345419883728, 'YES': 0.25684285163879395}},
#  {'test_case': 'EXIST2025',
#   'id': '120181',
#   'value': {'NO': 0.8459048867225647, 'YES': 0.14683520793914795}},
#  {'test_case': 'EXIST2025',
#   'id': '120182',
#   'value': {'NO': 0.3756513297557831, 'YES': 0.6069955825805664}},
#  {'test_case': 'EXIST2025',
#   'id': '120183',
#   'value': {'NO': 0.8477535843849182, 'YES': 0.14776566624641418}},
#  {'test_case': 'EXIST2025',
#   'id': '120184',
#   'value': {'NO': 0.8405662178993225, 'YES': 0.15462444722652435}},
#  {'test_case': 'EXIST2025',
#   'id': '120185',
#   'value': {'NO': 0.878234326839447, 'YES': 0.11282449960708618}},
#  {'test_case': 'EXIST2025',
#   'id': '120186',
#   'value': {'NO': 0.8716260194778442, 'YES': 0.11887543648481369}},
#  {'test_case': 'EXIST2025',
#   'id': '120187',
#   'value': {'NO': 0.7489301562309265, 'YES': 0.26139774918556213}},
#  {'test_case': 'EXIST2025',
#   'id': '120188',
#   'value': {'NO': 0.6567665338516235, 'YES': 0.30331602692604065}},
#  {'test_case': 'EXIST2025',
#   'id': '120189',
#   'value': {'NO': 0.6267269849777222, 'YES': 0.38025152683258057}},
#  {'test_case': 'EXIST2025',
#   'id': '120190',
#   'value': {'NO': 0.7453168034553528, 'YES': 0.23363852500915527}},
#  {'test_case': 'EXIST2025',
#   'id': '120191',
#   'value': {'NO': 0.8524306416511536, 'YES': 0.13478203117847443}},
#  {'test_case': 'EXIST2025',
#   'id': '120192',
#   'value': {'NO': 0.8086442947387695, 'YES': 0.20070411264896393}},
#  {'test_case': 'EXIST2025',
#   'id': '120193',
#   'value': {'NO': 0.8487899303436279, 'YES': 0.14182808995246887}},
#  {'test_case': 'EXIST2025',
#   'id': '120194',
#   'value': {'NO': 0.5758293867111206, 'YES': 0.35996636748313904}},
#  {'test_case': 'EXIST2025',
#   'id': '120195',
#   'value': {'NO': 0.8011918067932129, 'YES': 0.1983703374862671}},
#  {'test_case': 'EXIST2025',
#   'id': '120196',
#   'value': {'NO': 0.3246072232723236, 'YES': 0.6807699799537659}},
#  {'test_case': 'EXIST2025',
#   'id': '120197',
#   'value': {'NO': 0.8383423089981079, 'YES': 0.1692967414855957}},
#  {'test_case': 'EXIST2025',
#   'id': '120198',
#   'value': {'NO': 0.6441041827201843, 'YES': 0.32407984137535095}},
#  {'test_case': 'EXIST2025',
#   'id': '120199',
#   'value': {'NO': 0.40293043851852417, 'YES': 0.5554371476173401}},
#  {'test_case': 'EXIST2025',
#   'id': '120200',
#   'value': {'NO': 0.34539976716041565, 'YES': 0.6695294380187988}},
#  {'test_case': 'EXIST2025',
#   'id': '120201',
#   'value': {'NO': 0.8302719593048096, 'YES': 0.16168799996376038}},
#  {'test_case': 'EXIST2025',
#   'id': '120202',
#   'value': {'NO': 0.607699990272522, 'YES': 0.45001843571662903}},
#  {'test_case': 'EXIST2025',
#   'id': '120203',
#   'value': {'NO': 0.20362582802772522, 'YES': 0.7949394583702087}},
#  {'test_case': 'EXIST2025',
#   'id': '120204',
#   'value': {'NO': 0.5857431292533875, 'YES': 0.4345080852508545}},
#  {'test_case': 'EXIST2025',
#   'id': '120205',
#   'value': {'NO': 0.8688587546348572, 'YES': 0.139835923910141}},
#  {'test_case': 'EXIST2025',
#   'id': '120206',
#   'value': {'NO': 0.46042072772979736, 'YES': 0.5708152055740356}},
#  {'test_case': 'EXIST2025',
#   'id': '120207',
#   'value': {'NO': 0.46368086338043213, 'YES': 0.5646740198135376}},
#  {'test_case': 'EXIST2025',
#   'id': '120208',
#   'value': {'NO': 0.8651176691055298, 'YES': 0.1346060037612915}},
#  {'test_case': 'EXIST2025',
#   'id': '120209',
#   'value': {'NO': 0.17958204448223114, 'YES': 0.8080433011054993}},
#  {'test_case': 'EXIST2025',
#   'id': '120210',
#   'value': {'NO': 0.14478059113025665, 'YES': 0.8463580012321472}},
#  {'test_case': 'EXIST2025',
#   'id': '120211',
#   'value': {'NO': 0.703918993473053, 'YES': 0.31749048829078674}},
#  {'test_case': 'EXIST2025',
#   'id': '120212',
#   'value': {'NO': 0.870860755443573, 'YES': 0.13470320403575897}},
#  {'test_case': 'EXIST2025',
#   'id': '120213',
#   'value': {'NO': 0.1976231187582016, 'YES': 0.7922502160072327}},
#  {'test_case': 'EXIST2025',
#   'id': '120214',
#   'value': {'NO': 0.1834244728088379, 'YES': 0.8068292140960693}},
#  {'test_case': 'EXIST2025',
#   'id': '120215',
#   'value': {'NO': 0.13988235592842102, 'YES': 0.8485058546066284}},
#  {'test_case': 'EXIST2025',
#   'id': '120216',
#   'value': {'NO': 0.44914573431015015, 'YES': 0.5613161325454712}},
#  {'test_case': 'EXIST2025',
#   'id': '120217',
#   'value': {'NO': 0.7338591814041138, 'YES': 0.2669966518878937}},
#  {'test_case': 'EXIST2025',
#   'id': '120218',
#   'value': {'NO': 0.14698092639446259, 'YES': 0.8426415920257568}},
#  {'test_case': 'EXIST2025',
#   'id': '120219',
#   'value': {'NO': 0.29002049565315247, 'YES': 0.6976509690284729}},
#  {'test_case': 'EXIST2025',
#   'id': '120220',
#   'value': {'NO': 0.1790706217288971, 'YES': 0.8081388473510742}},
#  {'test_case': 'EXIST2025',
#   'id': '120221',
#   'value': {'NO': 0.14863722026348114, 'YES': 0.8374859094619751}},
#  {'test_case': 'EXIST2025',
#   'id': '120222',
#   'value': {'NO': 0.1834917962551117, 'YES': 0.8109334707260132}},
#  {'test_case': 'EXIST2025',
#   'id': '120223',
#   'value': {'NO': 0.21210835874080658, 'YES': 0.7699019908905029}},
#  {'test_case': 'EXIST2025',
#   'id': '120224',
#   'value': {'NO': 0.6104395389556885, 'YES': 0.41606780886650085}},
#  {'test_case': 'EXIST2025',
#   'id': '120225',
#   'value': {'NO': 0.16356170177459717, 'YES': 0.8265813589096069}},
#  {'test_case': 'EXIST2025',
#   'id': '120226',
#   'value': {'NO': 0.14905643463134766, 'YES': 0.8400128483772278}},
#  {'test_case': 'EXIST2025',
#   'id': '120227',
#   'value': {'NO': 0.22760657966136932, 'YES': 0.7637098431587219}},
#  {'test_case': 'EXIST2025',
#   'id': '120228',
#   'value': {'NO': 0.8620873093605042, 'YES': 0.14611142873764038}},
#  {'test_case': 'EXIST2025',
#   'id': '120229',
#   'value': {'NO': 0.2911228835582733, 'YES': 0.6994928121566772}},
#  {'test_case': 'EXIST2025',
#   'id': '120230',
#   'value': {'NO': 0.6406989097595215, 'YES': 0.34766510128974915}},
#  {'test_case': 'EXIST2025',
#   'id': '120231',
#   'value': {'NO': 0.6369890570640564, 'YES': 0.3522976338863373}},
#  {'test_case': 'EXIST2025',
#   'id': '120232',
#   'value': {'NO': 0.13542388379573822, 'YES': 0.8524956107139587}},
#  {'test_case': 'EXIST2025',
#   'id': '120233',
#   'value': {'NO': 0.6635177135467529, 'YES': 0.3734736442565918}},
#  {'test_case': 'EXIST2025',
#   'id': '120234',
#   'value': {'NO': 0.6957671046257019, 'YES': 0.2888779044151306}},
#  {'test_case': 'EXIST2025',
#   'id': '120235',
#   'value': {'NO': 0.16017776727676392, 'YES': 0.8226496577262878}},
#  {'test_case': 'EXIST2025',
#   'id': '120236',
#   'value': {'NO': 0.16646748781204224, 'YES': 0.8280064463615417}},
#  {'test_case': 'EXIST2025',
#   'id': '120237',
#   'value': {'NO': 0.13776089251041412, 'YES': 0.8537846803665161}},
#  {'test_case': 'EXIST2025',
#   'id': '120238',
#   'value': {'NO': 0.151580810546875, 'YES': 0.8462475538253784}},
#  {'test_case': 'EXIST2025',
#   'id': '120239',
#   'value': {'NO': 0.7926793098449707, 'YES': 0.1951753795146942}},
#  {'test_case': 'EXIST2025',
#   'id': '120240',
#   'value': {'NO': 0.16894382238388062, 'YES': 0.8149949908256531}},
#  {'test_case': 'EXIST2025',
#   'id': '120241',
#   'value': {'NO': 0.14284329116344452, 'YES': 0.846630334854126}},
#  {'test_case': 'EXIST2025',
#   'id': '120242',
#   'value': {'NO': 0.22297896444797516, 'YES': 0.7641837000846863}},
#  {'test_case': 'EXIST2025',
#   'id': '120243',
#   'value': {'NO': 0.7892932891845703, 'YES': 0.22216299176216125}},
#  {'test_case': 'EXIST2025',
#   'id': '120244',
#   'value': {'NO': 0.1374056488275528, 'YES': 0.8476454615592957}},
#  {'test_case': 'EXIST2025',
#   'id': '120245',
#   'value': {'NO': 0.7265169620513916, 'YES': 0.2826189696788788}},
#  {'test_case': 'EXIST2025',
#   'id': '120246',
#   'value': {'NO': 0.13036392629146576, 'YES': 0.8600067496299744}},
#  {'test_case': 'EXIST2025',
#   'id': '120247',
#   'value': {'NO': 0.18856795132160187, 'YES': 0.7932885885238647}},
#  {'test_case': 'EXIST2025',
#   'id': '120248',
#   'value': {'NO': 0.16156843304634094, 'YES': 0.8239438533782959}},
#  {'test_case': 'EXIST2025',
#   'id': '120249',
#   'value': {'NO': 0.13279485702514648, 'YES': 0.8605546355247498}},
#  {'test_case': 'EXIST2025',
#   'id': '120250',
#   'value': {'NO': 0.18175910413265228, 'YES': 0.8196104168891907}},
#  {'test_case': 'EXIST2025',
#   'id': '120251',
#   'value': {'NO': 0.2133183777332306, 'YES': 0.7745059132575989}},
#  {'test_case': 'EXIST2025',
#   'id': '120252',
#   'value': {'NO': 0.19918638467788696, 'YES': 0.7915842533111572}},
#  {'test_case': 'EXIST2025',
#   'id': '120253',
#   'value': {'NO': 0.21507900953292847, 'YES': 0.7799556851387024}},
#  {'test_case': 'EXIST2025',
#   'id': '120254',
#   'value': {'NO': 0.25824683904647827, 'YES': 0.7505046129226685}},
#  {'test_case': 'EXIST2025',
#   'id': '120255',
#   'value': {'NO': 0.1890365481376648, 'YES': 0.7985709309577942}},
#  {'test_case': 'EXIST2025',
#   'id': '120256',
#   'value': {'NO': 0.20614613592624664, 'YES': 0.7945703268051147}},
#  {'test_case': 'EXIST2025',
#   'id': '120257',
#   'value': {'NO': 0.22617636620998383, 'YES': 0.774390697479248}},
#  {'test_case': 'EXIST2025',
#   'id': '120258',
#   'value': {'NO': 0.1927463859319687, 'YES': 0.8057074546813965}},
#  {'test_case': 'EXIST2025',
#   'id': '120259',
#   'value': {'NO': 0.5058748722076416, 'YES': 0.4161520302295685}},
#  {'test_case': 'EXIST2025',
#   'id': '120260',
#   'value': {'NO': 0.2310355305671692, 'YES': 0.7689641118049622}},
#  {'test_case': 'EXIST2025',
#   'id': '120261',
#   'value': {'NO': 0.2959124445915222, 'YES': 0.6614735126495361}},
#  {'test_case': 'EXIST2025',
#   'id': '120262',
#   'value': {'NO': 0.6343551874160767, 'YES': 0.4080933928489685}},
#  {'test_case': 'EXIST2025',
#   'id': '120263',
#   'value': {'NO': 0.7701256275177002, 'YES': 0.22644516825675964}},
#  {'test_case': 'EXIST2025',
#   'id': '120264',
#   'value': {'NO': 0.18953284621238708, 'YES': 0.7982381582260132}},
#  {'test_case': 'EXIST2025',
#   'id': '120265',
#   'value': {'NO': 0.26510119438171387, 'YES': 0.7271197438240051}},
#  {'test_case': 'EXIST2025',
#   'id': '120266',
#   'value': {'NO': 0.2189372330904007, 'YES': 0.7765026092529297}},
#  {'test_case': 'EXIST2025',
#   'id': '120267',
#   'value': {'NO': 0.7118743062019348, 'YES': 0.29270878434181213}},
#  {'test_case': 'EXIST2025',
#   'id': '120268',
#   'value': {'NO': 0.7737385034561157, 'YES': 0.22982311248779297}},
#  {'test_case': 'EXIST2025',
#   'id': '120269',
#   'value': {'NO': 0.8062583208084106, 'YES': 0.18198348581790924}},
#  {'test_case': 'EXIST2025',
#   'id': '120270',
#   'value': {'NO': 0.872297465801239, 'YES': 0.11191555112600327}},
#  {'test_case': 'EXIST2025',
#   'id': '120271',
#   'value': {'NO': 0.4049338400363922, 'YES': 0.5842495560646057}},
#  {'test_case': 'EXIST2025',
#   'id': '120272',
#   'value': {'NO': 0.41733381152153015, 'YES': 0.5827842950820923}},
#  {'test_case': 'EXIST2025',
#   'id': '120273',
#   'value': {'NO': 0.3959648013114929, 'YES': 0.5816053748130798}},
#  {'test_case': 'EXIST2025',
#   'id': '120274',
#   'value': {'NO': 0.39696359634399414, 'YES': 0.588438868522644}},
#  {'test_case': 'EXIST2025',
#   'id': '120275',
#   'value': {'NO': 0.5031499862670898, 'YES': 0.4511597454547882}},
#  {'test_case': 'EXIST2025',
#   'id': '120276',
#   'value': {'NO': 0.7461532950401306, 'YES': 0.23357650637626648}},
#  {'test_case': 'EXIST2025',
#   'id': '120277',
#   'value': {'NO': 0.18642555177211761, 'YES': 0.7962766885757446}},
#  {'test_case': 'EXIST2025',
#   'id': '120278',
#   'value': {'NO': 0.6965170502662659, 'YES': 0.2846899628639221}},
#  {'test_case': 'EXIST2025',
#   'id': '120279',
#   'value': {'NO': 0.5069400072097778, 'YES': 0.4793425500392914}},
#  {'test_case': 'EXIST2025',
#   'id': '120280',
#   'value': {'NO': 0.8453930020332336, 'YES': 0.1362009346485138}},
#  {'test_case': 'EXIST2025',
#   'id': '120281',
#   'value': {'NO': 0.2852412760257721, 'YES': 0.7238636016845703}},
#  {'test_case': 'EXIST2025',
#   'id': '120282',
#   'value': {'NO': 0.19108135998249054, 'YES': 0.7936950325965881}},
#  {'test_case': 'EXIST2025',
#   'id': '120283',
#   'value': {'NO': 0.19849364459514618, 'YES': 0.7897851467132568}},
#  {'test_case': 'EXIST2025',
#   'id': '120284',
#   'value': {'NO': 0.8718266487121582, 'YES': 0.11884841322898865}},
#  {'test_case': 'EXIST2025',
#   'id': '120285',
#   'value': {'NO': 0.21515138447284698, 'YES': 0.7753564715385437}},
#  {'test_case': 'EXIST2025',
#   'id': '120286',
#   'value': {'NO': 0.37685707211494446, 'YES': 0.6597597002983093}},
#  {'test_case': 'EXIST2025',
#   'id': '120287',
#   'value': {'NO': 0.3191647231578827, 'YES': 0.676317036151886}},
#  {'test_case': 'EXIST2025',
#   'id': '120288',
#   'value': {'NO': 0.26120635867118835, 'YES': 0.7315475344657898}},
#  {'test_case': 'EXIST2025',
#   'id': '120289',
#   'value': {'NO': 0.7735520601272583, 'YES': 0.21083582937717438}},
#  {'test_case': 'EXIST2025',
#   'id': '120290',
#   'value': {'NO': 0.19650407135486603, 'YES': 0.7979447245597839}},
#  {'test_case': 'EXIST2025',
#   'id': '120291',
#   'value': {'NO': 0.2910975515842438, 'YES': 0.697182834148407}},
#  {'test_case': 'EXIST2025',
#   'id': '120292',
#   'value': {'NO': 0.2082381397485733, 'YES': 0.775631844997406}},
#  {'test_case': 'EXIST2025',
#   'id': '120293',
#   'value': {'NO': 0.2191265970468521, 'YES': 0.765312910079956}},
#  {'test_case': 'EXIST2025',
#   'id': '120294',
#   'value': {'NO': 0.44572174549102783, 'YES': 0.5798569917678833}},
#  {'test_case': 'EXIST2025',
#   'id': '120295',
#   'value': {'NO': 0.8572450876235962, 'YES': 0.14740748703479767}},
#  {'test_case': 'EXIST2025',
#   'id': '120296',
#   'value': {'NO': 0.3688884377479553, 'YES': 0.6268904805183411}},
#  {'test_case': 'EXIST2025',
#   'id': '120297',
#   'value': {'NO': 0.3900531530380249, 'YES': 0.6345338225364685}},
#  {'test_case': 'EXIST2025',
#   'id': '120298',
#   'value': {'NO': 0.15366855263710022, 'YES': 0.8354844450950623}},
#  {'test_case': 'EXIST2025',
#   'id': '120299',
#   'value': {'NO': 0.8189420700073242, 'YES': 0.17198185622692108}},
#  {'test_case': 'EXIST2025',
#   'id': '120300',
#   'value': {'NO': 0.6864945888519287, 'YES': 0.3063697814941406}},
#  {'test_case': 'EXIST2025',
#   'id': '120301',
#   'value': {'NO': 0.8731424808502197, 'YES': 0.1208333969116211}},
#  {'test_case': 'EXIST2025',
#   'id': '120302',
#   'value': {'NO': 0.8258928060531616, 'YES': 0.17302222549915314}},
#  {'test_case': 'EXIST2025',
#   'id': '120303',
#   'value': {'NO': 0.8476055264472961, 'YES': 0.15094035863876343}},
#  {'test_case': 'EXIST2025',
#   'id': '120304',
#   'value': {'NO': 0.6005893349647522, 'YES': 0.3724428415298462}},
#  {'test_case': 'EXIST2025',
#   'id': '120305',
#   'value': {'NO': 0.7660694122314453, 'YES': 0.2183128446340561}},
#  {'test_case': 'EXIST2025',
#   'id': '120306',
#   'value': {'NO': 0.2087695598602295, 'YES': 0.7856627702713013}},
#  {'test_case': 'EXIST2025',
#   'id': '120307',
#   'value': {'NO': 0.5365631580352783, 'YES': 0.4686564803123474}},
#  {'test_case': 'EXIST2025',
#   'id': '120308',
#   'value': {'NO': 0.6423864364624023, 'YES': 0.3477950096130371}},
#  {'test_case': 'EXIST2025',
#   'id': '120309',
#   'value': {'NO': 0.7227187156677246, 'YES': 0.25669994950294495}},
#  {'test_case': 'EXIST2025',
#   'id': '120310',
#   'value': {'NO': 0.20693355798721313, 'YES': 0.7889692783355713}},
#  {'test_case': 'EXIST2025',
#   'id': '120311',
#   'value': {'NO': 0.1752503365278244, 'YES': 0.8105199933052063}},
#  {'test_case': 'EXIST2025',
#   'id': '120312',
#   'value': {'NO': 0.17044338583946228, 'YES': 0.8297653198242188}},
#  {'test_case': 'EXIST2025',
#   'id': '120313',
#   'value': {'NO': 0.8700567483901978, 'YES': 0.11094304919242859}},
#  {'test_case': 'EXIST2025',
#   'id': '120314',
#   'value': {'NO': 0.2760030925273895, 'YES': 0.7336570620536804}},
#  {'test_case': 'EXIST2025',
#   'id': '120315',
#   'value': {'NO': 0.8442672491073608, 'YES': 0.14716081321239471}},
#  {'test_case': 'EXIST2025',
#   'id': '120316',
#   'value': {'NO': 0.7169695496559143, 'YES': 0.3129644989967346}},
#  {'test_case': 'EXIST2025',
#   'id': '120317',
#   'value': {'NO': 0.20847348868846893, 'YES': 0.7864702939987183}},
#  {'test_case': 'EXIST2025',
#   'id': '120318',
#   'value': {'NO': 0.6633463501930237, 'YES': 0.28185659646987915}},
#  {'test_case': 'EXIST2025',
#   'id': '120319',
#   'value': {'NO': 0.6640281677246094, 'YES': 0.35359397530555725}},
#  {'test_case': 'EXIST2025',
#   'id': '120320',
#   'value': {'NO': 0.3255772888660431, 'YES': 0.6502406001091003}},
#  {'test_case': 'EXIST2025',
#   'id': '120321',
#   'value': {'NO': 0.3220755457878113, 'YES': 0.6920205950737}},
#  {'test_case': 'EXIST2025',
#   'id': '120322',
#   'value': {'NO': 0.7733890414237976, 'YES': 0.21508947014808655}},
#  {'test_case': 'EXIST2025',
#   'id': '120323',
#   'value': {'NO': 0.7063818573951721, 'YES': 0.2705269157886505}},
#  {'test_case': 'EXIST2025',
#   'id': '120324',
#   'value': {'NO': 0.8435387015342712, 'YES': 0.135484978556633}},
#  {'test_case': 'EXIST2025',
#   'id': '120325',
#   'value': {'NO': 0.8504579663276672, 'YES': 0.14414864778518677}},
#  {'test_case': 'EXIST2025',
#   'id': '120326',
#   'value': {'NO': 0.8667603135108948, 'YES': 0.13582848012447357}},
#  {'test_case': 'EXIST2025',
#   'id': '120327',
#   'value': {'NO': 0.8678671717643738, 'YES': 0.12021157890558243}},
#  {'test_case': 'EXIST2025',
#   'id': '120328',
#   'value': {'NO': 0.8428902626037598, 'YES': 0.14567601680755615}},
#  {'test_case': 'EXIST2025',
#   'id': '120329',
#   'value': {'NO': 0.8229999542236328, 'YES': 0.16405797004699707}},
#  {'test_case': 'EXIST2025',
#   'id': '120330',
#   'value': {'NO': 0.6292033791542053, 'YES': 0.3454363942146301}},
#  {'test_case': 'EXIST2025',
#   'id': '120331',
#   'value': {'NO': 0.7960656881332397, 'YES': 0.20146866142749786}},
#  {'test_case': 'EXIST2025',
#   'id': '120332',
#   'value': {'NO': 0.5631456971168518, 'YES': 0.38299039006233215}},
#  {'test_case': 'EXIST2025',
#   'id': '120333',
#   'value': {'NO': 0.41094496846199036, 'YES': 0.6035625338554382}},
#  {'test_case': 'EXIST2025',
#   'id': '120334',
#   'value': {'NO': 0.8433828353881836, 'YES': 0.16531352698802948}},
#  {'test_case': 'EXIST2025',
#   'id': '120335',
#   'value': {'NO': 0.1800117939710617, 'YES': 0.7991645932197571}},
#  {'test_case': 'EXIST2025',
#   'id': '120336',
#   'value': {'NO': 0.17903591692447662, 'YES': 0.812527596950531}},
#  {'test_case': 'EXIST2025',
#   'id': '120337',
#   'value': {'NO': 0.7980507016181946, 'YES': 0.20447459816932678}},
#  {'test_case': 'EXIST2025',
#   'id': '120338',
#   'value': {'NO': 0.24423475563526154, 'YES': 0.7402285933494568}},
#  {'test_case': 'EXIST2025',
#   'id': '120339',
#   'value': {'NO': 0.4964596927165985, 'YES': 0.5538710951805115}},
#  {'test_case': 'EXIST2025',
#   'id': '120340',
#   'value': {'NO': 0.18737468123435974, 'YES': 0.7983630299568176}},
#  {'test_case': 'EXIST2025',
#   'id': '120341',
#   'value': {'NO': 0.8183103799819946, 'YES': 0.16905876994132996}},
#  {'test_case': 'EXIST2025',
#   'id': '120342',
#   'value': {'NO': 0.7138502597808838, 'YES': 0.27379748225212097}},
#  {'test_case': 'EXIST2025',
#   'id': '120343',
#   'value': {'NO': 0.6827302575111389, 'YES': 0.2739631235599518}},
#  {'test_case': 'EXIST2025',
#   'id': '120344',
#   'value': {'NO': 0.8537182211875916, 'YES': 0.14001069962978363}},
#  {'test_case': 'EXIST2025',
#   'id': '120345',
#   'value': {'NO': 0.8613473773002625, 'YES': 0.1409359574317932}},
#  {'test_case': 'EXIST2025',
#   'id': '120346',
#   'value': {'NO': 0.7254744172096252, 'YES': 0.28209298849105835}},
#  {'test_case': 'EXIST2025',
#   'id': '120347',
#   'value': {'NO': 0.8343368768692017, 'YES': 0.14804281294345856}},
#  {'test_case': 'EXIST2025',
#   'id': '120348',
#   'value': {'NO': 0.23196515440940857, 'YES': 0.7648066878318787}},
#  {'test_case': 'EXIST2025',
#   'id': '120349',
#   'value': {'NO': 0.6422690749168396, 'YES': 0.3690541684627533}},
#  {'test_case': 'EXIST2025',
#   'id': '120350',
#   'value': {'NO': 0.7506130933761597, 'YES': 0.2576081156730652}},
#  {'test_case': 'EXIST2025',
#   'id': '120351',
#   'value': {'NO': 0.13414046168327332, 'YES': 0.8548458814620972}},
#  {'test_case': 'EXIST2025',
#   'id': '120352',
#   'value': {'NO': 0.19119679927825928, 'YES': 0.7982127666473389}},
#  {'test_case': 'EXIST2025',
#   'id': '120353',
#   'value': {'NO': 0.14584816992282867, 'YES': 0.8445292711257935}},
#  {'test_case': 'EXIST2025',
#   'id': '120354',
#   'value': {'NO': 0.13771884143352509, 'YES': 0.8532903790473938}},
#  {'test_case': 'EXIST2025',
#   'id': '120355',
#   'value': {'NO': 0.8621843457221985, 'YES': 0.13378044962882996}},
#  {'test_case': 'EXIST2025',
#   'id': '120356',
#   'value': {'NO': 0.505553662776947, 'YES': 0.5029857158660889}},
#  {'test_case': 'EXIST2025',
#   'id': '120357',
#   'value': {'NO': 0.16707928478717804, 'YES': 0.8192644715309143}},
#  {'test_case': 'EXIST2025',
#   'id': '120358',
#   'value': {'NO': 0.15987420082092285, 'YES': 0.8249409198760986}},
#  {'test_case': 'EXIST2025',
#   'id': '120359',
#   'value': {'NO': 0.1593746393918991, 'YES': 0.8261975049972534}},
#  {'test_case': 'EXIST2025',
#   'id': '120360',
#   'value': {'NO': 0.5256854891777039, 'YES': 0.4584721028804779}},
#  {'test_case': 'EXIST2025',
#   'id': '120361',
#   'value': {'NO': 0.16282029449939728, 'YES': 0.8231741189956665}},
#  {'test_case': 'EXIST2025',
#   'id': '120362',
#   'value': {'NO': 0.6095660924911499, 'YES': 0.360232412815094}},
#  {'test_case': 'EXIST2025',
#   'id': '120363',
#   'value': {'NO': 0.8547561764717102, 'YES': 0.1308998465538025}},
#  {'test_case': 'EXIST2025',
#   'id': '120364',
#   'value': {'NO': 0.1980447769165039, 'YES': 0.8067954182624817}},
#  {'test_case': 'EXIST2025',
#   'id': '120365',
#   'value': {'NO': 0.8707607984542847, 'YES': 0.12272101640701294}},
#  {'test_case': 'EXIST2025',
#   'id': '120366',
#   'value': {'NO': 0.16696731746196747, 'YES': 0.8187541365623474}},
#  {'test_case': 'EXIST2025',
#   'id': '120367',
#   'value': {'NO': 0.2919933795928955, 'YES': 0.6949417591094971}},
#  {'test_case': 'EXIST2025',
#   'id': '120368',
#   'value': {'NO': 0.7421346306800842, 'YES': 0.2701584994792938}},
#  {'test_case': 'EXIST2025',
#   'id': '120369',
#   'value': {'NO': 0.4207953214645386, 'YES': 0.6093640327453613}},
#  {'test_case': 'EXIST2025',
#   'id': '120370',
#   'value': {'NO': 0.8488041162490845, 'YES': 0.14950717985630035}},
#  {'test_case': 'EXIST2025',
#   'id': '120371',
#   'value': {'NO': 0.7944466471672058, 'YES': 0.1942194253206253}},
#  {'test_case': 'EXIST2025',
#   'id': '120372',
#   'value': {'NO': 0.8499018549919128, 'YES': 0.1394011229276657}},
#  {'test_case': 'EXIST2025',
#   'id': '120373',
#   'value': {'NO': 0.8718838095664978, 'YES': 0.11971218138933182}},
#  {'test_case': 'EXIST2025',
#   'id': '120374',
#   'value': {'NO': 0.806804358959198, 'YES': 0.20064552128314972}},
#  {'test_case': 'EXIST2025',
#   'id': '120375',
#   'value': {'NO': 0.8543194532394409, 'YES': 0.14505623281002045}},
#  {'test_case': 'EXIST2025',
#   'id': '120376',
#   'value': {'NO': 0.4807398319244385, 'YES': 0.5549795627593994}},
#  {'test_case': 'EXIST2025',
#   'id': '120377',
#   'value': {'NO': 0.8199633359909058, 'YES': 0.17729343473911285}},
#  {'test_case': 'EXIST2025',
#   'id': '120378',
#   'value': {'NO': 0.31894445419311523, 'YES': 0.6757969260215759}},
#  {'test_case': 'EXIST2025',
#   'id': '120379',
#   'value': {'NO': 0.6740099787712097, 'YES': 0.287373811006546}},
#  {'test_case': 'EXIST2025',
#   'id': '120380',
#   'value': {'NO': 0.826790988445282, 'YES': 0.1621914803981781}},
#  {'test_case': 'EXIST2025',
#   'id': '120381',
#   'value': {'NO': 0.8642215728759766, 'YES': 0.12051822990179062}},
#  {'test_case': 'EXIST2025',
#   'id': '120382',
#   'value': {'NO': 0.18347136676311493, 'YES': 0.8088586330413818}},
#  {'test_case': 'EXIST2025',
#   'id': '120383',
#   'value': {'NO': 0.6288172602653503, 'YES': 0.36809512972831726}},
#  {'test_case': 'EXIST2025',
#   'id': '120384',
#   'value': {'NO': 0.22163434326648712, 'YES': 0.754517674446106}},
#  {'test_case': 'EXIST2025',
#   'id': '120385',
#   'value': {'NO': 0.5043103694915771, 'YES': 0.5080024003982544}},
#  {'test_case': 'EXIST2025',
#   'id': '120386',
# ...
#   'id': '120860',
#   'value': {'NO': 0.7716047167778015, 'YES': 0.22288714349269867}},
#  {'test_case': 'EXIST2025',
#   'id': '120861',
#   'value': {'NO': 0.8584295511245728, 'YES': 0.13242246210575104}},
#  {'test_case': 'EXIST2025',
#   'id': '120862',
#   'value': {'NO': 0.8469337821006775, 'YES': 0.1448194831609726}},
#  {'test_case': 'EXIST2025',
#   'id': '120863',
#   'value': {'NO': 0.8810664415359497, 'YES': 0.11341565102338791}},
#  {'test_case': 'EXIST2025',
#   'id': '120864',
#   'value': {'NO': 0.8672428727149963, 'YES': 0.12339770793914795}},
#  {'test_case': 'EXIST2025',
#   'id': '120865',
#   'value': {'NO': 0.8648068308830261, 'YES': 0.1299116164445877}},
#  {'test_case': 'EXIST2025',
#   'id': '120866',
#   'value': {'NO': 0.8451874256134033, 'YES': 0.1545581817626953}},
#  {'test_case': 'EXIST2025',
#   'id': '120867',
#   'value': {'NO': 0.21608971059322357, 'YES': 0.7656628489494324}},
#  {'test_case': 'EXIST2025',
#   'id': '120868',
#   'value': {'NO': 0.1743767261505127, 'YES': 0.8048849105834961}},
#  {'test_case': 'EXIST2025',
#   'id': '120869',
#   'value': {'NO': 0.18030735850334167, 'YES': 0.793699324131012}},
#  {'test_case': 'EXIST2025',
#   'id': '120870',
#   'value': {'NO': 0.16774871945381165, 'YES': 0.8207588195800781}},
#  {'test_case': 'EXIST2025',
#   'id': '120871',
#   'value': {'NO': 0.20186132192611694, 'YES': 0.7913681268692017}},
#  {'test_case': 'EXIST2025',
#   'id': '120872',
#   'value': {'NO': 0.7167364954948425, 'YES': 0.2689906656742096}},
#  {'test_case': 'EXIST2025',
#   'id': '120873',
#   'value': {'NO': 0.4626522660255432, 'YES': 0.4920784533023834}},
#  {'test_case': 'EXIST2025',
#   'id': '120874',
#   'value': {'NO': 0.673642635345459, 'YES': 0.3222403824329376}},
#  {'test_case': 'EXIST2025',
#   'id': '120875',
#   'value': {'NO': 0.20815610885620117, 'YES': 0.7730903029441833}},
#  {'test_case': 'EXIST2025',
#   'id': '120876',
#   'value': {'NO': 0.2400766909122467, 'YES': 0.7383005619049072}},
#  {'test_case': 'EXIST2025',
#   'id': '120877',
#   'value': {'NO': 0.760699450969696, 'YES': 0.22159041464328766}},
#  {'test_case': 'EXIST2025',
#   'id': '120878',
#   'value': {'NO': 0.23775283992290497, 'YES': 0.7516316175460815}},
#  {'test_case': 'EXIST2025',
#   'id': '120879',
#   'value': {'NO': 0.18197402358055115, 'YES': 0.7989693880081177}},
#  {'test_case': 'EXIST2025',
#   'id': '120880',
#   'value': {'NO': 0.815483033657074, 'YES': 0.1957433819770813}},
#  {'test_case': 'EXIST2025',
#   'id': '120881',
#   'value': {'NO': 0.24240249395370483, 'YES': 0.763527512550354}},
#  {'test_case': 'EXIST2025',
#   'id': '120882',
#   'value': {'NO': 0.14629966020584106, 'YES': 0.8411676287651062}},
#  {'test_case': 'EXIST2025',
#   'id': '120883',
#   'value': {'NO': 0.3519618511199951, 'YES': 0.6515911817550659}},
#  {'test_case': 'EXIST2025',
#   'id': '120884',
#   'value': {'NO': 0.13685773313045502, 'YES': 0.8579004406929016}},
#  {'test_case': 'EXIST2025',
#   'id': '120885',
#   'value': {'NO': 0.35361531376838684, 'YES': 0.6212722659111023}},
#  {'test_case': 'EXIST2025',
#   'id': '120886',
#   'value': {'NO': 0.5838074088096619, 'YES': 0.3646022081375122}},
#  {'test_case': 'EXIST2025',
#   'id': '120887',
#   'value': {'NO': 0.16954346001148224, 'YES': 0.8149418234825134}},
#  {'test_case': 'EXIST2025',
#   'id': '120888',
#   'value': {'NO': 0.36450546979904175, 'YES': 0.6576052308082581}},
#  {'test_case': 'EXIST2025',
#   'id': '120889',
#   'value': {'NO': 0.5716368556022644, 'YES': 0.4148801267147064}},
#  {'test_case': 'EXIST2025',
#   'id': '120890',
#   'value': {'NO': 0.4888317584991455, 'YES': 0.46866801381111145}},
#  {'test_case': 'EXIST2025',
#   'id': '120891',
#   'value': {'NO': 0.3059409558773041, 'YES': 0.6727475523948669}},
#  {'test_case': 'EXIST2025',
#   'id': '120892',
#   'value': {'NO': 0.5423089265823364, 'YES': 0.4455200433731079}},
#  {'test_case': 'EXIST2025',
#   'id': '120893',
#   'value': {'NO': 0.27761921286582947, 'YES': 0.7206222414970398}},
#  {'test_case': 'EXIST2025',
#   'id': '120894',
#   'value': {'NO': 0.22600242495536804, 'YES': 0.7591621279716492}},
#  {'test_case': 'EXIST2025',
#   'id': '120895',
#   'value': {'NO': 0.8522717356681824, 'YES': 0.13158084452152252}},
#  {'test_case': 'EXIST2025',
#   'id': '120896',
#   'value': {'NO': 0.8128979802131653, 'YES': 0.1727881282567978}},
#  {'test_case': 'EXIST2025',
#   'id': '120897',
#   'value': {'NO': 0.8095698356628418, 'YES': 0.17443817853927612}},
#  {'test_case': 'EXIST2025',
#   'id': '120898',
#   'value': {'NO': 0.18562033772468567, 'YES': 0.8010823726654053}},
#  {'test_case': 'EXIST2025',
#   'id': '120899',
#   'value': {'NO': 0.47027260065078735, 'YES': 0.5458646416664124}},
#  {'test_case': 'EXIST2025',
#   'id': '120900',
#   'value': {'NO': 0.16189426183700562, 'YES': 0.8246706128120422}},
#  {'test_case': 'EXIST2025',
#   'id': '120901',
#   'value': {'NO': 0.6134886145591736, 'YES': 0.37236008048057556}},
#  {'test_case': 'EXIST2025',
#   'id': '120902',
#   'value': {'NO': 0.8687772154808044, 'YES': 0.1166832372546196}},
#  {'test_case': 'EXIST2025',
#   'id': '120903',
#   'value': {'NO': 0.8573933839797974, 'YES': 0.1308266520500183}},
#  {'test_case': 'EXIST2025',
#   'id': '120904',
#   'value': {'NO': 0.845312237739563, 'YES': 0.14654043316841125}},
#  {'test_case': 'EXIST2025',
#   'id': '120905',
#   'value': {'NO': 0.8260061740875244, 'YES': 0.1632004827260971}},
#  {'test_case': 'EXIST2025',
#   'id': '120906',
#   'value': {'NO': 0.22418895363807678, 'YES': 0.7566151022911072}},
#  {'test_case': 'EXIST2025',
#   'id': '120907',
#   'value': {'NO': 0.8638593554496765, 'YES': 0.12599505484104156}},
#  {'test_case': 'EXIST2025',
#   'id': '120908',
#   'value': {'NO': 0.8260470032691956, 'YES': 0.16095203161239624}},
#  {'test_case': 'EXIST2025',
#   'id': '120909',
#   'value': {'NO': 0.6772670745849609, 'YES': 0.33389708399772644}},
#  {'test_case': 'EXIST2025',
#   'id': '120910',
#   'value': {'NO': 0.840053915977478, 'YES': 0.1647215485572815}},
#  {'test_case': 'EXIST2025',
#   'id': '120911',
#   'value': {'NO': 0.13977771997451782, 'YES': 0.8462130427360535}},
#  {'test_case': 'EXIST2025',
#   'id': '120912',
#   'value': {'NO': 0.18918251991271973, 'YES': 0.8086407780647278}},
#  {'test_case': 'EXIST2025',
#   'id': '120913',
#   'value': {'NO': 0.2842051386833191, 'YES': 0.7041962146759033}},
#  {'test_case': 'EXIST2025',
#   'id': '120914',
#   'value': {'NO': 0.15531593561172485, 'YES': 0.8337001800537109}},
#  {'test_case': 'EXIST2025',
#   'id': '120915',
#   'value': {'NO': 0.314721941947937, 'YES': 0.6737375855445862}},
#  {'test_case': 'EXIST2025',
#   'id': '120916',
#   'value': {'NO': 0.17937228083610535, 'YES': 0.8029543161392212}},
#  {'test_case': 'EXIST2025',
#   'id': '120917',
#   'value': {'NO': 0.21455056965351105, 'YES': 0.7583991289138794}},
#  {'test_case': 'EXIST2025',
#   'id': '120918',
#   'value': {'NO': 0.7449401617050171, 'YES': 0.2491723597049713}},
#  {'test_case': 'EXIST2025',
#   'id': '120919',
#   'value': {'NO': 0.2490479052066803, 'YES': 0.7411015629768372}},
#  {'test_case': 'EXIST2025',
#   'id': '120920',
#   'value': {'NO': 0.7880226373672485, 'YES': 0.19929392635822296}},
#  {'test_case': 'EXIST2025',
#   'id': '120921',
#   'value': {'NO': 0.7808007597923279, 'YES': 0.20686759054660797}},
#  {'test_case': 'EXIST2025',
#   'id': '120922',
#   'value': {'NO': 0.2677317261695862, 'YES': 0.7221272587776184}},
#  {'test_case': 'EXIST2025',
#   'id': '120923',
#   'value': {'NO': 0.7850171327590942, 'YES': 0.20011374354362488}},
#  {'test_case': 'EXIST2025',
#   'id': '120924',
#   'value': {'NO': 0.6600499749183655, 'YES': 0.35178565979003906}},
#  {'test_case': 'EXIST2025',
#   'id': '120925',
#   'value': {'NO': 0.7306687831878662, 'YES': 0.2745712101459503}},
#  {'test_case': 'EXIST2025',
#   'id': '120926',
#   'value': {'NO': 0.8554169535636902, 'YES': 0.13927778601646423}},
#  {'test_case': 'EXIST2025',
#   'id': '120927',
#   'value': {'NO': 0.39157983660697937, 'YES': 0.6400598287582397}},
#  {'test_case': 'EXIST2025',
#   'id': '120928',
#   'value': {'NO': 0.8556252121925354, 'YES': 0.1357032060623169}},
#  {'test_case': 'EXIST2025',
#   'id': '120929',
#   'value': {'NO': 0.12270940095186234, 'YES': 0.868143618106842}},
#  {'test_case': 'EXIST2025',
#   'id': '120930',
#   'value': {'NO': 0.1314135044813156, 'YES': 0.8546280264854431}},
#  {'test_case': 'EXIST2025',
#   'id': '120931',
#   'value': {'NO': 0.7722703218460083, 'YES': 0.23371678590774536}},
#  {'test_case': 'EXIST2025',
#   'id': '120932',
#   'value': {'NO': 0.8071414232254028, 'YES': 0.1911911517381668}},
#  {'test_case': 'EXIST2025',
#   'id': '120933',
#   'value': {'NO': 0.19791053235530853, 'YES': 0.7856080532073975}},
#  {'test_case': 'EXIST2025',
#   'id': '120934',
#   'value': {'NO': 0.853586733341217, 'YES': 0.1541331559419632}},
#  {'test_case': 'EXIST2025',
#   'id': '120935',
#   'value': {'NO': 0.16610804200172424, 'YES': 0.8272061944007874}},
#  {'test_case': 'EXIST2025',
#   'id': '120936',
#   'value': {'NO': 0.152350053191185, 'YES': 0.83450847864151}},
#  {'test_case': 'EXIST2025',
#   'id': '120937',
#   'value': {'NO': 0.6075500845909119, 'YES': 0.4113241732120514}},
#  {'test_case': 'EXIST2025',
#   'id': '120938',
#   'value': {'NO': 0.7592923641204834, 'YES': 0.24871975183486938}},
#  {'test_case': 'EXIST2025',
#   'id': '120939',
#   'value': {'NO': 0.1861344277858734, 'YES': 0.7987577319145203}},
#  {'test_case': 'EXIST2025',
#   'id': '120940',
#   'value': {'NO': 0.19494245946407318, 'YES': 0.7868597507476807}},
#  {'test_case': 'EXIST2025',
#   'id': '120941',
#   'value': {'NO': 0.7320311665534973, 'YES': 0.25374695658683777}},
#  {'test_case': 'EXIST2025',
#   'id': '120942',
#   'value': {'NO': 0.2597290873527527, 'YES': 0.7474026083946228}},
#  {'test_case': 'EXIST2025',
#   'id': '120943',
#   'value': {'NO': 0.14089150726795197, 'YES': 0.8497620820999146}},
#  {'test_case': 'EXIST2025',
#   'id': '120944',
#   'value': {'NO': 0.1472146213054657, 'YES': 0.8450818061828613}},
#  {'test_case': 'EXIST2025',
#   'id': '120945',
#   'value': {'NO': 0.8461393117904663, 'YES': 0.15591716766357422}},
#  {'test_case': 'EXIST2025',
#   'id': '120946',
#   'value': {'NO': 0.38267090916633606, 'YES': 0.6440303921699524}},
#  {'test_case': 'EXIST2025',
#   'id': '120947',
#   'value': {'NO': 0.7187384963035583, 'YES': 0.2714480459690094}},
#  {'test_case': 'EXIST2025',
#   'id': '120948',
#   'value': {'NO': 0.8257757425308228, 'YES': 0.15855291485786438}},
#  {'test_case': 'EXIST2025',
#   'id': '120949',
#   'value': {'NO': 0.2753186821937561, 'YES': 0.7113174796104431}},
#  {'test_case': 'EXIST2025',
#   'id': '120950',
#   'value': {'NO': 0.17167851328849792, 'YES': 0.8159133195877075}},
#  {'test_case': 'EXIST2025',
#   'id': '120951',
#   'value': {'NO': 0.8537794947624207, 'YES': 0.13279111683368683}},
#  {'test_case': 'EXIST2025',
#   'id': '120952',
#   'value': {'NO': 0.19547301530838013, 'YES': 0.7801466584205627}},
#  {'test_case': 'EXIST2025',
#   'id': '120953',
#   'value': {'NO': 0.605482816696167, 'YES': 0.36253753304481506}},
#  {'test_case': 'EXIST2025',
#   'id': '120954',
#   'value': {'NO': 0.21565844118595123, 'YES': 0.7935282588005066}},
#  {'test_case': 'EXIST2025',
#   'id': '120955',
#   'value': {'NO': 0.18592777848243713, 'YES': 0.8163896203041077}},
#  {'test_case': 'EXIST2025',
#   'id': '120956',
#   'value': {'NO': 0.22936367988586426, 'YES': 0.7619384527206421}},
#  {'test_case': 'EXIST2025',
#   'id': '120957',
#   'value': {'NO': 0.15646947920322418, 'YES': 0.8308993577957153}},
#  {'test_case': 'EXIST2025',
#   'id': '120958',
#   'value': {'NO': 0.20448653399944305, 'YES': 0.7935192584991455}},
#  {'test_case': 'EXIST2025',
#   'id': '120959',
#   'value': {'NO': 0.17709152400493622, 'YES': 0.8127278089523315}},
#  {'test_case': 'EXIST2025',
#   'id': '120960',
#   'value': {'NO': 0.13877248764038086, 'YES': 0.8493980765342712}},
#  {'test_case': 'EXIST2025',
#   'id': '120961',
#   'value': {'NO': 0.17766183614730835, 'YES': 0.8160302042961121}},
#  {'test_case': 'EXIST2025',
#   'id': '120962',
#   'value': {'NO': 0.1704394519329071, 'YES': 0.8208341598510742}},
#  {'test_case': 'EXIST2025',
#   'id': '120963',
#   'value': {'NO': 0.2177417278289795, 'YES': 0.7753157019615173}},
#  {'test_case': 'EXIST2025',
#   'id': '120964',
#   'value': {'NO': 0.4629019796848297, 'YES': 0.5876572132110596}},
#  {'test_case': 'EXIST2025',
#   'id': '120965',
#   'value': {'NO': 0.7850721478462219, 'YES': 0.20747902989387512}},
#  {'test_case': 'EXIST2025',
#   'id': '120966',
#   'value': {'NO': 0.4554155170917511, 'YES': 0.5581437349319458}},
#  {'test_case': 'EXIST2025',
#   'id': '120967',
#   'value': {'NO': 0.30550867319107056, 'YES': 0.7103209495544434}},
#  {'test_case': 'EXIST2025',
#   'id': '120968',
#   'value': {'NO': 0.24363142251968384, 'YES': 0.7224302887916565}},
#  {'test_case': 'EXIST2025',
#   'id': '120969',
#   'value': {'NO': 0.24370166659355164, 'YES': 0.7556805610656738}},
#  {'test_case': 'EXIST2025',
#   'id': '120970',
#   'value': {'NO': 0.7035440802574158, 'YES': 0.2837440073490143}},
#  {'test_case': 'EXIST2025',
#   'id': '120971',
#   'value': {'NO': 0.1866903454065323, 'YES': 0.8061907291412354}},
#  {'test_case': 'EXIST2025',
#   'id': '120972',
#   'value': {'NO': 0.18916358053684235, 'YES': 0.7925292253494263}},
#  {'test_case': 'EXIST2025',
#   'id': '120973',
#   'value': {'NO': 0.188688725233078, 'YES': 0.7937086820602417}},
#  {'test_case': 'EXIST2025',
#   'id': '120974',
#   'value': {'NO': 0.8398357629776001, 'YES': 0.1605311930179596}},
#  {'test_case': 'EXIST2025',
#   'id': '120975',
#   'value': {'NO': 0.4750572741031647, 'YES': 0.5520156621932983}},
#  {'test_case': 'EXIST2025',
#   'id': '120976',
#   'value': {'NO': 0.1784648299217224, 'YES': 0.8153960704803467}},
#  {'test_case': 'EXIST2025',
#   'id': '120977',
#   'value': {'NO': 0.40007516741752625, 'YES': 0.638155996799469}},
#  {'test_case': 'EXIST2025',
#   'id': '120978',
#   'value': {'NO': 0.5526425242424011, 'YES': 0.4128529131412506}},
#  {'test_case': 'EXIST2025',
#   'id': '120979',
#   'value': {'NO': 0.7903331518173218, 'YES': 0.1959422081708908}},
#  {'test_case': 'EXIST2025',
#   'id': '120980',
#   'value': {'NO': 0.1730910837650299, 'YES': 0.8235985040664673}},
#  {'test_case': 'EXIST2025',
#   'id': '120981',
#   'value': {'NO': 0.6818602085113525, 'YES': 0.3148166537284851}},
#  {'test_case': 'EXIST2025',
#   'id': '120982',
#   'value': {'NO': 0.5517897605895996, 'YES': 0.5007237792015076}},
#  {'test_case': 'EXIST2025',
#   'id': '120983',
#   'value': {'NO': 0.2898213863372803, 'YES': 0.7258071899414062}},
#  {'test_case': 'EXIST2025',
#   'id': '120984',
#   'value': {'NO': 0.28655317425727844, 'YES': 0.7220398187637329}},
#  {'test_case': 'EXIST2025',
#   'id': '120985',
#   'value': {'NO': 0.5850659012794495, 'YES': 0.41613808274269104}},
#  {'test_case': 'EXIST2025',
#   'id': '120986',
#   'value': {'NO': 0.32621797919273376, 'YES': 0.6859295964241028}},
#  {'test_case': 'EXIST2025',
#   'id': '120987',
#   'value': {'NO': 0.795950174331665, 'YES': 0.1935855895280838}},
#  {'test_case': 'EXIST2025',
#   'id': '120988',
#   'value': {'NO': 0.7253779172897339, 'YES': 0.27951136231422424}},
#  {'test_case': 'EXIST2025',
#   'id': '120989',
#   'value': {'NO': 0.4956764280796051, 'YES': 0.47208157181739807}},
#  {'test_case': 'EXIST2025',
#   'id': '120990',
#   'value': {'NO': 0.8547016978263855, 'YES': 0.12502895295619965}},
#  {'test_case': 'EXIST2025',
#   'id': '120991',
#   'value': {'NO': 0.7885770797729492, 'YES': 0.1769377887248993}},
#  {'test_case': 'EXIST2025',
#   'id': '120992',
#   'value': {'NO': 0.792712390422821, 'YES': 0.19189079105854034}},
#  {'test_case': 'EXIST2025',
#   'id': '120993',
#   'value': {'NO': 0.6377458572387695, 'YES': 0.3829592764377594}},
#  {'test_case': 'EXIST2025',
#   'id': '120994',
#   'value': {'NO': 0.6120604276657104, 'YES': 0.38879647850990295}},
#  {'test_case': 'EXIST2025',
#   'id': '120995',
#   'value': {'NO': 0.8393533229827881, 'YES': 0.14141550660133362}},
#  {'test_case': 'EXIST2025',
#   'id': '120996',
#   'value': {'NO': 0.8474293947219849, 'YES': 0.14998821914196014}},
#  {'test_case': 'EXIST2025',
#   'id': '120997',
#   'value': {'NO': 0.1503656506538391, 'YES': 0.8406667113304138}},
#  {'test_case': 'EXIST2025',
#   'id': '120998',
#   'value': {'NO': 0.7417540550231934, 'YES': 0.24292007088661194}},
#  {'test_case': 'EXIST2025',
#   'id': '120999',
#   'value': {'NO': 0.7973195910453796, 'YES': 0.20158448815345764}},
#  {'test_case': 'EXIST2025',
#   'id': '121000',
#   'value': {'NO': 0.14433184266090393, 'YES': 0.8453894257545471}},
#  ...]

# %%
#liberate GPU RAM
import torch
torch.cuda.empty_cache()

# %%
bert2 = Test(soft=True, model_name="hate-speech-CNERG/bert-base-uncased-hatexplain", label_name="label2")
bert2.train(epochs=3)
bert2.build_submission(task_name="task3_2",run=2)
# Out:
# Map:   0%|          | 0/2145 [00:00<?, ? examples/s]
# Map:   0%|          | 0/379 [00:00<?, ? examples/s]
# <ipython-input-4-54a9ba2e44c6>:136: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   self.trainer = Trainer(
#     <div>
#
#       <progress value='807' max='807' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [807/807 04:06, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mae</th>
#       <th>Logloss</th>
#       <th>F1 Micro</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.550013</td>
#       <td>0.322967</td>
#       <td>0.551320</td>
#       <td>0.716799</td>
#       <td>0.233436</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.537600</td>
#       <td>0.532096</td>
#       <td>0.299052</td>
#       <td>0.532928</td>
#       <td>0.737907</td>
#       <td>0.388270</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.537600</td>
#       <td>0.543280</td>
#       <td>0.291516</td>
#       <td>0.544458</td>
#       <td>0.737027</td>
#       <td>0.451699</td>
#     </tr>
#   </tbody>
# </table><p>
# Submission saved to task3_2_soft_ScalaR_2.json
# [{'test_case': 'EXIST2025',
#   'id': '120001',
#   'value': {'NO': 0.7327743172645569,
#    'DIRECT': 0.33858272433280945,
#    'JUDGEMENTAL': 0.037225548177957535}},
#  {'test_case': 'EXIST2025',
#   'id': '120002',
#   'value': {'NO': 0.7137416005134583,
#    'DIRECT': 0.22379235923290253,
#    'JUDGEMENTAL': 0.042803045362234116}},
#  {'test_case': 'EXIST2025',
#   'id': '120003',
#   'value': {'NO': 0.5235983729362488,
#    'DIRECT': 0.41495561599731445,
#    'JUDGEMENTAL': 0.06807385385036469}},
#  {'test_case': 'EXIST2025',
#   'id': '120004',
#   'value': {'NO': 0.3096788823604584,
#    'DIRECT': 0.5201644897460938,
#    'JUDGEMENTAL': 0.13389261066913605}},
#  {'test_case': 'EXIST2025',
#   'id': '120005',
#   'value': {'NO': 0.5652806162834167,
#    'DIRECT': 0.31144458055496216,
#    'JUDGEMENTAL': 0.06545636802911758}},
#  {'test_case': 'EXIST2025',
#   'id': '120006',
#   'value': {'NO': 0.7175052165985107,
#    'DIRECT': 0.2622414529323578,
#    'JUDGEMENTAL': 0.04356658086180687}},
#  {'test_case': 'EXIST2025',
#   'id': '120007',
#   'value': {'NO': 0.07741906493902206,
#    'DIRECT': 0.6743115782737732,
#    'JUDGEMENTAL': 0.32124200463294983}},
#  {'test_case': 'EXIST2025',
#   'id': '120008',
#   'value': {'NO': 0.10470985621213913,
#    'DIRECT': 0.7204477190971375,
#    'JUDGEMENTAL': 0.2830829620361328}},
#  {'test_case': 'EXIST2025',
#   'id': '120009',
#   'value': {'NO': 0.41193389892578125,
#    'DIRECT': 0.48566848039627075,
#    'JUDGEMENTAL': 0.11040236055850983}},
#  {'test_case': 'EXIST2025',
#   'id': '120010',
#   'value': {'NO': 0.31660550832748413,
#    'DIRECT': 0.5251437425613403,
#    'JUDGEMENTAL': 0.13464201986789703}},
#  {'test_case': 'EXIST2025',
#   'id': '120011',
#   'value': {'NO': 0.23870849609375,
#    'DIRECT': 0.654202938079834,
#    'JUDGEMENTAL': 0.1787874698638916}},
#  {'test_case': 'EXIST2025',
#   'id': '120012',
#   'value': {'NO': 0.4412105977535248,
#    'DIRECT': 0.27560514211654663,
#    'JUDGEMENTAL': 0.1613929271697998}},
#  {'test_case': 'EXIST2025',
#   'id': '120013',
#   'value': {'NO': 0.3226909935474396,
#    'DIRECT': 0.5788884162902832,
#    'JUDGEMENTAL': 0.09775424748659134}},
#  {'test_case': 'EXIST2025',
#   'id': '120014',
#   'value': {'NO': 0.5668229460716248,
#    'DIRECT': 0.3258253037929535,
#    'JUDGEMENTAL': 0.06445809453725815}},
#  {'test_case': 'EXIST2025',
#   'id': '120015',
#   'value': {'NO': 0.7128666639328003,
#    'DIRECT': 0.2277003824710846,
#    'JUDGEMENTAL': 0.03597838431596756}},
#  {'test_case': 'EXIST2025',
#   'id': '120016',
#   'value': {'NO': 0.0801575779914856,
#    'DIRECT': 0.5842541456222534,
#    'JUDGEMENTAL': 0.3708898425102234}},
#  {'test_case': 'EXIST2025',
#   'id': '120017',
#   'value': {'NO': 0.702506422996521,
#    'DIRECT': 0.1650633066892624,
#    'JUDGEMENTAL': 0.054295338690280914}},
#  {'test_case': 'EXIST2025',
#   'id': '120018',
#   'value': {'NO': 0.7827799320220947,
#    'DIRECT': 0.2507803440093994,
#    'JUDGEMENTAL': 0.025239305570721626}},
#  {'test_case': 'EXIST2025',
#   'id': '120019',
#   'value': {'NO': 0.9293628931045532,
#    'DIRECT': 0.08133737742900848,
#    'JUDGEMENTAL': 0.04006273299455643}},
#  {'test_case': 'EXIST2025',
#   'id': '120020',
#   'value': {'NO': 0.29756399989128113,
#    'DIRECT': 0.6800438165664673,
#    'JUDGEMENTAL': 0.07945021241903305}},
#  {'test_case': 'EXIST2025',
#   'id': '120021',
#   'value': {'NO': 0.622624933719635,
#    'DIRECT': 0.32553794980049133,
#    'JUDGEMENTAL': 0.04788748919963837}},
#  {'test_case': 'EXIST2025',
#   'id': '120022',
#   'value': {'NO': 0.08380378037691116,
#    'DIRECT': 0.6082448959350586,
#    'JUDGEMENTAL': 0.3910275995731354}},
#  {'test_case': 'EXIST2025',
#   'id': '120023',
#   'value': {'NO': 0.4377279579639435,
#    'DIRECT': 0.4454179108142853,
#    'JUDGEMENTAL': 0.0940491333603859}},
#  {'test_case': 'EXIST2025',
#   'id': '120024',
#   'value': {'NO': 0.637012243270874,
#    'DIRECT': 0.3103521764278412,
#    'JUDGEMENTAL': 0.06037325784564018}},
#  {'test_case': 'EXIST2025',
#   'id': '120025',
#   'value': {'NO': 0.57675701379776,
#    'DIRECT': 0.49200543761253357,
#    'JUDGEMENTAL': 0.062246017158031464}},
#  {'test_case': 'EXIST2025',
#   'id': '120026',
#   'value': {'NO': 0.6039032340049744,
#    'DIRECT': 0.38124778866767883,
#    'JUDGEMENTAL': 0.05446900799870491}},
#  {'test_case': 'EXIST2025',
#   'id': '120027',
#   'value': {'NO': 0.5483019351959229,
#    'DIRECT': 0.6090796589851379,
#    'JUDGEMENTAL': 0.04595037177205086}},
#  {'test_case': 'EXIST2025',
#   'id': '120028',
#   'value': {'NO': 0.6753739714622498,
#    'DIRECT': 0.31096071004867554,
#    'JUDGEMENTAL': 0.058130551129579544}},
#  {'test_case': 'EXIST2025',
#   'id': '120029',
#   'value': {'NO': 0.44196024537086487,
#    'DIRECT': 0.340807169675827,
#    'JUDGEMENTAL': 0.13997112214565277}},
#  {'test_case': 'EXIST2025',
#   'id': '120030',
#   'value': {'NO': 0.44888409972190857,
#    'DIRECT': 0.30550867319107056,
#    'JUDGEMENTAL': 0.11194147914648056}},
#  {'test_case': 'EXIST2025',
#   'id': '120031',
#   'value': {'NO': 0.1869489848613739,
#    'DIRECT': 0.677047610282898,
#    'JUDGEMENTAL': 0.24625101685523987}},
#  {'test_case': 'EXIST2025',
#   'id': '120032',
#   'value': {'NO': 0.8587213754653931,
#    'DIRECT': 0.16136617958545685,
#    'JUDGEMENTAL': 0.03878479450941086}},
#  {'test_case': 'EXIST2025',
#   'id': '120033',
#   'value': {'NO': 0.4980672597885132,
#    'DIRECT': 0.5756310224533081,
#    'JUDGEMENTAL': 0.042765211313962936}},
#  {'test_case': 'EXIST2025',
#   'id': '120034',
#   'value': {'NO': 0.26593974232673645,
#    'DIRECT': 0.4424651265144348,
#    'JUDGEMENTAL': 0.25531822443008423}},
#  {'test_case': 'EXIST2025',
#   'id': '120035',
#   'value': {'NO': 0.31087422370910645,
#    'DIRECT': 0.638822078704834,
#    'JUDGEMENTAL': 0.11057722568511963}},
#  {'test_case': 'EXIST2025',
#   'id': '120036',
#   'value': {'NO': 0.7143306136131287,
#    'DIRECT': 0.261355459690094,
#    'JUDGEMENTAL': 0.02723386138677597}},
#  {'test_case': 'EXIST2025',
#   'id': '120037',
#   'value': {'NO': 0.19961532950401306,
#    'DIRECT': 0.7045595049858093,
#    'JUDGEMENTAL': 0.23064741492271423}},
#  {'test_case': 'EXIST2025',
#   'id': '120038',
#   'value': {'NO': 0.8037670254707336,
#    'DIRECT': 0.13357751071453094,
#    'JUDGEMENTAL': 0.04614624008536339}},
#  {'test_case': 'EXIST2025',
#   'id': '120039',
#   'value': {'NO': 0.30749115347862244,
#    'DIRECT': 0.4095612168312073,
#    'JUDGEMENTAL': 0.3147132396697998}},
#  {'test_case': 'EXIST2025',
#   'id': '120040',
#   'value': {'NO': 0.17305779457092285,
#    'DIRECT': 0.6710271239280701,
#    'JUDGEMENTAL': 0.1588614135980606}},
#  {'test_case': 'EXIST2025',
#   'id': '120041',
#   'value': {'NO': 0.8971361517906189,
#    'DIRECT': 0.08320527523756027,
#    'JUDGEMENTAL': 0.06298921257257462}},
#  {'test_case': 'EXIST2025',
#   'id': '120042',
#   'value': {'NO': 0.10474865883588791,
#    'DIRECT': 0.7518117427825928,
#    'JUDGEMENTAL': 0.31437936425209045}},
#  {'test_case': 'EXIST2025',
#   'id': '120043',
#   'value': {'NO': 0.2771555483341217,
#    'DIRECT': 0.530372679233551,
#    'JUDGEMENTAL': 0.26377129554748535}},
#  {'test_case': 'EXIST2025',
#   'id': '120044',
#   'value': {'NO': 0.3055800199508667,
#    'DIRECT': 0.8059579133987427,
#    'JUDGEMENTAL': 0.14006265997886658}},
#  {'test_case': 'EXIST2025',
#   'id': '120045',
#   'value': {'NO': 0.07035976648330688,
#    'DIRECT': 0.5826879739761353,
#    'JUDGEMENTAL': 0.4513651132583618}},
#  {'test_case': 'EXIST2025',
#   'id': '120046',
#   'value': {'NO': 0.7375059723854065,
#    'DIRECT': 0.1817937046289444,
#    'JUDGEMENTAL': 0.038504719734191895}},
#  {'test_case': 'EXIST2025',
#   'id': '120047',
#   'value': {'NO': 0.11303823441267014,
#    'DIRECT': 0.6918433904647827,
#    'JUDGEMENTAL': 0.27471718192100525}},
#  {'test_case': 'EXIST2025',
#   'id': '120048',
#   'value': {'NO': 0.26721125841140747,
#    'DIRECT': 0.3465699553489685,
#    'JUDGEMENTAL': 0.29474207758903503}},
#  {'test_case': 'EXIST2025',
#   'id': '120049',
#   'value': {'NO': 0.5167919397354126,
#    'DIRECT': 0.1916486918926239,
#    'JUDGEMENTAL': 0.14263927936553955}},
#  {'test_case': 'EXIST2025',
#   'id': '120050',
#   'value': {'NO': 0.1894034743309021,
#    'DIRECT': 0.5356937646865845,
#    'JUDGEMENTAL': 0.2568969428539276}},
#  {'test_case': 'EXIST2025',
#   'id': '120051',
#   'value': {'NO': 0.2048964500427246,
#    'DIRECT': 0.5002040266990662,
#    'JUDGEMENTAL': 0.2651523947715759}},
#  {'test_case': 'EXIST2025',
#   'id': '120052',
#   'value': {'NO': 0.90913325548172,
#    'DIRECT': 0.09925735741853714,
#    'JUDGEMENTAL': 0.03663697838783264}},
#  {'test_case': 'EXIST2025',
#   'id': '120053',
#   'value': {'NO': 0.6193299293518066,
#    'DIRECT': 0.25095880031585693,
#    'JUDGEMENTAL': 0.15916676819324493}},
#  {'test_case': 'EXIST2025',
#   'id': '120054',
#   'value': {'NO': 0.9385641813278198,
#    'DIRECT': 0.058750540018081665,
#    'JUDGEMENTAL': 0.0585852675139904}},
#  {'test_case': 'EXIST2025',
#   'id': '120055',
#   'value': {'NO': 0.42634329199790955,
#    'DIRECT': 0.3121807873249054,
#    'JUDGEMENTAL': 0.22695192694664001}},
#  {'test_case': 'EXIST2025',
#   'id': '120056',
#   'value': {'NO': 0.0791589692234993,
#    'DIRECT': 0.6114661693572998,
#    'JUDGEMENTAL': 0.42077383399009705}},
#  {'test_case': 'EXIST2025',
#   'id': '120057',
#   'value': {'NO': 0.0719246119260788,
#    'DIRECT': 0.4668634831905365,
#    'JUDGEMENTAL': 0.6150320172309875}},
#  {'test_case': 'EXIST2025',
#   'id': '120058',
#   'value': {'NO': 0.1173568069934845,
#    'DIRECT': 0.38152018189430237,
#    'JUDGEMENTAL': 0.3900021016597748}},
#  {'test_case': 'EXIST2025',
#   'id': '120059',
#   'value': {'NO': 0.5141641497612,
#    'DIRECT': 0.2408302277326584,
#    'JUDGEMENTAL': 0.16618451476097107}},
#  {'test_case': 'EXIST2025',
#   'id': '120060',
#   'value': {'NO': 0.5185800790786743,
#    'DIRECT': 0.2353915125131607,
#    'JUDGEMENTAL': 0.17543195188045502}},
#  {'test_case': 'EXIST2025',
#   'id': '120061',
#   'value': {'NO': 0.11189763993024826,
#    'DIRECT': 0.4256649315357208,
#    'JUDGEMENTAL': 0.4800724387168884}},
#  {'test_case': 'EXIST2025',
#   'id': '120062',
#   'value': {'NO': 0.21287043392658234,
#    'DIRECT': 0.26440414786338806,
#    'JUDGEMENTAL': 0.5229669213294983}},
#  {'test_case': 'EXIST2025',
#   'id': '120063',
#   'value': {'NO': 0.19732865691184998,
#    'DIRECT': 0.4797672629356384,
#    'JUDGEMENTAL': 0.25199976563453674}},
#  {'test_case': 'EXIST2025',
#   'id': '120064',
#   'value': {'NO': 0.3027110993862152,
#    'DIRECT': 0.34965622425079346,
#    'JUDGEMENTAL': 0.30241337418556213}},
#  {'test_case': 'EXIST2025',
#   'id': '120065',
#   'value': {'NO': 0.2585788667201996,
#    'DIRECT': 0.6974486112594604,
#    'JUDGEMENTAL': 0.11951486766338348}},
#  {'test_case': 'EXIST2025',
#   'id': '120066',
#   'value': {'NO': 0.10885026305913925,
#    'DIRECT': 0.7261461019515991,
#    'JUDGEMENTAL': 0.3267354667186737}},
#  {'test_case': 'EXIST2025',
#   'id': '120067',
#   'value': {'NO': 0.2524493932723999,
#    'DIRECT': 0.5469085574150085,
#    'JUDGEMENTAL': 0.19270768761634827}},
#  {'test_case': 'EXIST2025',
#   'id': '120068',
#   'value': {'NO': 0.4157397150993347,
#    'DIRECT': 0.2722683548927307,
#    'JUDGEMENTAL': 0.14604036509990692}},
#  {'test_case': 'EXIST2025',
#   'id': '120069',
#   'value': {'NO': 0.08522538840770721,
#    'DIRECT': 0.5813108682632446,
#    'JUDGEMENTAL': 0.43556126952171326}},
#  {'test_case': 'EXIST2025',
#   'id': '120070',
#   'value': {'NO': 0.1669936180114746,
#    'DIRECT': 0.7310166954994202,
#    'JUDGEMENTAL': 0.24832679331302643}},
#  {'test_case': 'EXIST2025',
#   'id': '120071',
#   'value': {'NO': 0.14395037293434143,
#    'DIRECT': 0.31507447361946106,
#    'JUDGEMENTAL': 0.4483242630958557}},
#  {'test_case': 'EXIST2025',
#   'id': '120072',
#   'value': {'NO': 0.7026486396789551,
#    'DIRECT': 0.27335041761398315,
#    'JUDGEMENTAL': 0.04702536389231682}},
#  {'test_case': 'EXIST2025',
#   'id': '120073',
#   'value': {'NO': 0.9022451639175415,
#    'DIRECT': 0.11055362224578857,
#    'JUDGEMENTAL': 0.03231881931424141}},
#  {'test_case': 'EXIST2025',
#   'id': '120074',
#   'value': {'NO': 0.2886166572570801,
#    'DIRECT': 0.3916409909725189,
#    'JUDGEMENTAL': 0.20203955471515656}},
#  {'test_case': 'EXIST2025',
#   'id': '120075',
#   'value': {'NO': 0.8913812637329102,
#    'DIRECT': 0.06372717022895813,
#    'JUDGEMENTAL': 0.05267879366874695}},
#  {'test_case': 'EXIST2025',
#   'id': '120076',
#   'value': {'NO': 0.4011116325855255,
#    'DIRECT': 0.3173535168170929,
#    'JUDGEMENTAL': 0.14382314682006836}},
#  {'test_case': 'EXIST2025',
#   'id': '120077',
#   'value': {'NO': 0.4811280369758606,
#    'DIRECT': 0.16987097263336182,
#    'JUDGEMENTAL': 0.41261401772499084}},
#  {'test_case': 'EXIST2025',
#   'id': '120078',
#   'value': {'NO': 0.22932520508766174,
#    'DIRECT': 0.30851271748542786,
#    'JUDGEMENTAL': 0.39916959404945374}},
#  {'test_case': 'EXIST2025',
#   'id': '120079',
#   'value': {'NO': 0.3279666006565094,
#    'DIRECT': 0.23300576210021973,
#    'JUDGEMENTAL': 0.31267669796943665}},
#  {'test_case': 'EXIST2025',
#   'id': '120080',
#   'value': {'NO': 0.18912431597709656,
#    'DIRECT': 0.22571200132369995,
#    'JUDGEMENTAL': 0.6656051278114319}},
#  {'test_case': 'EXIST2025',
#   'id': '120081',
#   'value': {'NO': 0.6359717845916748,
#    'DIRECT': 0.17770282924175262,
#    'JUDGEMENTAL': 0.07256726175546646}},
#  {'test_case': 'EXIST2025',
#   'id': '120082',
#   'value': {'NO': 0.44695404171943665,
#    'DIRECT': 0.2342512160539627,
#    'JUDGEMENTAL': 0.22174446284770966}},
#  {'test_case': 'EXIST2025',
#   'id': '120083',
#   'value': {'NO': 0.24185441434383392,
#    'DIRECT': 0.41496849060058594,
#    'JUDGEMENTAL': 0.33775392174720764}},
#  {'test_case': 'EXIST2025',
#   'id': '120084',
#   'value': {'NO': 0.4587327837944031,
#    'DIRECT': 0.5337863564491272,
#    'JUDGEMENTAL': 0.04907085746526718}},
#  {'test_case': 'EXIST2025',
#   'id': '120085',
#   'value': {'NO': 0.36538612842559814,
#    'DIRECT': 0.5891236066818237,
#    'JUDGEMENTAL': 0.08500998467206955}},
#  {'test_case': 'EXIST2025',
#   'id': '120086',
#   'value': {'NO': 0.7668884992599487,
#    'DIRECT': 0.1540313959121704,
#    'JUDGEMENTAL': 0.06432141363620758}},
#  {'test_case': 'EXIST2025',
#   'id': '120087',
#   'value': {'NO': 0.8563203811645508,
#    'DIRECT': 0.1523810178041458,
#    'JUDGEMENTAL': 0.02599899098277092}},
#  {'test_case': 'EXIST2025',
#   'id': '120088',
#   'value': {'NO': 0.3039226830005646,
#    'DIRECT': 0.3635735511779785,
#    'JUDGEMENTAL': 0.30517327785491943}},
#  {'test_case': 'EXIST2025',
#   'id': '120089',
#   'value': {'NO': 0.3421161472797394,
#    'DIRECT': 0.3662961423397064,
#    'JUDGEMENTAL': 0.25373730063438416}},
#  {'test_case': 'EXIST2025',
#   'id': '120090',
#   'value': {'NO': 0.45650744438171387,
#    'DIRECT': 0.1941825896501541,
#    'JUDGEMENTAL': 0.33417388796806335}},
#  {'test_case': 'EXIST2025',
#   'id': '120091',
#   'value': {'NO': 0.09636612236499786,
#    'DIRECT': 0.7645849585533142,
#    'JUDGEMENTAL': 0.30232977867126465}},
#  {'test_case': 'EXIST2025',
#   'id': '120092',
#   'value': {'NO': 0.4423847794532776,
#    'DIRECT': 0.291369765996933,
#    'JUDGEMENTAL': 0.16025575995445251}},
#  {'test_case': 'EXIST2025',
#   'id': '120093',
#   'value': {'NO': 0.37305164337158203,
#    'DIRECT': 0.615882396697998,
#    'JUDGEMENTAL': 0.08923082798719406}},
#  {'test_case': 'EXIST2025',
#   'id': '120094',
#   'value': {'NO': 0.20685698091983795,
#    'DIRECT': 0.5447020530700684,
#    'JUDGEMENTAL': 0.18492811918258667}},
#  {'test_case': 'EXIST2025',
#   'id': '120095',
#   'value': {'NO': 0.09196483343839645,
#    'DIRECT': 0.39017927646636963,
#    'JUDGEMENTAL': 0.5553138256072998}},
#  {'test_case': 'EXIST2025',
#   'id': '120096',
#   'value': {'NO': 0.13043005764484406,
#    'DIRECT': 0.7940554022789001,
#    'JUDGEMENTAL': 0.19839723408222198}},
#  {'test_case': 'EXIST2025',
#   'id': '120097',
#   'value': {'NO': 0.5708090662956238,
#    'DIRECT': 0.4478481113910675,
#    'JUDGEMENTAL': 0.05726388841867447}},
#  {'test_case': 'EXIST2025',
#   'id': '120098',
#   'value': {'NO': 0.861893355846405,
#    'DIRECT': 0.10949216037988663,
#    'JUDGEMENTAL': 0.040429070591926575}},
#  {'test_case': 'EXIST2025',
#   'id': '120099',
#   'value': {'NO': 0.5425989627838135,
#    'DIRECT': 0.25725817680358887,
#    'JUDGEMENTAL': 0.14711429178714752}},
#  {'test_case': 'EXIST2025',
#   'id': '120100',
#   'value': {'NO': 0.7234933972358704,
#    'DIRECT': 0.27123725414276123,
#    'JUDGEMENTAL': 0.03072061762213707}},
#  {'test_case': 'EXIST2025',
#   'id': '120101',
#   'value': {'NO': 0.3705165386199951,
#    'DIRECT': 0.6506683230400085,
#    'JUDGEMENTAL': 0.08257529139518738}},
#  {'test_case': 'EXIST2025',
#   'id': '120102',
#   'value': {'NO': 0.6517384052276611,
#    'DIRECT': 0.28901538252830505,
#    'JUDGEMENTAL': 0.046809274703264236}},
#  {'test_case': 'EXIST2025',
#   'id': '120103',
#   'value': {'NO': 0.3693411648273468,
#    'DIRECT': 0.454023540019989,
#    'JUDGEMENTAL': 0.1403735876083374}},
#  {'test_case': 'EXIST2025',
#   'id': '120104',
#   'value': {'NO': 0.1811268925666809,
#    'DIRECT': 0.24398255348205566,
#    'JUDGEMENTAL': 0.5371977090835571}},
#  {'test_case': 'EXIST2025',
#   'id': '120105',
#   'value': {'NO': 0.1122216060757637,
#    'DIRECT': 0.7253834009170532,
#    'JUDGEMENTAL': 0.27147501707077026}},
#  {'test_case': 'EXIST2025',
#   'id': '120106',
#   'value': {'NO': 0.17135395109653473,
#    'DIRECT': 0.6891350746154785,
#    'JUDGEMENTAL': 0.1564783751964569}},
#  {'test_case': 'EXIST2025',
#   'id': '120107',
#   'value': {'NO': 0.8946037292480469,
#    'DIRECT': 0.1648624837398529,
#    'JUDGEMENTAL': 0.12887413799762726}},
#  {'test_case': 'EXIST2025',
#   'id': '120108',
#   'value': {'NO': 0.11602446436882019,
#    'DIRECT': 0.7674802541732788,
#    'JUDGEMENTAL': 0.21435050666332245}},
#  {'test_case': 'EXIST2025',
#   'id': '120109',
#   'value': {'NO': 0.3122619390487671,
#    'DIRECT': 0.7034101486206055,
#    'JUDGEMENTAL': 0.09961184114217758}},
#  {'test_case': 'EXIST2025',
#   'id': '120110',
#   'value': {'NO': 0.359021931886673,
#    'DIRECT': 0.7468692660331726,
#    'JUDGEMENTAL': 0.13188624382019043}},
#  {'test_case': 'EXIST2025',
#   'id': '120111',
#   'value': {'NO': 0.9177278280258179,
#    'DIRECT': 0.1177876740694046,
#    'JUDGEMENTAL': 0.05569535493850708}},
#  {'test_case': 'EXIST2025',
#   'id': '120112',
#   'value': {'NO': 0.7731518149375916,
#    'DIRECT': 0.35554033517837524,
#    'JUDGEMENTAL': 0.07417232543230057}},
#  {'test_case': 'EXIST2025',
#   'id': '120113',
#   'value': {'NO': 0.36146649718284607,
#    'DIRECT': 0.5647664070129395,
#    'JUDGEMENTAL': 0.10092917084693909}},
#  {'test_case': 'EXIST2025',
#   'id': '120114',
#   'value': {'NO': 0.6488130688667297,
#    'DIRECT': 0.5994439721107483,
#    'JUDGEMENTAL': 0.1132558137178421}},
#  {'test_case': 'EXIST2025',
#   'id': '120115',
#   'value': {'NO': 0.6617283821105957,
#    'DIRECT': 0.7306742668151855,
#    'JUDGEMENTAL': 0.1886712610721588}},
#  {'test_case': 'EXIST2025',
#   'id': '120116',
#   'value': {'NO': 0.538887619972229,
#    'DIRECT': 0.7161622047424316,
#    'JUDGEMENTAL': 0.10894835740327835}},
#  {'test_case': 'EXIST2025',
#   'id': '120117',
#   'value': {'NO': 0.7773579359054565,
#    'DIRECT': 0.1713625192642212,
#    'JUDGEMENTAL': 0.04219704866409302}},
#  {'test_case': 'EXIST2025',
#   'id': '120118',
#   'value': {'NO': 0.333754301071167,
#    'DIRECT': 0.693341076374054,
#    'JUDGEMENTAL': 0.3924175500869751}},
#  {'test_case': 'EXIST2025',
#   'id': '120119',
#   'value': {'NO': 0.8999641537666321,
#    'DIRECT': 0.10350727289915085,
#    'JUDGEMENTAL': 0.034949686378240585}},
#  {'test_case': 'EXIST2025',
#   'id': '120120',
#   'value': {'NO': 0.5919454097747803,
#    'DIRECT': 0.6532036066055298,
#    'JUDGEMENTAL': 0.05810822173953056}},
#  {'test_case': 'EXIST2025',
#   'id': '120121',
#   'value': {'NO': 0.6092332005500793,
#    'DIRECT': 0.4599836766719818,
#    'JUDGEMENTAL': 0.049792397767305374}},
#  {'test_case': 'EXIST2025',
#   'id': '120122',
#   'value': {'NO': 0.7266442179679871,
#    'DIRECT': 0.27849462628364563,
#    'JUDGEMENTAL': 0.03710262104868889}},
#  {'test_case': 'EXIST2025',
#   'id': '120123',
#   'value': {'NO': 0.6764703392982483,
#    'DIRECT': 0.28072524070739746,
#    'JUDGEMENTAL': 0.045743510127067566}},
#  {'test_case': 'EXIST2025',
#   'id': '120124',
#   'value': {'NO': 0.30027055740356445,
#    'DIRECT': 0.8040518164634705,
#    'JUDGEMENTAL': 0.09206560254096985}},
#  {'test_case': 'EXIST2025',
#   'id': '120125',
#   'value': {'NO': 0.5039581656455994,
#    'DIRECT': 0.6345632672309875,
#    'JUDGEMENTAL': 0.054442476481199265}},
#  {'test_case': 'EXIST2025',
#   'id': '120126',
#   'value': {'NO': 0.13744403421878815,
#    'DIRECT': 0.7555984854698181,
#    'JUDGEMENTAL': 0.3021702766418457}},
#  {'test_case': 'EXIST2025',
#   'id': '120127',
#   'value': {'NO': 0.08427008986473083,
#    'DIRECT': 0.729232907295227,
#    'JUDGEMENTAL': 0.3110146224498749}},
#  {'test_case': 'EXIST2025',
#   'id': '120128',
#   'value': {'NO': 0.11608370393514633,
#    'DIRECT': 0.783119797706604,
#    'JUDGEMENTAL': 0.23666414618492126}},
#  {'test_case': 'EXIST2025',
#   'id': '120129',
#   'value': {'NO': 0.09977029263973236,
#    'DIRECT': 0.7849683165550232,
#    'JUDGEMENTAL': 0.25502389669418335}},
#  {'test_case': 'EXIST2025',
#   'id': '120130',
#   'value': {'NO': 0.222316712141037,
#    'DIRECT': 0.30419793725013733,
#    'JUDGEMENTAL': 0.38700997829437256}},
#  {'test_case': 'EXIST2025',
#   'id': '120131',
#   'value': {'NO': 0.24766626954078674,
#    'DIRECT': 0.7035765647888184,
#    'JUDGEMENTAL': 0.1337498277425766}},
#  {'test_case': 'EXIST2025',
#   'id': '120132',
#   'value': {'NO': 0.08398884534835815,
#    'DIRECT': 0.5752665400505066,
#    'JUDGEMENTAL': 0.3871089816093445}},
#  {'test_case': 'EXIST2025',
#   'id': '120133',
#   'value': {'NO': 0.6496292352676392,
#    'DIRECT': 0.41106417775154114,
#    'JUDGEMENTAL': 0.04088734835386276}},
#  {'test_case': 'EXIST2025',
#   'id': '120134',
#   'value': {'NO': 0.16651974618434906,
#    'DIRECT': 0.6703965663909912,
#    'JUDGEMENTAL': 0.1898483783006668}},
#  {'test_case': 'EXIST2025',
#   'id': '120135',
#   'value': {'NO': 0.2971230447292328,
#    'DIRECT': 0.4023212790489197,
#    'JUDGEMENTAL': 0.15161727368831635}},
#  {'test_case': 'EXIST2025',
#   'id': '120136',
#   'value': {'NO': 0.43086540699005127,
#    'DIRECT': 0.42229709029197693,
#    'JUDGEMENTAL': 0.11306670308113098}},
#  {'test_case': 'EXIST2025',
#   'id': '120137',
#   'value': {'NO': 0.43774938583374023,
#    'DIRECT': 0.32050853967666626,
#    'JUDGEMENTAL': 0.13644690811634064}},
#  {'test_case': 'EXIST2025',
#   'id': '120138',
#   'value': {'NO': 0.3502003252506256,
#    'DIRECT': 0.5425103306770325,
#    'JUDGEMENTAL': 0.14136143028736115}},
#  {'test_case': 'EXIST2025',
#   'id': '120139',
#   'value': {'NO': 0.1635407656431198,
#    'DIRECT': 0.7892759442329407,
#    'JUDGEMENTAL': 0.19547145068645477}},
#  {'test_case': 'EXIST2025',
#   'id': '120140',
#   'value': {'NO': 0.1916705071926117,
#    'DIRECT': 0.7796503305435181,
#    'JUDGEMENTAL': 0.12999628484249115}},
#  {'test_case': 'EXIST2025',
#   'id': '120141',
#   'value': {'NO': 0.9112016558647156,
#    'DIRECT': 0.05461319535970688,
#    'JUDGEMENTAL': 0.06615088880062103}},
#  {'test_case': 'EXIST2025',
#   'id': '120142',
#   'value': {'NO': 0.3588579595088959,
#    'DIRECT': 0.43397265672683716,
#    'JUDGEMENTAL': 0.12229135632514954}},
#  {'test_case': 'EXIST2025',
#   'id': '120143',
#   'value': {'NO': 0.23605547845363617,
#    'DIRECT': 0.4550809860229492,
#    'JUDGEMENTAL': 0.27797362208366394}},
#  {'test_case': 'EXIST2025',
#   'id': '120144',
#   'value': {'NO': 0.8032844662666321,
#    'DIRECT': 0.1799452304840088,
#    'JUDGEMENTAL': 0.025403374806046486}},
#  {'test_case': 'EXIST2025',
#   'id': '120145',
#   'value': {'NO': 0.2952973544597626,
#    'DIRECT': 0.38457879424095154,
#    'JUDGEMENTAL': 0.230300173163414}},
#  {'test_case': 'EXIST2025',
#   'id': '120146',
#   'value': {'NO': 0.6211265325546265,
#    'DIRECT': 0.3594183921813965,
#    'JUDGEMENTAL': 0.055263642221689224}},
#  {'test_case': 'EXIST2025',
#   'id': '120147',
#   'value': {'NO': 0.8951320052146912,
#    'DIRECT': 0.1278281807899475,
#    'JUDGEMENTAL': 0.04146185517311096}},
#  {'test_case': 'EXIST2025',
#   'id': '120148',
#   'value': {'NO': 0.7757002711296082,
#    'DIRECT': 0.37376531958580017,
#    'JUDGEMENTAL': 0.045354291796684265}},
#  {'test_case': 'EXIST2025',
#   'id': '120149',
#   'value': {'NO': 0.7439084649085999,
#    'DIRECT': 0.21773146092891693,
#    'JUDGEMENTAL': 0.03962543606758118}},
#  {'test_case': 'EXIST2025',
#   'id': '120150',
#   'value': {'NO': 0.813500702381134,
#    'DIRECT': 0.1879609078168869,
#    'JUDGEMENTAL': 0.035327762365341187}},
#  {'test_case': 'EXIST2025',
#   'id': '120151',
#   'value': {'NO': 0.6152922511100769,
#    'DIRECT': 0.3957114517688751,
#    'JUDGEMENTAL': 0.03859741985797882}},
#  {'test_case': 'EXIST2025',
#   'id': '120152',
#   'value': {'NO': 0.48207277059555054,
#    'DIRECT': 0.5394310355186462,
#    'JUDGEMENTAL': 0.05390087142586708}},
#  {'test_case': 'EXIST2025',
#   'id': '120153',
#   'value': {'NO': 0.5023062825202942,
#    'DIRECT': 0.5162959098815918,
#    'JUDGEMENTAL': 0.050661586225032806}},
#  {'test_case': 'EXIST2025',
#   'id': '120154',
#   'value': {'NO': 0.624036967754364,
#    'DIRECT': 0.2788841128349304,
#    'JUDGEMENTAL': 0.06714590638875961}},
#  {'test_case': 'EXIST2025',
#   'id': '120155',
#   'value': {'NO': 0.5265204310417175,
#    'DIRECT': 0.4558168053627014,
#    'JUDGEMENTAL': 0.053303636610507965}},
#  {'test_case': 'EXIST2025',
#   'id': '120156',
#   'value': {'NO': 0.2667095959186554,
#    'DIRECT': 0.5666754245758057,
#    'JUDGEMENTAL': 0.17085012793540955}},
#  {'test_case': 'EXIST2025',
#   'id': '120157',
#   'value': {'NO': 0.5153311491012573,
#    'DIRECT': 0.35104209184646606,
#    'JUDGEMENTAL': 0.08029374480247498}},
#  {'test_case': 'EXIST2025',
#   'id': '120158',
#   'value': {'NO': 0.5052452087402344,
#    'DIRECT': 0.3993065357208252,
#    'JUDGEMENTAL': 0.06530396640300751}},
#  {'test_case': 'EXIST2025',
#   'id': '120159',
#   'value': {'NO': 0.3870709240436554,
#    'DIRECT': 0.5283977389335632,
#    'JUDGEMENTAL': 0.06941259652376175}},
#  {'test_case': 'EXIST2025',
#   'id': '120160',
#   'value': {'NO': 0.27824848890304565,
#    'DIRECT': 0.39176255464553833,
#    'JUDGEMENTAL': 0.3121066689491272}},
#  {'test_case': 'EXIST2025',
#   'id': '120161',
#   'value': {'NO': 0.8778995275497437,
#    'DIRECT': 0.12220211327075958,
#    'JUDGEMENTAL': 0.026795867830514908}},
#  {'test_case': 'EXIST2025',
#   'id': '120162',
#   'value': {'NO': 0.19226756691932678,
#    'DIRECT': 0.6668195128440857,
#    'JUDGEMENTAL': 0.1818438619375229}},
#  {'test_case': 'EXIST2025',
#   'id': '120163',
#   'value': {'NO': 0.592179536819458,
#    'DIRECT': 0.29422107338905334,
#    'JUDGEMENTAL': 0.0598122738301754}},
#  {'test_case': 'EXIST2025',
#   'id': '120164',
#   'value': {'NO': 0.9260269999504089,
#    'DIRECT': 0.07021792232990265,
#    'JUDGEMENTAL': 0.031682807952165604}},
#  {'test_case': 'EXIST2025',
#   'id': '120165',
#   'value': {'NO': 0.38723474740982056,
#    'DIRECT': 0.5394862294197083,
#    'JUDGEMENTAL': 0.11355701833963394}},
#  {'test_case': 'EXIST2025',
#   'id': '120166',
#   'value': {'NO': 0.5180503726005554,
#    'DIRECT': 0.3230530917644501,
#    'JUDGEMENTAL': 0.08571849763393402}},
#  {'test_case': 'EXIST2025',
#   'id': '120167',
#   'value': {'NO': 0.24878723919391632,
#    'DIRECT': 0.4072049558162689,
#    'JUDGEMENTAL': 0.2799052894115448}},
#  {'test_case': 'EXIST2025',
#   'id': '120168',
#   'value': {'NO': 0.5666795372962952,
#    'DIRECT': 0.3894362449645996,
#    'JUDGEMENTAL': 0.06991659849882126}},
#  {'test_case': 'EXIST2025',
#   'id': '120169',
#   'value': {'NO': 0.8210299015045166,
#    'DIRECT': 0.18115811049938202,
#    'JUDGEMENTAL': 0.03317057713866234}},
#  {'test_case': 'EXIST2025',
#   'id': '120170',
#   'value': {'NO': 0.5826485753059387,
#    'DIRECT': 0.36358991265296936,
#    'JUDGEMENTAL': 0.056123036891222}},
#  {'test_case': 'EXIST2025',
#   'id': '120171',
#   'value': {'NO': 0.9119160175323486,
#    'DIRECT': 0.0932476744055748,
#    'JUDGEMENTAL': 0.0355294831097126}},
#  {'test_case': 'EXIST2025',
#   'id': '120172',
#   'value': {'NO': 0.5940165519714355,
#    'DIRECT': 0.2528556287288666,
#    'JUDGEMENTAL': 0.1093575656414032}},
#  {'test_case': 'EXIST2025',
#   'id': '120173',
#   'value': {'NO': 0.7812830805778503,
#    'DIRECT': 0.21374735236167908,
#    'JUDGEMENTAL': 0.03334401920437813}},
#  {'test_case': 'EXIST2025',
#   'id': '120174',
#   'value': {'NO': 0.3653610646724701,
#    'DIRECT': 0.41636040806770325,
#    'JUDGEMENTAL': 0.2090635895729065}},
#  {'test_case': 'EXIST2025',
#   'id': '120175',
#   'value': {'NO': 0.860523521900177,
#    'DIRECT': 0.08974882960319519,
#    'JUDGEMENTAL': 0.04710149019956589}},
#  {'test_case': 'EXIST2025',
#   'id': '120176',
#   'value': {'NO': 0.9160007834434509,
#    'DIRECT': 0.1409536600112915,
#    'JUDGEMENTAL': 0.037306223064661026}},
#  {'test_case': 'EXIST2025',
#   'id': '120177',
#   'value': {'NO': 0.9181137681007385,
#    'DIRECT': 0.0971764624118805,
#    'JUDGEMENTAL': 0.03475766256451607}},
#  {'test_case': 'EXIST2025',
#   'id': '120178',
#   'value': {'NO': 0.2961096167564392,
#    'DIRECT': 0.3779137134552002,
#    'JUDGEMENTAL': 0.202818363904953}},
#  {'test_case': 'EXIST2025',
#   'id': '120179',
#   'value': {'NO': 0.7141754627227783,
#    'DIRECT': 0.21837849915027618,
#    'JUDGEMENTAL': 0.04627742990851402}},
#  {'test_case': 'EXIST2025',
#   'id': '120180',
#   'value': {'NO': 0.5882498621940613,
#    'DIRECT': 0.2834779918193817,
#    'JUDGEMENTAL': 0.06627463549375534}},
#  {'test_case': 'EXIST2025',
#   'id': '120181',
#   'value': {'NO': 0.6937788128852844,
#    'DIRECT': 0.21994782984256744,
#    'JUDGEMENTAL': 0.04946819692850113}},
#  {'test_case': 'EXIST2025',
#   'id': '120182',
#   'value': {'NO': 0.34652313590049744,
#    'DIRECT': 0.21871255338191986,
#    'JUDGEMENTAL': 0.3707539737224579}},
#  {'test_case': 'EXIST2025',
#   'id': '120183',
#   'value': {'NO': 0.8750489950180054,
#    'DIRECT': 0.1263536512851715,
#    'JUDGEMENTAL': 0.039058394730091095}},
#  {'test_case': 'EXIST2025',
#   'id': '120184',
#   'value': {'NO': 0.9124932289123535,
#    'DIRECT': 0.09099150449037552,
#    'JUDGEMENTAL': 0.02759147435426712}},
#  {'test_case': 'EXIST2025',
#   'id': '120185',
#   'value': {'NO': 0.8109513521194458,
#    'DIRECT': 0.22706343233585358,
#    'JUDGEMENTAL': 0.021265678107738495}},
#  {'test_case': 'EXIST2025',
#   'id': '120186',
#   'value': {'NO': 0.9135085344314575,
#    'DIRECT': 0.12415765970945358,
#    'JUDGEMENTAL': 0.04538837447762489}},
#  {'test_case': 'EXIST2025',
#   'id': '120187',
#   'value': {'NO': 0.6430633068084717,
#    'DIRECT': 0.21275728940963745,
#    'JUDGEMENTAL': 0.06491796672344208}},
#  {'test_case': 'EXIST2025',
#   'id': '120188',
#   'value': {'NO': 0.5308339595794678,
#    'DIRECT': 0.280681848526001,
#    'JUDGEMENTAL': 0.11644791811704636}},
#  {'test_case': 'EXIST2025',
#   'id': '120189',
#   'value': {'NO': 0.49830251932144165,
#    'DIRECT': 0.30574581027030945,
#    'JUDGEMENTAL': 0.11680838465690613}},
#  {'test_case': 'EXIST2025',
#   'id': '120190',
#   'value': {'NO': 0.753917932510376,
#    'DIRECT': 0.22458530962467194,
#    'JUDGEMENTAL': 0.07254812121391296}},
#  {'test_case': 'EXIST2025',
#   'id': '120191',
#   'value': {'NO': 0.8959909677505493,
#    'DIRECT': 0.09165480732917786,
#    'JUDGEMENTAL': 0.03779341280460358}},
#  {'test_case': 'EXIST2025',
#   'id': '120192',
#   'value': {'NO': 0.8486297130584717,
#    'DIRECT': 0.10785780847072601,
#    'JUDGEMENTAL': 0.04169351980090141}},
#  {'test_case': 'EXIST2025',
#   'id': '120193',
#   'value': {'NO': 0.758690595626831,
#    'DIRECT': 0.20823661983013153,
#    'JUDGEMENTAL': 0.039964888244867325}},
#  {'test_case': 'EXIST2025',
#   'id': '120194',
#   'value': {'NO': 0.5410737991333008,
#    'DIRECT': 0.1265467405319214,
#    'JUDGEMENTAL': 0.41837942600250244}},
#  {'test_case': 'EXIST2025',
#   'id': '120195',
#   'value': {'NO': 0.8425559401512146,
#    'DIRECT': 0.13411177694797516,
#    'JUDGEMENTAL': 0.06485933810472488}},
#  {'test_case': 'EXIST2025',
#   'id': '120196',
#   'value': {'NO': 0.37393394112586975,
#    'DIRECT': 0.555672287940979,
#    'JUDGEMENTAL': 0.13518166542053223}},
#  {'test_case': 'EXIST2025',
#   'id': '120197',
#   'value': {'NO': 0.9270666241645813,
#    'DIRECT': 0.06557299196720123,
#    'JUDGEMENTAL': 0.04570077732205391}},
#  {'test_case': 'EXIST2025',
#   'id': '120198',
#   'value': {'NO': 0.32183128595352173,
#    'DIRECT': 0.3505586087703705,
#    'JUDGEMENTAL': 0.23834630846977234}},
#  {'test_case': 'EXIST2025',
#   'id': '120199',
#   'value': {'NO': 0.7086094617843628,
#    'DIRECT': 0.09844691306352615,
#    'JUDGEMENTAL': 0.2739507853984833}},
#  {'test_case': 'EXIST2025',
#   'id': '120200',
#   'value': {'NO': 0.47163501381874084,
#    'DIRECT': 0.3129114806652069,
#    'JUDGEMENTAL': 0.11563988775014877}},
#  {'test_case': 'EXIST2025',
#   'id': '120201',
#   'value': {'NO': 0.8530653715133667,
#    'DIRECT': 0.1611684262752533,
#    'JUDGEMENTAL': 0.029127134010195732}},
#  {'test_case': 'EXIST2025',
#   'id': '120202',
#   'value': {'NO': 0.3419282138347626,
#    'DIRECT': 0.32030990719795227,
#    'JUDGEMENTAL': 0.1751050353050232}},
#  {'test_case': 'EXIST2025',
#   'id': '120203',
#   'value': {'NO': 0.5875502824783325,
#    'DIRECT': 0.27683204412460327,
#    'JUDGEMENTAL': 0.06512637436389923}},
#  {'test_case': 'EXIST2025',
#   'id': '120204',
#   'value': {'NO': 0.38791900873184204,
#    'DIRECT': 0.3403404653072357,
#    'JUDGEMENTAL': 0.13784261047840118}},
#  {'test_case': 'EXIST2025',
#   'id': '120205',
#   'value': {'NO': 0.9432180523872375,
#    'DIRECT': 0.07990746200084686,
#    'JUDGEMENTAL': 0.06135934591293335}},
#  {'test_case': 'EXIST2025',
#   'id': '120206',
#   'value': {'NO': 0.8291082382202148,
#    'DIRECT': 0.18138015270233154,
#    'JUDGEMENTAL': 0.03470221534371376}},
#  {'test_case': 'EXIST2025',
#   'id': '120207',
#   'value': {'NO': 0.8437530398368835,
#    'DIRECT': 0.17381227016448975,
#    'JUDGEMENTAL': 0.02932724729180336}},
#  {'test_case': 'EXIST2025',
#   'id': '120208',
#   'value': {'NO': 0.7392956018447876,
#    'DIRECT': 0.19025810062885284,
#    'JUDGEMENTAL': 0.04131268337368965}},
#  {'test_case': 'EXIST2025',
#   'id': '120209',
#   'value': {'NO': 0.372366338968277,
#    'DIRECT': 0.3829728960990906,
#    'JUDGEMENTAL': 0.20132438838481903}},
#  {'test_case': 'EXIST2025',
#   'id': '120210',
#   'value': {'NO': 0.06808232516050339,
#    'DIRECT': 0.43083247542381287,
#    'JUDGEMENTAL': 0.6755918860435486}},
#  {'test_case': 'EXIST2025',
#   'id': '120211',
#   'value': {'NO': 0.6120970249176025,
#    'DIRECT': 0.2696307599544525,
#    'JUDGEMENTAL': 0.09881168603897095}},
#  {'test_case': 'EXIST2025',
#   'id': '120212',
#   'value': {'NO': 0.7889598608016968,
#    'DIRECT': 0.11995581537485123,
#    'JUDGEMENTAL': 0.05444800481200218}},
#  {'test_case': 'EXIST2025',
#   'id': '120213',
#   'value': {'NO': 0.2297835797071457,
#    'DIRECT': 0.5987318754196167,
#    'JUDGEMENTAL': 0.14991608262062073}},
#  {'test_case': 'EXIST2025',
#   'id': '120214',
#   'value': {'NO': 0.2279580980539322,
#    'DIRECT': 0.4973943829536438,
#    'JUDGEMENTAL': 0.1930115967988968}},
#  {'test_case': 'EXIST2025',
#   'id': '120215',
#   'value': {'NO': 0.10488275438547134,
#    'DIRECT': 0.741965115070343,
#    'JUDGEMENTAL': 0.2508130669593811}},
#  {'test_case': 'EXIST2025',
#   'id': '120216',
#   'value': {'NO': 0.20402847230434418,
#    'DIRECT': 0.7663151025772095,
#    'JUDGEMENTAL': 0.11270584911108017}},
#  {'test_case': 'EXIST2025',
#   'id': '120217',
#   'value': {'NO': 0.6726897358894348,
#    'DIRECT': 0.15944434702396393,
#    'JUDGEMENTAL': 0.09669623523950577}},
#  {'test_case': 'EXIST2025',
#   'id': '120218',
#   'value': {'NO': 0.11604339629411697,
#    'DIRECT': 0.6931124329566956,
#    'JUDGEMENTAL': 0.2497413158416748}},
#  {'test_case': 'EXIST2025',
#   'id': '120219',
#   'value': {'NO': 0.459359347820282,
#    'DIRECT': 0.2635386288166046,
#    'JUDGEMENTAL': 0.2240578830242157}},
#  {'test_case': 'EXIST2025',
#   'id': '120220',
#   'value': {'NO': 0.2038727104663849,
#    'DIRECT': 0.48561349511146545,
#    'JUDGEMENTAL': 0.301452100276947}},
#  {'test_case': 'EXIST2025',
#   'id': '120221',
#   'value': {'NO': 0.12487543374300003,
#    'DIRECT': 0.6855965852737427,
#    'JUDGEMENTAL': 0.22168944776058197}},
#  {'test_case': 'EXIST2025',
#   'id': '120222',
#   'value': {'NO': 0.24569301307201385,
#    'DIRECT': 0.664225697517395,
#    'JUDGEMENTAL': 0.12699946761131287}},
#  {'test_case': 'EXIST2025',
#   'id': '120223',
#   'value': {'NO': 0.3868337869644165,
#    'DIRECT': 0.379351943731308,
#    'JUDGEMENTAL': 0.17219620943069458}},
#  {'test_case': 'EXIST2025',
#   'id': '120224',
#   'value': {'NO': 0.3514344096183777,
#    'DIRECT': 0.3645459711551666,
#    'JUDGEMENTAL': 0.23149427771568298}},
#  {'test_case': 'EXIST2025',
#   'id': '120225',
#   'value': {'NO': 0.05837355554103851,
#    'DIRECT': 0.5003576874732971,
#    'JUDGEMENTAL': 0.5841997265815735}},
#  {'test_case': 'EXIST2025',
#   'id': '120226',
#   'value': {'NO': 0.12968450784683228,
#    'DIRECT': 0.7883195281028748,
#    'JUDGEMENTAL': 0.2074211984872818}},
#  {'test_case': 'EXIST2025',
#   'id': '120227',
#   'value': {'NO': 0.17568618059158325,
#    'DIRECT': 0.5448645353317261,
#    'JUDGEMENTAL': 0.18615935742855072}},
#  {'test_case': 'EXIST2025',
#   'id': '120228',
#   'value': {'NO': 0.8208256959915161,
#    'DIRECT': 0.1991291046142578,
#    'JUDGEMENTAL': 0.03700564056634903}},
#  {'test_case': 'EXIST2025',
#   'id': '120229',
#   'value': {'NO': 0.7377299666404724,
#    'DIRECT': 0.5823882818222046,
#    'JUDGEMENTAL': 0.20421753823757172}},
#  {'test_case': 'EXIST2025',
#   'id': '120230',
#   'value': {'NO': 0.4389125406742096,
#    'DIRECT': 0.30114465951919556,
#    'JUDGEMENTAL': 0.19446314871311188}},
#  {'test_case': 'EXIST2025',
#   'id': '120231',
#   'value': {'NO': 0.30265891551971436,
#    'DIRECT': 0.40144577622413635,
#    'JUDGEMENTAL': 0.20937404036521912}},
#  {'test_case': 'EXIST2025',
#   'id': '120232',
#   'value': {'NO': 0.07477675378322601,
#    'DIRECT': 0.6726670265197754,
#    'JUDGEMENTAL': 0.42961814999580383}},
#  {'test_case': 'EXIST2025',
#   'id': '120233',
#   'value': {'NO': 0.40329232811927795,
#    'DIRECT': 0.3856063485145569,
#    'JUDGEMENTAL': 0.12893646955490112}},
#  {'test_case': 'EXIST2025',
#   'id': '120234',
#   'value': {'NO': 0.43900418281555176,
#    'DIRECT': 0.2673533260822296,
#    'JUDGEMENTAL': 0.22141312062740326}},
#  {'test_case': 'EXIST2025',
#   'id': '120235',
#   'value': {'NO': 0.06811211258172989,
#    'DIRECT': 0.5712038278579712,
#    'JUDGEMENTAL': 0.4863864481449127}},
#  {'test_case': 'EXIST2025',
#   'id': '120236',
#   'value': {'NO': 0.09460633993148804,
#    'DIRECT': 0.43649759888648987,
#    'JUDGEMENTAL': 0.5285512804985046}},
#  {'test_case': 'EXIST2025',
#   'id': '120237',
#   'value': {'NO': 0.07442046701908112,
#    'DIRECT': 0.5803987979888916,
#    'JUDGEMENTAL': 0.4602023959159851}},
#  {'test_case': 'EXIST2025',
#   'id': '120238',
#   'value': {'NO': 0.09290371090173721,
#    'DIRECT': 0.652440071105957,
#    'JUDGEMENTAL': 0.34753885865211487}},
#  {'test_case': 'EXIST2025',
#   'id': '120239',
#   'value': {'NO': 0.7200334072113037,
#    'DIRECT': 0.20377054810523987,
#    'JUDGEMENTAL': 0.04385853558778763}},
#  {'test_case': 'EXIST2025',
#   'id': '120240',
#   'value': {'NO': 0.12231214344501495,
#    'DIRECT': 0.4276010990142822,
#    'JUDGEMENTAL': 0.4757910966873169}},
#  {'test_case': 'EXIST2025',
#   'id': '120241',
#   'value': {'NO': 0.11655742675065994,
#    'DIRECT': 0.687975287437439,
#    'JUDGEMENTAL': 0.32927483320236206}},
#  {'test_case': 'EXIST2025',
#   'id': '120242',
#   'value': {'NO': 0.4314937889575958,
#    'DIRECT': 0.30754902958869934,
#    'JUDGEMENTAL': 0.18598030507564545}},
#  {'test_case': 'EXIST2025',
#   'id': '120243',
#   'value': {'NO': 0.6425995826721191,
#    'DIRECT': 0.2840507924556732,
#    'JUDGEMENTAL': 0.07943373173475266}},
#  {'test_case': 'EXIST2025',
#   'id': '120244',
#   'value': {'NO': 0.15708349645137787,
#    'DIRECT': 0.40535447001457214,
#    'JUDGEMENTAL': 0.4122055172920227}},
#  {'test_case': 'EXIST2025',
#   'id': '120245',
#   'value': {'NO': 0.33870208263397217,
#    'DIRECT': 0.45888346433639526,
#    'JUDGEMENTAL': 0.19770942628383636}},
#  {'test_case': 'EXIST2025',
#   'id': '120246',
#   'value': {'NO': 0.10114726424217224,
#    'DIRECT': 0.6559377312660217,
#    'JUDGEMENTAL': 0.36720940470695496}},
#  {'test_case': 'EXIST2025',
#   'id': '120247',
#   'value': {'NO': 0.2851431965827942,
#    'DIRECT': 0.34588003158569336,
#    'JUDGEMENTAL': 0.39696136116981506}},
#  {'test_case': 'EXIST2025',
#   'id': '120248',
#   'value': {'NO': 0.25926533341407776,
#    'DIRECT': 0.3679307997226715,
#    'JUDGEMENTAL': 0.3391762673854828}},
#  {'test_case': 'EXIST2025',
#   'id': '120249',
#   'value': {'NO': 0.0740247368812561,
#    'DIRECT': 0.5568625926971436,
#    'JUDGEMENTAL': 0.45232102274894714}},
#  {'test_case': 'EXIST2025',
#   'id': '120250',
#   'value': {'NO': 0.653226375579834,
#    'DIRECT': 0.2142673134803772,
#    'JUDGEMENTAL': 0.09166873246431351}},
#  {'test_case': 'EXIST2025',
#   'id': '120251',
#   'value': {'NO': 0.22861333191394806,
#    'DIRECT': 0.42187657952308655,
#    'JUDGEMENTAL': 0.29960036277770996}},
#  {'test_case': 'EXIST2025',
#   'id': '120252',
#   'value': {'NO': 0.23980480432510376,
#    'DIRECT': 0.4763471186161041,
#    'JUDGEMENTAL': 0.22428132593631744}},
#  {'test_case': 'EXIST2025',
#   'id': '120253',
#   'value': {'NO': 0.4863085150718689,
#    'DIRECT': 0.4894770681858063,
#    'JUDGEMENTAL': 0.06335509568452835}},
#  {'test_case': 'EXIST2025',
#   'id': '120254',
#   'value': {'NO': 0.21531476080417633,
#    'DIRECT': 0.43668612837791443,
#    'JUDGEMENTAL': 0.27422893047332764}},
#  {'test_case': 'EXIST2025',
#   'id': '120255',
#   'value': {'NO': 0.27357017993927,
#    'DIRECT': 0.5311558246612549,
#    'JUDGEMENTAL': 0.1389092206954956}},
#  {'test_case': 'EXIST2025',
#   'id': '120256',
#   'value': {'NO': 0.2663087248802185,
#    'DIRECT': 0.42821750044822693,
#    'JUDGEMENTAL': 0.2640063762664795}},
#  {'test_case': 'EXIST2025',
#   'id': '120257',
#   'value': {'NO': 0.3432953655719757,
#    'DIRECT': 0.17408595979213715,
#    'JUDGEMENTAL': 0.4694262742996216}},
#  {'test_case': 'EXIST2025',
#   'id': '120258',
#   'value': {'NO': 0.3798794150352478,
#    'DIRECT': 0.18503516912460327,
#    'JUDGEMENTAL': 0.416901558637619}},
#  {'test_case': 'EXIST2025',
#   'id': '120259',
#   'value': {'NO': 0.3959406316280365,
#    'DIRECT': 0.24216806888580322,
#    'JUDGEMENTAL': 0.27081725001335144}},
#  {'test_case': 'EXIST2025',
#   'id': '120260',
#   'value': {'NO': 0.3852718770503998,
#    'DIRECT': 0.3604092597961426,
#    'JUDGEMENTAL': 0.19930748641490936}},
#  {'test_case': 'EXIST2025',
#   'id': '120261',
#   'value': {'NO': 0.1800348460674286,
#    'DIRECT': 0.5367748141288757,
#    'JUDGEMENTAL': 0.27014434337615967}},
#  {'test_case': 'EXIST2025',
#   'id': '120262',
#   'value': {'NO': 0.8727483749389648,
#    'DIRECT': 0.10934705287218094,
#    'JUDGEMENTAL': 0.03726630285382271}},
#  {'test_case': 'EXIST2025',
#   'id': '120263',
#   'value': {'NO': 0.37139713764190674,
#    'DIRECT': 0.3634674549102783,
#    'JUDGEMENTAL': 0.23087257146835327}},
#  {'test_case': 'EXIST2025',
#   'id': '120264',
#   'value': {'NO': 0.45844459533691406,
#    'DIRECT': 0.2140653133392334,
#    'JUDGEMENTAL': 0.2109776735305786}},
#  {'test_case': 'EXIST2025',
#   'id': '120265',
#   'value': {'NO': 0.30008482933044434,
#    'DIRECT': 0.7429782748222351,
#    'JUDGEMENTAL': 0.09108423441648483}},
#  {'test_case': 'EXIST2025',
#   'id': '120266',
#   'value': {'NO': 0.35323983430862427,
#    'DIRECT': 0.3313262462615967,
#    'JUDGEMENTAL': 0.2251616269350052}},
#  {'test_case': 'EXIST2025',
#   'id': '120267',
#   'value': {'NO': 0.7391538023948669,
#    'DIRECT': 0.17821532487869263,
#    'JUDGEMENTAL': 0.09014280885457993}},
#  {'test_case': 'EXIST2025',
#   'id': '120268',
#   'value': {'NO': 0.8133701682090759,
#    'DIRECT': 0.15520788729190826,
#    'JUDGEMENTAL': 0.05007465183734894}},
#  {'test_case': 'EXIST2025',
#   'id': '120269',
#   'value': {'NO': 0.8030267953872681,
#    'DIRECT': 0.17609435319900513,
#    'JUDGEMENTAL': 0.05137293040752411}},
#  {'test_case': 'EXIST2025',
#   'id': '120270',
#   'value': {'NO': 0.6683152914047241,
#    'DIRECT': 0.12674902379512787,
#    'JUDGEMENTAL': 0.13755202293395996}},
#  {'test_case': 'EXIST2025',
#   'id': '120271',
#   'value': {'NO': 0.9271531105041504,
#    'DIRECT': 0.04627155885100365,
#    'JUDGEMENTAL': 0.10278154909610748}},
#  {'test_case': 'EXIST2025',
#   'id': '120272',
#   'value': {'NO': 0.4486410617828369,
#    'DIRECT': 0.1631431132555008,
#    'JUDGEMENTAL': 0.43399733304977417}},
#  {'test_case': 'EXIST2025',
#   'id': '120273',
#   'value': {'NO': 0.8605101108551025,
#    'DIRECT': 0.09290289878845215,
#    'JUDGEMENTAL': 0.07776815444231033}},
#  {'test_case': 'EXIST2025',
#   'id': '120274',
#   'value': {'NO': 0.5974622368812561,
#    'DIRECT': 0.1849168837070465,
#    'JUDGEMENTAL': 0.11137136816978455}},
#  {'test_case': 'EXIST2025',
#   'id': '120275',
#   'value': {'NO': 0.18053968250751495,
#    'DIRECT': 0.46747887134552,
#    'JUDGEMENTAL': 0.3242599666118622}},
#  {'test_case': 'EXIST2025',
#   'id': '120276',
#   'value': {'NO': 0.64314866065979,
#    'DIRECT': 0.3609270453453064,
#    'JUDGEMENTAL': 0.042090870440006256}},
#  {'test_case': 'EXIST2025',
#   'id': '120277',
#   'value': {'NO': 0.3550943434238434,
#    'DIRECT': 0.673266589641571,
#    'JUDGEMENTAL': 0.07135578989982605}},
#  {'test_case': 'EXIST2025',
#   'id': '120278',
#   'value': {'NO': 0.7059714794158936,
#    'DIRECT': 0.19217641651630402,
#    'JUDGEMENTAL': 0.06772420555353165}},
#  {'test_case': 'EXIST2025',
#   'id': '120279',
#   'value': {'NO': 0.25074419379234314,
#    'DIRECT': 0.7194226980209351,
#    'JUDGEMENTAL': 0.15576034784317017}},
#  {'test_case': 'EXIST2025',
#   'id': '120280',
#   'value': {'NO': 0.6010286808013916,
#    'DIRECT': 0.5552616119384766,
#    'JUDGEMENTAL': 0.05081714317202568}},
#  {'test_case': 'EXIST2025',
#   'id': '120281',
#   'value': {'NO': 0.4800187051296234,
#    'DIRECT': 0.41667383909225464,
#    'JUDGEMENTAL': 0.07829737663269043}},
#  {'test_case': 'EXIST2025',
#   'id': '120282',
#   'value': {'NO': 0.29745030403137207,
#    'DIRECT': 0.44386085867881775,
#    'JUDGEMENTAL': 0.16118665039539337}},
#  {'test_case': 'EXIST2025',
#   'id': '120283',
#   'value': {'NO': 0.28686636686325073,
#    'DIRECT': 0.6779332756996155,
#    'JUDGEMENTAL': 0.09610354900360107}},
#  {'test_case': 'EXIST2025',
#   'id': '120284',
#   'value': {'NO': 0.9305171966552734,
#    'DIRECT': 0.06637828797101974,
#    'JUDGEMENTAL': 0.04000740498304367}},
#  {'test_case': 'EXIST2025',
#   'id': '120285',
#   'value': {'NO': 0.4989774823188782,
#    'DIRECT': 0.3268912136554718,
#    'JUDGEMENTAL': 0.11308081448078156}},
#  {'test_case': 'EXIST2025',
#   'id': '120286',
#   'value': {'NO': 0.7324554920196533,
#    'DIRECT': 0.1368480920791626,
#    'JUDGEMENTAL': 0.06754279136657715}},
#  {'test_case': 'EXIST2025',
#   'id': '120287',
#   'value': {'NO': 0.6819036602973938,
#    'DIRECT': 0.23964208364486694,
#    'JUDGEMENTAL': 0.0654836893081665}},
#  {'test_case': 'EXIST2025',
#   'id': '120288',
#   'value': {'NO': 0.6542718410491943,
#    'DIRECT': 0.2539710998535156,
#    'JUDGEMENTAL': 0.06676241010427475}},
#  {'test_case': 'EXIST2025',
#   'id': '120289',
#   'value': {'NO': 0.8547574281692505,
#    'DIRECT': 0.1178310289978981,
#    'JUDGEMENTAL': 0.05772024020552635}},
#  {'test_case': 'EXIST2025',
#   'id': '120290',
#   'value': {'NO': 0.33316516876220703,
#    'DIRECT': 0.6745067238807678,
#    'JUDGEMENTAL': 0.12051863223314285}},
#  {'test_case': 'EXIST2025',
#   'id': '120291',
#   'value': {'NO': 0.8038544058799744,
#    'DIRECT': 0.15348117053508759,
#    'JUDGEMENTAL': 0.043452188372612}},
#  {'test_case': 'EXIST2025',
#   'id': '120292',
#   'value': {'NO': 0.6162490844726562,
#    'DIRECT': 0.29188647866249084,
#    'JUDGEMENTAL': 0.07032854110002518}},
#  {'test_case': 'EXIST2025',
#   'id': '120293',
#   'value': {'NO': 0.7228839993476868,
#    'DIRECT': 0.1845545619726181,
#    'JUDGEMENTAL': 0.06473392993211746}},
#  {'test_case': 'EXIST2025',
#   'id': '120294',
#   'value': {'NO': 0.6147173643112183,
#    'DIRECT': 0.42057985067367554,
#    'JUDGEMENTAL': 0.032287243753671646}},
#  {'test_case': 'EXIST2025',
#   'id': '120295',
# ...
#   'id': '120900',
#   'value': {'NO': 0.4004156291484833,
#    'DIRECT': 0.4276660978794098,
#    'JUDGEMENTAL': 0.14383648335933685}},
#  {'test_case': 'EXIST2025',
#   'id': '120901',
#   'value': {'NO': 0.40531423687934875,
#    'DIRECT': 0.5678786635398865,
#    'JUDGEMENTAL': 0.08363639563322067}},
#  {'test_case': 'EXIST2025',
#   'id': '120902',
#   'value': {'NO': 0.8534043431282043,
#    'DIRECT': 0.16779294610023499,
#    'JUDGEMENTAL': 0.029824847355484962}},
#  {'test_case': 'EXIST2025',
#   'id': '120903',
#   'value': {'NO': 0.8590864539146423,
#    'DIRECT': 0.16468004882335663,
#    'JUDGEMENTAL': 0.027924198657274246}},
#  {'test_case': 'EXIST2025',
#   'id': '120904',
#   'value': {'NO': 0.9362074732780457,
#    'DIRECT': 0.07017403841018677,
#    'JUDGEMENTAL': 0.04334990680217743}},
#  {'test_case': 'EXIST2025',
#   'id': '120905',
#   'value': {'NO': 0.42680782079696655,
#    'DIRECT': 0.43573111295700073,
#    'JUDGEMENTAL': 0.0898011326789856}},
#  {'test_case': 'EXIST2025',
#   'id': '120906',
#   'value': {'NO': 0.23395925760269165,
#    'DIRECT': 0.6538731455802917,
#    'JUDGEMENTAL': 0.15582747757434845}},
#  {'test_case': 'EXIST2025',
#   'id': '120907',
#   'value': {'NO': 0.8191120624542236,
#    'DIRECT': 0.2102959156036377,
#    'JUDGEMENTAL': 0.027094611898064613}},
#  {'test_case': 'EXIST2025',
#   'id': '120908',
#   'value': {'NO': 0.7218043804168701,
#    'DIRECT': 0.37976378202438354,
#    'JUDGEMENTAL': 0.030650807544589043}},
#  {'test_case': 'EXIST2025',
#   'id': '120909',
#   'value': {'NO': 0.3735843598842621,
#    'DIRECT': 0.30783435702323914,
#    'JUDGEMENTAL': 0.2375204861164093}},
#  {'test_case': 'EXIST2025',
#   'id': '120910',
#   'value': {'NO': 0.3593985438346863,
#    'DIRECT': 0.37400200963020325,
#    'JUDGEMENTAL': 0.244289830327034}},
#  {'test_case': 'EXIST2025',
#   'id': '120911',
#   'value': {'NO': 0.07713711261749268,
#    'DIRECT': 0.32639771699905396,
#    'JUDGEMENTAL': 0.7128304839134216}},
#  {'test_case': 'EXIST2025',
#   'id': '120912',
#   'value': {'NO': 0.2966965138912201,
#    'DIRECT': 0.2566607594490051,
#    'JUDGEMENTAL': 0.438681960105896}},
#  {'test_case': 'EXIST2025',
#   'id': '120913',
#   'value': {'NO': 0.44933435320854187,
#    'DIRECT': 0.350683331489563,
#    'JUDGEMENTAL': 0.10352098941802979}},
#  {'test_case': 'EXIST2025',
#   'id': '120914',
#   'value': {'NO': 0.12230736017227173,
#    'DIRECT': 0.26275020837783813,
#    'JUDGEMENTAL': 0.6315479278564453}},
#  {'test_case': 'EXIST2025',
#   'id': '120915',
#   'value': {'NO': 0.5602510571479797,
#    'DIRECT': 0.192876935005188,
#    'JUDGEMENTAL': 0.18313375115394592}},
#  {'test_case': 'EXIST2025',
#   'id': '120916',
#   'value': {'NO': 0.17555175721645355,
#    'DIRECT': 0.25482964515686035,
#    'JUDGEMENTAL': 0.5681955218315125}},
#  {'test_case': 'EXIST2025',
#   'id': '120917',
#   'value': {'NO': 0.3489205241203308,
#    'DIRECT': 0.3892821967601776,
#    'JUDGEMENTAL': 0.17561160027980804}},
#  {'test_case': 'EXIST2025',
#   'id': '120918',
#   'value': {'NO': 0.7916353940963745,
#    'DIRECT': 0.1659287065267563,
#    'JUDGEMENTAL': 0.06233905255794525}},
#  {'test_case': 'EXIST2025',
#   'id': '120919',
#   'value': {'NO': 0.3747280538082123,
#    'DIRECT': 0.24108967185020447,
#    'JUDGEMENTAL': 0.2609267234802246}},
#  {'test_case': 'EXIST2025',
#   'id': '120920',
#   'value': {'NO': 0.36640653014183044,
#    'DIRECT': 0.4313434958457947,
#    'JUDGEMENTAL': 0.198966845870018}},
#  {'test_case': 'EXIST2025',
#   'id': '120921',
#   'value': {'NO': 0.9169214367866516,
#    'DIRECT': 0.060115229338407516,
#    'JUDGEMENTAL': 0.05091787502169609}},
#  {'test_case': 'EXIST2025',
#   'id': '120922',
#   'value': {'NO': 0.3838280141353607,
#    'DIRECT': 0.2876385450363159,
#    'JUDGEMENTAL': 0.29203733801841736}},
#  {'test_case': 'EXIST2025',
#   'id': '120923',
#   'value': {'NO': 0.5079543590545654,
#    'DIRECT': 0.28665199875831604,
#    'JUDGEMENTAL': 0.07972508668899536}},
#  {'test_case': 'EXIST2025',
#   'id': '120924',
#   'value': {'NO': 0.5814959406852722,
#    'DIRECT': 0.19636733829975128,
#    'JUDGEMENTAL': 0.1269281655550003}},
#  {'test_case': 'EXIST2025',
#   'id': '120925',
#   'value': {'NO': 0.3642868995666504,
#    'DIRECT': 0.2977007329463959,
#    'JUDGEMENTAL': 0.2627563178539276}},
#  {'test_case': 'EXIST2025',
#   'id': '120926',
#   'value': {'NO': 0.5157594680786133,
#    'DIRECT': 0.3342140316963196,
#    'JUDGEMENTAL': 0.10273383557796478}},
#  {'test_case': 'EXIST2025',
#   'id': '120927',
#   'value': {'NO': 0.28717517852783203,
#    'DIRECT': 0.36281725764274597,
#    'JUDGEMENTAL': 0.30497869849205017}},
#  {'test_case': 'EXIST2025',
#   'id': '120928',
#   'value': {'NO': 0.8697679042816162,
#    'DIRECT': 0.12914404273033142,
#    'JUDGEMENTAL': 0.031089648604393005}},
#  {'test_case': 'EXIST2025',
#   'id': '120929',
#   'value': {'NO': 0.18985901772975922,
#    'DIRECT': 0.7889324426651001,
#    'JUDGEMENTAL': 0.19655776023864746}},
#  {'test_case': 'EXIST2025',
#   'id': '120930',
#   'value': {'NO': 0.13596831262111664,
#    'DIRECT': 0.818128764629364,
#    'JUDGEMENTAL': 0.24673038721084595}},
#  {'test_case': 'EXIST2025',
#   'id': '120931',
#   'value': {'NO': 0.7021246552467346,
#    'DIRECT': 0.41414687037467957,
#    'JUDGEMENTAL': 0.06739408522844315}},
#  {'test_case': 'EXIST2025',
#   'id': '120932',
#   'value': {'NO': 0.7446987628936768,
#    'DIRECT': 0.38271763920783997,
#    'JUDGEMENTAL': 0.032519761472940445}},
#  {'test_case': 'EXIST2025',
#   'id': '120933',
#   'value': {'NO': 0.1296735405921936,
#    'DIRECT': 0.5343847274780273,
#    'JUDGEMENTAL': 0.32040464878082275}},
#  {'test_case': 'EXIST2025',
#   'id': '120934',
#   'value': {'NO': 0.7950623035430908,
#    'DIRECT': 0.1799088567495346,
#    'JUDGEMENTAL': 0.04540129750967026}},
#  {'test_case': 'EXIST2025',
#   'id': '120935',
#   'value': {'NO': 0.11498339474201202,
#    'DIRECT': 0.7652633786201477,
#    'JUDGEMENTAL': 0.22908282279968262}},
#  {'test_case': 'EXIST2025',
#   'id': '120936',
#   'value': {'NO': 0.13308902084827423,
#    'DIRECT': 0.7945737242698669,
#    'JUDGEMENTAL': 0.2246152013540268}},
#  {'test_case': 'EXIST2025',
#   'id': '120937',
#   'value': {'NO': 0.39621487259864807,
#    'DIRECT': 0.5283616185188293,
#    'JUDGEMENTAL': 0.07961142063140869}},
#  {'test_case': 'EXIST2025',
#   'id': '120938',
#   'value': {'NO': 0.5859296321868896,
#    'DIRECT': 0.5453581809997559,
#    'JUDGEMENTAL': 0.039712194353342056}},
#  {'test_case': 'EXIST2025',
#   'id': '120939',
#   'value': {'NO': 0.08560674637556076,
#    'DIRECT': 0.68398517370224,
#    'JUDGEMENTAL': 0.299961119890213}},
#  {'test_case': 'EXIST2025',
#   'id': '120940',
#   'value': {'NO': 0.13779915869235992,
#    'DIRECT': 0.7891461849212646,
#    'JUDGEMENTAL': 0.17279984056949615}},
#  {'test_case': 'EXIST2025',
#   'id': '120941',
#   'value': {'NO': 0.4662463963031769,
#    'DIRECT': 0.30976712703704834,
#    'JUDGEMENTAL': 0.1087695062160492}},
#  {'test_case': 'EXIST2025',
#   'id': '120942',
#   'value': {'NO': 0.4530276656150818,
#    'DIRECT': 0.2850956916809082,
#    'JUDGEMENTAL': 0.2004321664571762}},
#  {'test_case': 'EXIST2025',
#   'id': '120943',
#   'value': {'NO': 0.1143948957324028,
#    'DIRECT': 0.7595089077949524,
#    'JUDGEMENTAL': 0.31751129031181335}},
#  {'test_case': 'EXIST2025',
#   'id': '120944',
#   'value': {'NO': 0.1416994333267212,
#    'DIRECT': 0.7740777134895325,
#    'JUDGEMENTAL': 0.245844304561615}},
#  {'test_case': 'EXIST2025',
#   'id': '120945',
#   'value': {'NO': 0.2711256444454193,
#    'DIRECT': 0.5926211476325989,
#    'JUDGEMENTAL': 0.18589863181114197}},
#  {'test_case': 'EXIST2025',
#   'id': '120946',
#   'value': {'NO': 0.7228738069534302,
#    'DIRECT': 0.24995926022529602,
#    'JUDGEMENTAL': 0.03570498153567314}},
#  {'test_case': 'EXIST2025',
#   'id': '120947',
#   'value': {'NO': 0.45530813932418823,
#    'DIRECT': 0.2868209183216095,
#    'JUDGEMENTAL': 0.23841865360736847}},
#  {'test_case': 'EXIST2025',
#   'id': '120948',
#   'value': {'NO': 0.7235920429229736,
#    'DIRECT': 0.16266916692256927,
#    'JUDGEMENTAL': 0.06338003277778625}},
#  {'test_case': 'EXIST2025',
#   'id': '120949',
#   'value': {'NO': 0.31005436182022095,
#    'DIRECT': 0.33073756098747253,
#    'JUDGEMENTAL': 0.3085527718067169}},
#  {'test_case': 'EXIST2025',
#   'id': '120950',
#   'value': {'NO': 0.16090795397758484,
#    'DIRECT': 0.3393102288246155,
#    'JUDGEMENTAL': 0.5374215245246887}},
#  {'test_case': 'EXIST2025',
#   'id': '120951',
#   'value': {'NO': 0.5240737795829773,
#    'DIRECT': 0.41794443130493164,
#    'JUDGEMENTAL': 0.057241879403591156}},
#  {'test_case': 'EXIST2025',
#   'id': '120952',
#   'value': {'NO': 0.32472532987594604,
#    'DIRECT': 0.6623154282569885,
#    'JUDGEMENTAL': 0.11951392889022827}},
#  {'test_case': 'EXIST2025',
#   'id': '120953',
#   'value': {'NO': 0.5781973004341125,
#    'DIRECT': 0.32441025972366333,
#    'JUDGEMENTAL': 0.04635041952133179}},
#  {'test_case': 'EXIST2025',
#   'id': '120954',
#   'value': {'NO': 0.2612007260322571,
#    'DIRECT': 0.6369951367378235,
#    'JUDGEMENTAL': 0.20326030254364014}},
#  {'test_case': 'EXIST2025',
#   'id': '120955',
#   'value': {'NO': 0.2331371307373047,
#    'DIRECT': 0.5466814041137695,
#    'JUDGEMENTAL': 0.2778269052505493}},
#  {'test_case': 'EXIST2025',
#   'id': '120956',
#   'value': {'NO': 0.5664937496185303,
#    'DIRECT': 0.3652050495147705,
#    'JUDGEMENTAL': 0.07513633370399475}},
#  {'test_case': 'EXIST2025',
#   'id': '120957',
#   'value': {'NO': 0.1067097932100296,
#    'DIRECT': 0.2841250002384186,
#    'JUDGEMENTAL': 0.6559990048408508}},
#  {'test_case': 'EXIST2025',
#   'id': '120958',
#   'value': {'NO': 0.462205171585083,
#    'DIRECT': 0.3808196187019348,
#    'JUDGEMENTAL': 0.13983340561389923}},
#  {'test_case': 'EXIST2025',
#   'id': '120959',
#   'value': {'NO': 0.11972136795520782,
#    'DIRECT': 0.593941330909729,
#    'JUDGEMENTAL': 0.33732566237449646}},
#  {'test_case': 'EXIST2025',
#   'id': '120960',
#   'value': {'NO': 0.1531820297241211,
#    'DIRECT': 0.7935572266578674,
#    'JUDGEMENTAL': 0.20661498606204987}},
#  {'test_case': 'EXIST2025',
#   'id': '120961',
#   'value': {'NO': 0.1620401293039322,
#    'DIRECT': 0.6479871273040771,
#    'JUDGEMENTAL': 0.27752912044525146}},
#  {'test_case': 'EXIST2025',
#   'id': '120962',
#   'value': {'NO': 0.12066522985696793,
#    'DIRECT': 0.6514744758605957,
#    'JUDGEMENTAL': 0.24412773549556732}},
#  {'test_case': 'EXIST2025',
#   'id': '120963',
#   'value': {'NO': 0.5123588442802429,
#    'DIRECT': 0.5004054307937622,
#    'JUDGEMENTAL': 0.05883093550801277}},
#  {'test_case': 'EXIST2025',
#   'id': '120964',
#   'value': {'NO': 0.2372831106185913,
#    'DIRECT': 0.6605221629142761,
#    'JUDGEMENTAL': 0.13434791564941406}},
#  {'test_case': 'EXIST2025',
#   'id': '120965',
#   'value': {'NO': 0.2402094006538391,
#    'DIRECT': 0.6140240430831909,
#    'JUDGEMENTAL': 0.13424934446811676}},
#  {'test_case': 'EXIST2025',
#   'id': '120966',
#   'value': {'NO': 0.5884773135185242,
#    'DIRECT': 0.2245359718799591,
#    'JUDGEMENTAL': 0.09283587336540222}},
#  {'test_case': 'EXIST2025',
#   'id': '120967',
#   'value': {'NO': 0.45391353964805603,
#    'DIRECT': 0.27951207756996155,
#    'JUDGEMENTAL': 0.15833842754364014}},
#  {'test_case': 'EXIST2025',
#   'id': '120968',
#   'value': {'NO': 0.22033214569091797,
#    'DIRECT': 0.6419496536254883,
#    'JUDGEMENTAL': 0.16843360662460327}},
#  {'test_case': 'EXIST2025',
#   'id': '120969',
#   'value': {'NO': 0.810072124004364,
#    'DIRECT': 0.5332714319229126,
#    'JUDGEMENTAL': 0.2091730237007141}},
#  {'test_case': 'EXIST2025',
#   'id': '120970',
#   'value': {'NO': 0.8940529227256775,
#    'DIRECT': 0.11419937014579773,
#    'JUDGEMENTAL': 0.05189406871795654}},
#  {'test_case': 'EXIST2025',
#   'id': '120971',
#   'value': {'NO': 0.4338702857494354,
#    'DIRECT': 0.48283910751342773,
#    'JUDGEMENTAL': 0.08874042332172394}},
#  {'test_case': 'EXIST2025',
#   'id': '120972',
#   'value': {'NO': 0.22010686993598938,
#    'DIRECT': 0.6643107533454895,
#    'JUDGEMENTAL': 0.13981135189533234}},
#  {'test_case': 'EXIST2025',
#   'id': '120973',
#   'value': {'NO': 0.34363168478012085,
#    'DIRECT': 0.37716713547706604,
#    'JUDGEMENTAL': 0.16736967861652374}},
#  {'test_case': 'EXIST2025',
#   'id': '120974',
#   'value': {'NO': 0.8040053844451904,
#    'DIRECT': 0.29167184233665466,
#    'JUDGEMENTAL': 0.02561809867620468}},
#  {'test_case': 'EXIST2025',
#   'id': '120975',
#   'value': {'NO': 0.9090961217880249,
#    'DIRECT': 0.1255604773759842,
#    'JUDGEMENTAL': 0.024354731664061546}},
#  {'test_case': 'EXIST2025',
#   'id': '120976',
#   'value': {'NO': 0.4019711911678314,
#    'DIRECT': 0.3062029182910919,
#    'JUDGEMENTAL': 0.24671661853790283}},
#  {'test_case': 'EXIST2025',
#   'id': '120977',
#   'value': {'NO': 0.5720919370651245,
#    'DIRECT': 0.40239641070365906,
#    'JUDGEMENTAL': 0.04695434123277664}},
#  {'test_case': 'EXIST2025',
#   'id': '120978',
#   'value': {'NO': 0.34869661927223206,
#    'DIRECT': 0.47470590472221375,
#    'JUDGEMENTAL': 0.18226900696754456}},
#  {'test_case': 'EXIST2025',
#   'id': '120979',
#   'value': {'NO': 0.4812960922718048,
#    'DIRECT': 0.3935815989971161,
#    'JUDGEMENTAL': 0.11686993390321732}},
#  {'test_case': 'EXIST2025',
#   'id': '120980',
#   'value': {'NO': 0.18684318661689758,
#    'DIRECT': 0.49357736110687256,
#    'JUDGEMENTAL': 0.20666679739952087}},
#  {'test_case': 'EXIST2025',
#   'id': '120981',
#   'value': {'NO': 0.8676213026046753,
#    'DIRECT': 0.10995882004499435,
#    'JUDGEMENTAL': 0.037651605904102325}},
#  {'test_case': 'EXIST2025',
#   'id': '120982',
#   'value': {'NO': 0.21915923058986664,
#    'DIRECT': 0.4826177656650543,
#    'JUDGEMENTAL': 0.15802566707134247}},
#  {'test_case': 'EXIST2025',
#   'id': '120983',
#   'value': {'NO': 0.8536390066146851,
#    'DIRECT': 0.09650055319070816,
#    'JUDGEMENTAL': 0.08509507030248642}},
#  {'test_case': 'EXIST2025',
#   'id': '120984',
#   'value': {'NO': 0.15225602686405182,
#    'DIRECT': 0.41579774022102356,
#    'JUDGEMENTAL': 0.3478197455406189}},
#  {'test_case': 'EXIST2025',
#   'id': '120985',
#   'value': {'NO': 0.3129202425479889,
#    'DIRECT': 0.43015626072883606,
#    'JUDGEMENTAL': 0.23208118975162506}},
#  {'test_case': 'EXIST2025',
#   'id': '120986',
#   'value': {'NO': 0.5366631746292114,
#    'DIRECT': 0.27936211228370667,
#    'JUDGEMENTAL': 0.11344112455844879}},
#  {'test_case': 'EXIST2025',
#   'id': '120987',
#   'value': {'NO': 0.8484722375869751,
#    'DIRECT': 0.19088442623615265,
#    'JUDGEMENTAL': 0.044643301516771317}},
#  {'test_case': 'EXIST2025',
#   'id': '120988',
#   'value': {'NO': 0.2971222400665283,
#    'DIRECT': 0.40454211831092834,
#    'JUDGEMENTAL': 0.3005220890045166}},
#  {'test_case': 'EXIST2025',
#   'id': '120989',
#   'value': {'NO': 0.14575500786304474,
#    'DIRECT': 0.5690937638282776,
#    'JUDGEMENTAL': 0.21490193903446198}},
#  {'test_case': 'EXIST2025',
#   'id': '120990',
#   'value': {'NO': 0.8937302231788635,
#    'DIRECT': 0.08701442182064056,
#    'JUDGEMENTAL': 0.03910205140709877}},
#  {'test_case': 'EXIST2025',
#   'id': '120991',
#   'value': {'NO': 0.8009459972381592,
#    'DIRECT': 0.21355979144573212,
#    'JUDGEMENTAL': 0.05091320723295212}},
#  {'test_case': 'EXIST2025',
#   'id': '120992',
#   'value': {'NO': 0.743695855140686,
#    'DIRECT': 0.19813652336597443,
#    'JUDGEMENTAL': 0.07191621512174606}},
#  {'test_case': 'EXIST2025',
#   'id': '120993',
#   'value': {'NO': 0.597757875919342,
#    'DIRECT': 0.3239872455596924,
#    'JUDGEMENTAL': 0.060398779809474945}},
#  {'test_case': 'EXIST2025',
#   'id': '120994',
#   'value': {'NO': 0.3243183493614197,
#    'DIRECT': 0.39190611243247986,
#    'JUDGEMENTAL': 0.2105744630098343}},
#  {'test_case': 'EXIST2025',
#   'id': '120995',
#   'value': {'NO': 0.6944093108177185,
#    'DIRECT': 0.1396401822566986,
#    'JUDGEMENTAL': 0.08178998529911041}},
#  {'test_case': 'EXIST2025',
#   'id': '120996',
#   'value': {'NO': 0.32535862922668457,
#    'DIRECT': 0.4168674051761627,
#    'JUDGEMENTAL': 0.2013099491596222}},
#  {'test_case': 'EXIST2025',
#   'id': '120997',
#   'value': {'NO': 0.08882082998752594,
#    'DIRECT': 0.4733016788959503,
#    'JUDGEMENTAL': 0.4424010217189789}},
#  {'test_case': 'EXIST2025',
#   'id': '120998',
#   'value': {'NO': 0.7868306636810303,
#    'DIRECT': 0.12739792466163635,
#    'JUDGEMENTAL': 0.09189952909946442}},
#  {'test_case': 'EXIST2025',
#   'id': '120999',
#   'value': {'NO': 0.6113570928573608,
#    'DIRECT': 0.233234703540802,
#    'JUDGEMENTAL': 0.0905720591545105}},
#  {'test_case': 'EXIST2025',
#   'id': '121000',
#   'value': {'NO': 0.12704885005950928,
#    'DIRECT': 0.7065964341163635,
#    'JUDGEMENTAL': 0.25668177008628845}},
#  ...]

# %%
bert3 = Test(soft=True, model_name="hate-speech-CNERG/bert-base-uncased-hatexplain", label_name="label3")
bert3.train(epochs=3)
bert3.build_submission(task_name="task3_3",run=2)
# Out:
# Map:   0%|          | 0/2145 [00:00<?, ? examples/s]
# Map:   0%|          | 0/379 [00:00<?, ? examples/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hate-speech-CNERG/bert-base-uncased-hatexplain and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([3, 768]) in the checkpoint and torch.Size([6, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([3]) in the checkpoint and torch.Size([6]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-4-54a9ba2e44c6>:136: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   self.trainer = Trainer(
#     <div>
#
#       <progress value='807' max='807' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [807/807 03:53, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mae</th>
#       <th>Logloss</th>
#       <th>F1 Micro</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.322942</td>
#       <td>0.172009</td>
#       <td>0.323410</td>
#       <td>0.863237</td>
#       <td>0.120968</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.341500</td>
#       <td>0.310256</td>
#       <td>0.156942</td>
#       <td>0.303119</td>
#       <td>0.870273</td>
#       <td>0.130478</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.341500</td>
#       <td>0.313652</td>
#       <td>0.157075</td>
#       <td>0.304277</td>
#       <td>0.873791</td>
#       <td>0.166078</td>
#     </tr>
#   </tbody>
# </table><p>
# Submission saved to task3_3_soft_ScalaR_2.json
# [{'test_case': 'EXIST2025',
#   'id': '120001',
#   'value': {'NO': 0.8136799931526184,
#    'IDEOLOGICAL-INEQUALITY': 0.02814907394349575,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02100774459540844,
#    'OBJECTIFICATION': 0.06081663817167282,
#    'SEXUAL-VIOLENCE': 0.023641666397452354,
#    'STEREOTYPING-DOMINANCE': 0.0880696177482605}},
#  {'test_case': 'EXIST2025',
#   'id': '120002',
#   'value': {'NO': 0.7127540111541748,
#    'IDEOLOGICAL-INEQUALITY': 0.050591424107551575,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02621469832956791,
#    'OBJECTIFICATION': 0.05364593118429184,
#    'SEXUAL-VIOLENCE': 0.02907707542181015,
#    'STEREOTYPING-DOMINANCE': 0.10909833759069443}},
#  {'test_case': 'EXIST2025',
#   'id': '120003',
#   'value': {'NO': 0.3495138883590698,
#    'IDEOLOGICAL-INEQUALITY': 0.17356429994106293,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.055212683975696564,
#    'OBJECTIFICATION': 0.05426902323961258,
#    'SEXUAL-VIOLENCE': 0.04155711084604263,
#    'STEREOTYPING-DOMINANCE': 0.24586300551891327}},
#  {'test_case': 'EXIST2025',
#   'id': '120004',
#   'value': {'NO': 0.13648869097232819,
#    'IDEOLOGICAL-INEQUALITY': 0.2440418303012848,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08141793310642242,
#    'OBJECTIFICATION': 0.08318350464105606,
#    'SEXUAL-VIOLENCE': 0.05290758237242699,
#    'STEREOTYPING-DOMINANCE': 0.5861950516700745}},
#  {'test_case': 'EXIST2025',
#   'id': '120005',
#   'value': {'NO': 0.4729788899421692,
#    'IDEOLOGICAL-INEQUALITY': 0.08190914988517761,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03617381677031517,
#    'OBJECTIFICATION': 0.06161560118198395,
#    'SEXUAL-VIOLENCE': 0.03103540651500225,
#    'STEREOTYPING-DOMINANCE': 0.18885193765163422}},
#  {'test_case': 'EXIST2025',
#   'id': '120006',
#   'value': {'NO': 0.5547012090682983,
#    'IDEOLOGICAL-INEQUALITY': 0.07004925608634949,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.029109060764312744,
#    'OBJECTIFICATION': 0.04498901218175888,
#    'SEXUAL-VIOLENCE': 0.02428441122174263,
#    'STEREOTYPING-DOMINANCE': 0.19143955409526825}},
#  {'test_case': 'EXIST2025',
#   'id': '120007',
#   'value': {'NO': 0.11445537209510803,
#    'IDEOLOGICAL-INEQUALITY': 0.4406646192073822,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.11853238195180893,
#    'OBJECTIFICATION': 0.1019471138715744,
#    'SEXUAL-VIOLENCE': 0.08612657338380814,
#    'STEREOTYPING-DOMINANCE': 0.32209745049476624}},
#  {'test_case': 'EXIST2025',
#   'id': '120008',
#   'value': {'NO': 0.1142834722995758,
#    'IDEOLOGICAL-INEQUALITY': 0.4030810296535492,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.10262573510408401,
#    'OBJECTIFICATION': 0.08601711690425873,
#    'SEXUAL-VIOLENCE': 0.07033076137304306,
#    'STEREOTYPING-DOMINANCE': 0.33306074142456055}},
#  {'test_case': 'EXIST2025',
#   'id': '120009',
#   'value': {'NO': 0.48149147629737854,
#    'IDEOLOGICAL-INEQUALITY': 0.09916224330663681,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03932984545826912,
#    'OBJECTIFICATION': 0.054334044456481934,
#    'SEXUAL-VIOLENCE': 0.030628284439444542,
#    'STEREOTYPING-DOMINANCE': 0.22410818934440613}},
#  {'test_case': 'EXIST2025',
#   'id': '120010',
#   'value': {'NO': 0.3423343598842621,
#    'IDEOLOGICAL-INEQUALITY': 0.18584424257278442,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05819147825241089,
#    'OBJECTIFICATION': 0.06261902302503586,
#    'SEXUAL-VIOLENCE': 0.05041759833693504,
#    'STEREOTYPING-DOMINANCE': 0.23357047140598297}},
#  {'test_case': 'EXIST2025',
#   'id': '120011',
#   'value': {'NO': 0.34660953283309937,
#    'IDEOLOGICAL-INEQUALITY': 0.25026407837867737,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08341306447982788,
#    'OBJECTIFICATION': 0.07652159780263901,
#    'SEXUAL-VIOLENCE': 0.06574961543083191,
#    'STEREOTYPING-DOMINANCE': 0.23595553636550903}},
#  {'test_case': 'EXIST2025',
#   'id': '120012',
#   'value': {'NO': 0.5880201458930969,
#    'IDEOLOGICAL-INEQUALITY': 0.06357868760824203,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.029968619346618652,
#    'OBJECTIFICATION': 0.05297177657485008,
#    'SEXUAL-VIOLENCE': 0.025128120556473732,
#    'STEREOTYPING-DOMINANCE': 0.19280360639095306}},
#  {'test_case': 'EXIST2025',
#   'id': '120013',
#   'value': {'NO': 0.2671721875667572,
#    'IDEOLOGICAL-INEQUALITY': 0.1338576078414917,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04587651416659355,
#    'OBJECTIFICATION': 0.049504972994327545,
#    'SEXUAL-VIOLENCE': 0.028264552354812622,
#    'STEREOTYPING-DOMINANCE': 0.48043760657310486}},
#  {'test_case': 'EXIST2025',
#   'id': '120014',
#   'value': {'NO': 0.17158560454845428,
#    'IDEOLOGICAL-INEQUALITY': 0.21876269578933716,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.06743551790714264,
#    'OBJECTIFICATION': 0.07846133410930634,
#    'SEXUAL-VIOLENCE': 0.045492738485336304,
#    'STEREOTYPING-DOMINANCE': 0.5214409828186035}},
#  {'test_case': 'EXIST2025',
#   'id': '120015',
#   'value': {'NO': 0.8166536092758179,
#    'IDEOLOGICAL-INEQUALITY': 0.029222926124930382,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.023037945851683617,
#    'OBJECTIFICATION': 0.06014262139797211,
#    'SEXUAL-VIOLENCE': 0.023790402337908745,
#    'STEREOTYPING-DOMINANCE': 0.09505670517683029}},
#  {'test_case': 'EXIST2025',
#   'id': '120016',
#   'value': {'NO': 0.11826413869857788,
#    'IDEOLOGICAL-INEQUALITY': 0.43650826811790466,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.1094735860824585,
#    'OBJECTIFICATION': 0.09148717671632767,
#    'SEXUAL-VIOLENCE': 0.08038536459207535,
#    'STEREOTYPING-DOMINANCE': 0.34309032559394836}},
#  {'test_case': 'EXIST2025',
#   'id': '120017',
#   'value': {'NO': 0.7681506872177124,
#    'IDEOLOGICAL-INEQUALITY': 0.037075288593769073,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.026740165427327156,
#    'OBJECTIFICATION': 0.06892931461334229,
#    'SEXUAL-VIOLENCE': 0.02944469265639782,
#    'STEREOTYPING-DOMINANCE': 0.10630200058221817}},
#  {'test_case': 'EXIST2025',
#   'id': '120018',
#   'value': {'NO': 0.7143297791481018,
#    'IDEOLOGICAL-INEQUALITY': 0.052484989166259766,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03164711222052574,
#    'OBJECTIFICATION': 0.05853565037250519,
#    'SEXUAL-VIOLENCE': 0.02751283161342144,
#    'STEREOTYPING-DOMINANCE': 0.20437179505825043}},
#  {'test_case': 'EXIST2025',
#   'id': '120019',
#   'value': {'NO': 0.8284735083580017,
#    'IDEOLOGICAL-INEQUALITY': 0.02672186680138111,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02442166395485401,
#    'OBJECTIFICATION': 0.06795943528413773,
#    'SEXUAL-VIOLENCE': 0.025536851957440376,
#    'STEREOTYPING-DOMINANCE': 0.09754138439893723}},
#  {'test_case': 'EXIST2025',
#   'id': '120020',
#   'value': {'NO': 0.2553975582122803,
#    'IDEOLOGICAL-INEQUALITY': 0.19349142909049988,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04277840629220009,
#    'OBJECTIFICATION': 0.05708811432123184,
#    'SEXUAL-VIOLENCE': 0.03512932360172272,
#    'STEREOTYPING-DOMINANCE': 0.23148880898952484}},
#  {'test_case': 'EXIST2025',
#   'id': '120021',
#   'value': {'NO': 0.5546026229858398,
#    'IDEOLOGICAL-INEQUALITY': 0.07840567082166672,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0344381146132946,
#    'OBJECTIFICATION': 0.05592682585120201,
#    'SEXUAL-VIOLENCE': 0.029420463368296623,
#    'STEREOTYPING-DOMINANCE': 0.18698637187480927}},
#  {'test_case': 'EXIST2025',
#   'id': '120022',
#   'value': {'NO': 0.11781074851751328,
#    'IDEOLOGICAL-INEQUALITY': 0.4617152512073517,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.13084371387958527,
#    'OBJECTIFICATION': 0.12379981577396393,
#    'SEXUAL-VIOLENCE': 0.10116322338581085,
#    'STEREOTYPING-DOMINANCE': 0.29912373423576355}},
#  {'test_case': 'EXIST2025',
#   'id': '120023',
#   'value': {'NO': 0.6536917686462402,
#    'IDEOLOGICAL-INEQUALITY': 0.07470200210809708,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03414083644747734,
#    'OBJECTIFICATION': 0.06595710664987564,
#    'SEXUAL-VIOLENCE': 0.042803455144166946,
#    'STEREOTYPING-DOMINANCE': 0.1039750799536705}},
#  {'test_case': 'EXIST2025',
#   'id': '120024',
#   'value': {'NO': 0.7115848660469055,
#    'IDEOLOGICAL-INEQUALITY': 0.04744460806250572,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02704913541674614,
#    'OBJECTIFICATION': 0.06131555885076523,
#    'SEXUAL-VIOLENCE': 0.02806059643626213,
#    'STEREOTYPING-DOMINANCE': 0.12481347471475601}},
#  {'test_case': 'EXIST2025',
#   'id': '120025',
#   'value': {'NO': 0.48768097162246704,
#    'IDEOLOGICAL-INEQUALITY': 0.09681166708469391,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03564496710896492,
#    'OBJECTIFICATION': 0.053880590945482254,
#    'SEXUAL-VIOLENCE': 0.03212035819888115,
#    'STEREOTYPING-DOMINANCE': 0.19300207495689392}},
#  {'test_case': 'EXIST2025',
#   'id': '120026',
#   'value': {'NO': 0.25401997566223145,
#    'IDEOLOGICAL-INEQUALITY': 0.1933315247297287,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05347453057765961,
#    'OBJECTIFICATION': 0.05543078854680061,
#    'SEXUAL-VIOLENCE': 0.035975381731987,
#    'STEREOTYPING-DOMINANCE': 0.34862592816352844}},
#  {'test_case': 'EXIST2025',
#   'id': '120027',
#   'value': {'NO': 0.7165788412094116,
#    'IDEOLOGICAL-INEQUALITY': 0.03986997529864311,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02551743946969509,
#    'OBJECTIFICATION': 0.05222298577427864,
#    'SEXUAL-VIOLENCE': 0.023103056475520134,
#    'STEREOTYPING-DOMINANCE': 0.20540659129619598}},
#  {'test_case': 'EXIST2025',
#   'id': '120028',
#   'value': {'NO': 0.3669109046459198,
#    'IDEOLOGICAL-INEQUALITY': 0.1514655202627182,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.043177325278520584,
#    'OBJECTIFICATION': 0.058585960417985916,
#    'SEXUAL-VIOLENCE': 0.039788298308849335,
#    'STEREOTYPING-DOMINANCE': 0.18283848464488983}},
#  {'test_case': 'EXIST2025',
#   'id': '120029',
#   'value': {'NO': 0.38599368929862976,
#    'IDEOLOGICAL-INEQUALITY': 0.10903310030698776,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03924179449677467,
#    'OBJECTIFICATION': 0.06572264432907104,
#    'SEXUAL-VIOLENCE': 0.03141099587082863,
#    'STEREOTYPING-DOMINANCE': 0.3497251570224762}},
#  {'test_case': 'EXIST2025',
#   'id': '120030',
#   'value': {'NO': 0.42104241251945496,
#    'IDEOLOGICAL-INEQUALITY': 0.12383303046226501,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04607583209872246,
#    'OBJECTIFICATION': 0.061876121908426285,
#    'SEXUAL-VIOLENCE': 0.03987062722444534,
#    'STEREOTYPING-DOMINANCE': 0.22074508666992188}},
#  {'test_case': 'EXIST2025',
#   'id': '120031',
#   'value': {'NO': 0.14481601119041443,
#    'IDEOLOGICAL-INEQUALITY': 0.3823826313018799,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.09493432939052582,
#    'OBJECTIFICATION': 0.080684132874012,
#    'SEXUAL-VIOLENCE': 0.06682562083005905,
#    'STEREOTYPING-DOMINANCE': 0.28514236211776733}},
#  {'test_case': 'EXIST2025',
#   'id': '120032',
#   'value': {'NO': 0.7414986491203308,
#    'IDEOLOGICAL-INEQUALITY': 0.03978155180811882,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0249286238104105,
#    'OBJECTIFICATION': 0.052352093160152435,
#    'SEXUAL-VIOLENCE': 0.021967513486742973,
#    'STEREOTYPING-DOMINANCE': 0.16817431151866913}},
#  {'test_case': 'EXIST2025',
#   'id': '120033',
#   'value': {'NO': 0.5272731781005859,
#    'IDEOLOGICAL-INEQUALITY': 0.060402970761060715,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02597227320075035,
#    'OBJECTIFICATION': 0.04603810980916023,
#    'SEXUAL-VIOLENCE': 0.019144997000694275,
#    'STEREOTYPING-DOMINANCE': 0.21165065467357635}},
#  {'test_case': 'EXIST2025',
#   'id': '120034',
#   'value': {'NO': 0.4880586862564087,
#    'IDEOLOGICAL-INEQUALITY': 0.07380680739879608,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.030536571517586708,
#    'OBJECTIFICATION': 0.05198455974459648,
#    'SEXUAL-VIOLENCE': 0.024327268823981285,
#    'STEREOTYPING-DOMINANCE': 0.24193666875362396}},
#  {'test_case': 'EXIST2025',
#   'id': '120035',
#   'value': {'NO': 0.338286429643631,
#    'IDEOLOGICAL-INEQUALITY': 0.17531916499137878,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.052250053733587265,
#    'OBJECTIFICATION': 0.05650896951556206,
#    'SEXUAL-VIOLENCE': 0.04277294874191284,
#    'STEREOTYPING-DOMINANCE': 0.2792268395423889}},
#  {'test_case': 'EXIST2025',
#   'id': '120036',
#   'value': {'NO': 0.8444682359695435,
#    'IDEOLOGICAL-INEQUALITY': 0.030244138091802597,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.026958128437399864,
#    'OBJECTIFICATION': 0.07538234442472458,
#    'SEXUAL-VIOLENCE': 0.030622392892837524,
#    'STEREOTYPING-DOMINANCE': 0.0824011042714119}},
#  {'test_case': 'EXIST2025',
#   'id': '120037',
#   'value': {'NO': 0.3289754390716553,
#    'IDEOLOGICAL-INEQUALITY': 0.25158604979515076,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08285605907440186,
#    'OBJECTIFICATION': 0.07598213851451874,
#    'SEXUAL-VIOLENCE': 0.06146121397614479,
#    'STEREOTYPING-DOMINANCE': 0.26423153281211853}},
#  {'test_case': 'EXIST2025',
#   'id': '120038',
#   'value': {'NO': 0.8332875370979309,
#    'IDEOLOGICAL-INEQUALITY': 0.03162383288145065,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.025135578587651253,
#    'OBJECTIFICATION': 0.06393685936927795,
#    'SEXUAL-VIOLENCE': 0.029794711619615555,
#    'STEREOTYPING-DOMINANCE': 0.08029449731111526}},
#  {'test_case': 'EXIST2025',
#   'id': '120039',
#   'value': {'NO': 0.6957164406776428,
#    'IDEOLOGICAL-INEQUALITY': 0.0668889507651329,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03646671772003174,
#    'OBJECTIFICATION': 0.06890697032213211,
#    'SEXUAL-VIOLENCE': 0.04395097866654396,
#    'STEREOTYPING-DOMINANCE': 0.09916824102401733}},
#  {'test_case': 'EXIST2025',
#   'id': '120040',
#   'value': {'NO': 0.20532500743865967,
#    'IDEOLOGICAL-INEQUALITY': 0.30617886781692505,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.07376040518283844,
#    'OBJECTIFICATION': 0.07340283691883087,
#    'SEXUAL-VIOLENCE': 0.06350523233413696,
#    'STEREOTYPING-DOMINANCE': 0.23017221689224243}},
#  {'test_case': 'EXIST2025',
#   'id': '120041',
#   'value': {'NO': 0.5427380204200745,
#    'IDEOLOGICAL-INEQUALITY': 0.09192223101854324,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03405490145087242,
#    'OBJECTIFICATION': 0.06297173351049423,
#    'SEXUAL-VIOLENCE': 0.03477458283305168,
#    'STEREOTYPING-DOMINANCE': 0.20896005630493164}},
#  {'test_case': 'EXIST2025',
#   'id': '120042',
#   'value': {'NO': 0.11224769800901413,
#    'IDEOLOGICAL-INEQUALITY': 0.4130558371543884,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.10462920367717743,
#    'OBJECTIFICATION': 0.09267306327819824,
#    'SEXUAL-VIOLENCE': 0.07392027229070663,
#    'STEREOTYPING-DOMINANCE': 0.3127865195274353}},
#  {'test_case': 'EXIST2025',
#   'id': '120043',
#   'value': {'NO': 0.5933932662010193,
#    'IDEOLOGICAL-INEQUALITY': 0.08938884735107422,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04927283152937889,
#    'OBJECTIFICATION': 0.06641939282417297,
#    'SEXUAL-VIOLENCE': 0.04334704950451851,
#    'STEREOTYPING-DOMINANCE': 0.16392163932323456}},
#  {'test_case': 'EXIST2025',
#   'id': '120044',
#   'value': {'NO': 0.2858332395553589,
#    'IDEOLOGICAL-INEQUALITY': 0.12784990668296814,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05502721667289734,
#    'OBJECTIFICATION': 0.06135314330458641,
#    'SEXUAL-VIOLENCE': 0.03784027323126793,
#    'STEREOTYPING-DOMINANCE': 0.563438355922699}},
#  {'test_case': 'EXIST2025',
#   'id': '120045',
#   'value': {'NO': 0.10406125336885452,
#    'IDEOLOGICAL-INEQUALITY': 0.3874584138393402,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.09933231770992279,
#    'OBJECTIFICATION': 0.08438168466091156,
#    'SEXUAL-VIOLENCE': 0.06531772017478943,
#    'STEREOTYPING-DOMINANCE': 0.4387538731098175}},
#  {'test_case': 'EXIST2025',
#   'id': '120046',
#   'value': {'NO': 0.6422839760780334,
#    'IDEOLOGICAL-INEQUALITY': 0.05111227557063103,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02702075056731701,
#    'OBJECTIFICATION': 0.04616894572973251,
#    'SEXUAL-VIOLENCE': 0.02191862091422081,
#    'STEREOTYPING-DOMINANCE': 0.21325483918190002}},
#  {'test_case': 'EXIST2025',
#   'id': '120047',
#   'value': {'NO': 0.1380000114440918,
#    'IDEOLOGICAL-INEQUALITY': 0.3908085227012634,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.09852480888366699,
#    'OBJECTIFICATION': 0.08993716537952423,
#    'SEXUAL-VIOLENCE': 0.06945037841796875,
#    'STEREOTYPING-DOMINANCE': 0.29517892003059387}},
#  {'test_case': 'EXIST2025',
#   'id': '120048',
#   'value': {'NO': 0.2292502075433731,
#    'IDEOLOGICAL-INEQUALITY': 0.19732792675495148,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05607784166932106,
#    'OBJECTIFICATION': 0.059658631682395935,
#    'SEXUAL-VIOLENCE': 0.039497341960668564,
#    'STEREOTYPING-DOMINANCE': 0.48048099875450134}},
#  {'test_case': 'EXIST2025',
#   'id': '120049',
#   'value': {'NO': 0.8183403611183167,
#    'IDEOLOGICAL-INEQUALITY': 0.03333720937371254,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.022319795563817024,
#    'OBJECTIFICATION': 0.06566529721021652,
#    'SEXUAL-VIOLENCE': 0.028019119054079056,
#    'STEREOTYPING-DOMINANCE': 0.09331578761339188}},
#  {'test_case': 'EXIST2025',
#   'id': '120050',
#   'value': {'NO': 0.25982314348220825,
#    'IDEOLOGICAL-INEQUALITY': 0.2122616171836853,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05701472982764244,
#    'OBJECTIFICATION': 0.06651566922664642,
#    'SEXUAL-VIOLENCE': 0.04309038445353508,
#    'STEREOTYPING-DOMINANCE': 0.4125291109085083}},
#  {'test_case': 'EXIST2025',
#   'id': '120051',
#   'value': {'NO': 0.254464328289032,
#    'IDEOLOGICAL-INEQUALITY': 0.26068276166915894,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.07284785807132721,
#    'OBJECTIFICATION': 0.06424900889396667,
#    'SEXUAL-VIOLENCE': 0.0524238683283329,
#    'STEREOTYPING-DOMINANCE': 0.3300773799419403}},
#  {'test_case': 'EXIST2025',
#   'id': '120052',
#   'value': {'NO': 0.8048406839370728,
#    'IDEOLOGICAL-INEQUALITY': 0.03485375642776489,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.022667866200208664,
#    'OBJECTIFICATION': 0.0588504821062088,
#    'SEXUAL-VIOLENCE': 0.028302526101469994,
#    'STEREOTYPING-DOMINANCE': 0.08237574249505997}},
#  {'test_case': 'EXIST2025',
#   'id': '120053',
#   'value': {'NO': 0.5950204730033875,
#    'IDEOLOGICAL-INEQUALITY': 0.07455874979496002,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.035296693444252014,
#    'OBJECTIFICATION': 0.05498501658439636,
#    'SEXUAL-VIOLENCE': 0.0346299484372139,
#    'STEREOTYPING-DOMINANCE': 0.15415234863758087}},
#  {'test_case': 'EXIST2025',
#   'id': '120054',
#   'value': {'NO': 0.8639143109321594,
#    'IDEOLOGICAL-INEQUALITY': 0.03026222437620163,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.026576627045869827,
#    'OBJECTIFICATION': 0.0853143185377121,
#    'SEXUAL-VIOLENCE': 0.033908456563949585,
#    'STEREOTYPING-DOMINANCE': 0.07674907147884369}},
#  {'test_case': 'EXIST2025',
#   'id': '120055',
#   'value': {'NO': 0.23219846189022064,
#    'IDEOLOGICAL-INEQUALITY': 0.2882978916168213,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.07562234997749329,
#    'OBJECTIFICATION': 0.0736105740070343,
#    'SEXUAL-VIOLENCE': 0.06059252843260765,
#    'STEREOTYPING-DOMINANCE': 0.26948603987693787}},
#  {'test_case': 'EXIST2025',
#   'id': '120056',
#   'value': {'NO': 0.1092173159122467,
#    'IDEOLOGICAL-INEQUALITY': 0.48961612582206726,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.12059178948402405,
#    'OBJECTIFICATION': 0.11112863570451736,
#    'SEXUAL-VIOLENCE': 0.10720948874950409,
#    'STEREOTYPING-DOMINANCE': 0.26442164182662964}},
#  {'test_case': 'EXIST2025',
#   'id': '120057',
#   'value': {'NO': 0.12228856235742569,
#    'IDEOLOGICAL-INEQUALITY': 0.4310130178928375,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.1057247519493103,
#    'OBJECTIFICATION': 0.08868198841810226,
#    'SEXUAL-VIOLENCE': 0.08371420949697495,
#    'STEREOTYPING-DOMINANCE': 0.29651540517807007}},
#  {'test_case': 'EXIST2025',
#   'id': '120058',
#   'value': {'NO': 0.11726824194192886,
#    'IDEOLOGICAL-INEQUALITY': 0.48527729511260986,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.11353950947523117,
#    'OBJECTIFICATION': 0.11045283079147339,
#    'SEXUAL-VIOLENCE': 0.09921476989984512,
#    'STEREOTYPING-DOMINANCE': 0.2589896619319916}},
#  {'test_case': 'EXIST2025',
#   'id': '120059',
#   'value': {'NO': 0.7438941597938538,
#    'IDEOLOGICAL-INEQUALITY': 0.03675411641597748,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.022041909396648407,
#    'OBJECTIFICATION': 0.05838354676961899,
#    'SEXUAL-VIOLENCE': 0.024285102263092995,
#    'STEREOTYPING-DOMINANCE': 0.1033942922949791}},
#  {'test_case': 'EXIST2025',
#   'id': '120060',
#   'value': {'NO': 0.24799619615077972,
#    'IDEOLOGICAL-INEQUALITY': 0.20516572892665863,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05693095549941063,
#    'OBJECTIFICATION': 0.06285440921783447,
#    'SEXUAL-VIOLENCE': 0.04300219565629959,
#    'STEREOTYPING-DOMINANCE': 0.3952758014202118}},
#  {'test_case': 'EXIST2025',
#   'id': '120061',
#   'value': {'NO': 0.20790591835975647,
#    'IDEOLOGICAL-INEQUALITY': 0.2080858051776886,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05704590678215027,
#    'OBJECTIFICATION': 0.07322224974632263,
#    'SEXUAL-VIOLENCE': 0.04215140640735626,
#    'STEREOTYPING-DOMINANCE': 0.43188977241516113}},
#  {'test_case': 'EXIST2025',
#   'id': '120062',
#   'value': {'NO': 0.25645914673805237,
#    'IDEOLOGICAL-INEQUALITY': 0.2722119987010956,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08064427971839905,
#    'OBJECTIFICATION': 0.07703115791082382,
#    'SEXUAL-VIOLENCE': 0.07151234894990921,
#    'STEREOTYPING-DOMINANCE': 0.2919507622718811}},
#  {'test_case': 'EXIST2025',
#   'id': '120063',
#   'value': {'NO': 0.19367428123950958,
#    'IDEOLOGICAL-INEQUALITY': 0.40151312947273254,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.11034893989562988,
#    'OBJECTIFICATION': 0.0905035212635994,
#    'SEXUAL-VIOLENCE': 0.07802945375442505,
#    'STEREOTYPING-DOMINANCE': 0.24582359194755554}},
#  {'test_case': 'EXIST2025',
#   'id': '120064',
#   'value': {'NO': 0.296111524105072,
#    'IDEOLOGICAL-INEQUALITY': 0.23983708024024963,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0700368583202362,
#    'OBJECTIFICATION': 0.06689872592687607,
#    'SEXUAL-VIOLENCE': 0.056701503694057465,
#    'STEREOTYPING-DOMINANCE': 0.2831629812717438}},
#  {'test_case': 'EXIST2025',
#   'id': '120065',
#   'value': {'NO': 0.18981486558914185,
#    'IDEOLOGICAL-INEQUALITY': 0.43463966250419617,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.12251242250204086,
#    'OBJECTIFICATION': 0.10369715839624405,
#    'SEXUAL-VIOLENCE': 0.08851266652345657,
#    'STEREOTYPING-DOMINANCE': 0.26574137806892395}},
#  {'test_case': 'EXIST2025',
#   'id': '120066',
#   'value': {'NO': 0.11141828447580338,
#    'IDEOLOGICAL-INEQUALITY': 0.517072319984436,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.1414088010787964,
#    'OBJECTIFICATION': 0.12198469042778015,
#    'SEXUAL-VIOLENCE': 0.1160908043384552,
#    'STEREOTYPING-DOMINANCE': 0.2878631353378296}},
#  {'test_case': 'EXIST2025',
#   'id': '120067',
#   'value': {'NO': 0.21277755498886108,
#    'IDEOLOGICAL-INEQUALITY': 0.33073267340660095,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08161934465169907,
#    'OBJECTIFICATION': 0.06796569377183914,
#    'SEXUAL-VIOLENCE': 0.058193791657686234,
#    'STEREOTYPING-DOMINANCE': 0.2861042618751526}},
#  {'test_case': 'EXIST2025',
#   'id': '120068',
#   'value': {'NO': 0.46458369493484497,
#    'IDEOLOGICAL-INEQUALITY': 0.08723773807287216,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03127129375934601,
#    'OBJECTIFICATION': 0.0579778291285038,
#    'SEXUAL-VIOLENCE': 0.028922678902745247,
#    'STEREOTYPING-DOMINANCE': 0.17638449370861053}},
#  {'test_case': 'EXIST2025',
#   'id': '120069',
#   'value': {'NO': 0.10940267145633698,
#    'IDEOLOGICAL-INEQUALITY': 0.4563766419887543,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.10836754739284515,
#    'OBJECTIFICATION': 0.09451279789209366,
#    'SEXUAL-VIOLENCE': 0.09082482755184174,
#    'STEREOTYPING-DOMINANCE': 0.2912980318069458}},
#  {'test_case': 'EXIST2025',
#   'id': '120070',
#   'value': {'NO': 0.15863898396492004,
#    'IDEOLOGICAL-INEQUALITY': 0.4053814113140106,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08964891731739044,
#    'OBJECTIFICATION': 0.0812557190656662,
#    'SEXUAL-VIOLENCE': 0.06991323083639145,
#    'STEREOTYPING-DOMINANCE': 0.24390809237957}},
#  {'test_case': 'EXIST2025',
#   'id': '120071',
#   'value': {'NO': 0.13579967617988586,
#    'IDEOLOGICAL-INEQUALITY': 0.39550843834877014,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.09693887084722519,
#    'OBJECTIFICATION': 0.08536594361066818,
#    'SEXUAL-VIOLENCE': 0.0714695081114769,
#    'STEREOTYPING-DOMINANCE': 0.3130214214324951}},
#  {'test_case': 'EXIST2025',
#   'id': '120072',
#   'value': {'NO': 0.23810574412345886,
#    'IDEOLOGICAL-INEQUALITY': 0.1229744404554367,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04319509491324425,
#    'OBJECTIFICATION': 0.05352116748690605,
#    'SEXUAL-VIOLENCE': 0.028187550604343414,
#    'STEREOTYPING-DOMINANCE': 0.4997927248477936}},
#  {'test_case': 'EXIST2025',
#   'id': '120073',
#   'value': {'NO': 0.8330328464508057,
#    'IDEOLOGICAL-INEQUALITY': 0.03119838610291481,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.024658897891640663,
#    'OBJECTIFICATION': 0.06844450533390045,
#    'SEXUAL-VIOLENCE': 0.02974308654665947,
#    'STEREOTYPING-DOMINANCE': 0.08310390263795853}},
#  {'test_case': 'EXIST2025',
#   'id': '120074',
#   'value': {'NO': 0.7414923906326294,
#    'IDEOLOGICAL-INEQUALITY': 0.034985821694135666,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02277507446706295,
#    'OBJECTIFICATION': 0.07501546293497086,
#    'SEXUAL-VIOLENCE': 0.02502048946917057,
#    'STEREOTYPING-DOMINANCE': 0.08979859948158264}},
#  {'test_case': 'EXIST2025',
#   'id': '120075',
#   'value': {'NO': 0.8617976903915405,
#    'IDEOLOGICAL-INEQUALITY': 0.027211220934987068,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0254218727350235,
#    'OBJECTIFICATION': 0.07802514731884003,
#    'SEXUAL-VIOLENCE': 0.03129668906331062,
#    'STEREOTYPING-DOMINANCE': 0.08995598554611206}},
#  {'test_case': 'EXIST2025',
#   'id': '120076',
#   'value': {'NO': 0.4162856638431549,
#    'IDEOLOGICAL-INEQUALITY': 0.1287594735622406,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03842245042324066,
#    'OBJECTIFICATION': 0.05601729080080986,
#    'SEXUAL-VIOLENCE': 0.03568440303206444,
#    'STEREOTYPING-DOMINANCE': 0.3090859353542328}},
#  {'test_case': 'EXIST2025',
#   'id': '120077',
#   'value': {'NO': 0.43250972032546997,
#    'IDEOLOGICAL-INEQUALITY': 0.15182343125343323,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05503193661570549,
#    'OBJECTIFICATION': 0.0694189965724945,
#    'SEXUAL-VIOLENCE': 0.05627356097102165,
#    'STEREOTYPING-DOMINANCE': 0.17671813070774078}},
#  {'test_case': 'EXIST2025',
#   'id': '120078',
#   'value': {'NO': 0.23529116809368134,
#    'IDEOLOGICAL-INEQUALITY': 0.273982971906662,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0773119404911995,
#    'OBJECTIFICATION': 0.07730015367269516,
#    'SEXUAL-VIOLENCE': 0.060264334082603455,
#    'STEREOTYPING-DOMINANCE': 0.28314709663391113}},
#  {'test_case': 'EXIST2025',
#   'id': '120079',
#   'value': {'NO': 0.20450562238693237,
#    'IDEOLOGICAL-INEQUALITY': 0.21910537779331207,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.056318383663892746,
#    'OBJECTIFICATION': 0.05288773402571678,
#    'SEXUAL-VIOLENCE': 0.03980502486228943,
#    'STEREOTYPING-DOMINANCE': 0.47707000374794006}},
#  {'test_case': 'EXIST2025',
#   'id': '120080',
#   'value': {'NO': 0.19018228352069855,
#    'IDEOLOGICAL-INEQUALITY': 0.36353322863578796,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.09660624712705612,
#    'OBJECTIFICATION': 0.10583524405956268,
#    'SEXUAL-VIOLENCE': 0.11196155846118927,
#    'STEREOTYPING-DOMINANCE': 0.2509078085422516}},
#  {'test_case': 'EXIST2025',
#   'id': '120081',
#   'value': {'NO': 0.6859304308891296,
#    'IDEOLOGICAL-INEQUALITY': 0.05712730810046196,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02925308793783188,
#    'OBJECTIFICATION': 0.06392616033554077,
#    'SEXUAL-VIOLENCE': 0.03581599146127701,
#    'STEREOTYPING-DOMINANCE': 0.10256839543581009}},
#  {'test_case': 'EXIST2025',
#   'id': '120082',
#   'value': {'NO': 0.563990592956543,
#    'IDEOLOGICAL-INEQUALITY': 0.08578409999608994,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.040351346135139465,
#    'OBJECTIFICATION': 0.059723321348428726,
#    'SEXUAL-VIOLENCE': 0.03688879311084747,
#    'STEREOTYPING-DOMINANCE': 0.17180421948432922}},
#  {'test_case': 'EXIST2025',
#   'id': '120083',
#   'value': {'NO': 0.246236652135849,
#    'IDEOLOGICAL-INEQUALITY': 0.18411432206630707,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.056124504655599594,
#    'OBJECTIFICATION': 0.06504447758197784,
#    'SEXUAL-VIOLENCE': 0.03968450427055359,
#    'STEREOTYPING-DOMINANCE': 0.4700433909893036}},
#  {'test_case': 'EXIST2025',
#   'id': '120084',
#   'value': {'NO': 0.5055726170539856,
#    'IDEOLOGICAL-INEQUALITY': 0.07013218849897385,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.028006786480545998,
#    'OBJECTIFICATION': 0.04818040877580643,
#    'SEXUAL-VIOLENCE': 0.021640649065375328,
#    'STEREOTYPING-DOMINANCE': 0.23729285597801208}},
#  {'test_case': 'EXIST2025',
#   'id': '120085',
#   'value': {'NO': 0.628318190574646,
#    'IDEOLOGICAL-INEQUALITY': 0.05064556375145912,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.025534238666296005,
#    'OBJECTIFICATION': 0.05864042788743973,
#    'SEXUAL-VIOLENCE': 0.023756006732583046,
#    'STEREOTYPING-DOMINANCE': 0.21433040499687195}},
#  {'test_case': 'EXIST2025',
#   'id': '120086',
#   'value': {'NO': 0.6728780269622803,
#    'IDEOLOGICAL-INEQUALITY': 0.050583504140377045,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.025834834203124046,
#    'OBJECTIFICATION': 0.055144019424915314,
#    'SEXUAL-VIOLENCE': 0.025982758030295372,
#    'STEREOTYPING-DOMINANCE': 0.15227240324020386}},
#  {'test_case': 'EXIST2025',
#   'id': '120087',
#   'value': {'NO': 0.8261796832084656,
#    'IDEOLOGICAL-INEQUALITY': 0.028301285579800606,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.023537974804639816,
#    'OBJECTIFICATION': 0.0666893795132637,
#    'SEXUAL-VIOLENCE': 0.027598151937127113,
#    'STEREOTYPING-DOMINANCE': 0.08509881794452667}},
#  {'test_case': 'EXIST2025',
#   'id': '120088',
#   'value': {'NO': 0.20106711983680725,
#    'IDEOLOGICAL-INEQUALITY': 0.21387293934822083,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.059877246618270874,
#    'OBJECTIFICATION': 0.06540993601083755,
#    'SEXUAL-VIOLENCE': 0.04064217582345009,
#    'STEREOTYPING-DOMINANCE': 0.5325357913970947}},
#  {'test_case': 'EXIST2025',
#   'id': '120089',
#   'value': {'NO': 0.30425897240638733,
#    'IDEOLOGICAL-INEQUALITY': 0.204546719789505,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05758685991168022,
#    'OBJECTIFICATION': 0.05802673101425171,
#    'SEXUAL-VIOLENCE': 0.046570152044296265,
#    'STEREOTYPING-DOMINANCE': 0.309418261051178}},
#  {'test_case': 'EXIST2025',
#   'id': '120090',
#   'value': {'NO': 0.27964141964912415,
#    'IDEOLOGICAL-INEQUALITY': 0.3174945116043091,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08605197072029114,
#    'OBJECTIFICATION': 0.08307333290576935,
#    'SEXUAL-VIOLENCE': 0.08299838751554489,
#    'STEREOTYPING-DOMINANCE': 0.21005216240882874}},
#  {'test_case': 'EXIST2025',
#   'id': '120091',
#   'value': {'NO': 0.11484165489673615,
#    'IDEOLOGICAL-INEQUALITY': 0.4737618863582611,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.1138429269194603,
#    'OBJECTIFICATION': 0.1045842170715332,
#    'SEXUAL-VIOLENCE': 0.09546328336000443,
#    'STEREOTYPING-DOMINANCE': 0.2582681179046631}},
#  {'test_case': 'EXIST2025',
#   'id': '120092',
#   'value': {'NO': 0.2868836522102356,
#    'IDEOLOGICAL-INEQUALITY': 0.19739112257957458,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.049369413405656815,
#    'OBJECTIFICATION': 0.06521560251712799,
#    'SEXUAL-VIOLENCE': 0.04661846533417702,
#    'STEREOTYPING-DOMINANCE': 0.22106753289699554}},
#  {'test_case': 'EXIST2025',
#   'id': '120093',
#   'value': {'NO': 0.5072458386421204,
#    'IDEOLOGICAL-INEQUALITY': 0.09827663004398346,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03847924619913101,
#    'OBJECTIFICATION': 0.0549221895635128,
#    'SEXUAL-VIOLENCE': 0.032749027013778687,
#    'STEREOTYPING-DOMINANCE': 0.16475391387939453}},
#  {'test_case': 'EXIST2025',
#   'id': '120094',
#   'value': {'NO': 0.7544764280319214,
#    'IDEOLOGICAL-INEQUALITY': 0.04144981503486633,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.026883605867624283,
#    'OBJECTIFICATION': 0.07281427085399628,
#    'SEXUAL-VIOLENCE': 0.03145454823970795,
#    'STEREOTYPING-DOMINANCE': 0.0909171849489212}},
#  {'test_case': 'EXIST2025',
#   'id': '120095',
#   'value': {'NO': 0.17413675785064697,
#    'IDEOLOGICAL-INEQUALITY': 0.27734243869781494,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.061426274478435516,
#    'OBJECTIFICATION': 0.06834684312343597,
#    'SEXUAL-VIOLENCE': 0.05023902282118797,
#    'STEREOTYPING-DOMINANCE': 0.2707744836807251}},
#  {'test_case': 'EXIST2025',
#   'id': '120096',
#   'value': {'NO': 0.11337321996688843,
#    'IDEOLOGICAL-INEQUALITY': 0.4846876859664917,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.11156982183456421,
#    'OBJECTIFICATION': 0.10373860597610474,
#    'SEXUAL-VIOLENCE': 0.09269161522388458,
#    'STEREOTYPING-DOMINANCE': 0.27006712555885315}},
#  {'test_case': 'EXIST2025',
#   'id': '120097',
#   'value': {'NO': 0.7965628504753113,
#    'IDEOLOGICAL-INEQUALITY': 0.03737867623567581,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.025132669135928154,
#    'OBJECTIFICATION': 0.06359566003084183,
#    'SEXUAL-VIOLENCE': 0.03190942481160164,
#    'STEREOTYPING-DOMINANCE': 0.0818859413266182}},
#  {'test_case': 'EXIST2025',
#   'id': '120098',
#   'value': {'NO': 0.14702968299388885,
#    'IDEOLOGICAL-INEQUALITY': 0.3450683355331421,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0671018660068512,
#    'OBJECTIFICATION': 0.07557752728462219,
#    'SEXUAL-VIOLENCE': 0.05291938781738281,
#    'STEREOTYPING-DOMINANCE': 0.24884580075740814}},
#  {'test_case': 'EXIST2025',
#   'id': '120099',
#   'value': {'NO': 0.45289307832717896,
#    'IDEOLOGICAL-INEQUALITY': 0.11277201026678085,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0429137758910656,
#    'OBJECTIFICATION': 0.04947742819786072,
#    'SEXUAL-VIOLENCE': 0.03304048255085945,
#    'STEREOTYPING-DOMINANCE': 0.2766636610031128}},
#  {'test_case': 'EXIST2025',
#   'id': '120100',
#   'value': {'NO': 0.37220484018325806,
#    'IDEOLOGICAL-INEQUALITY': 0.13994084298610687,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.043127771466970444,
#    'OBJECTIFICATION': 0.050470687448978424,
#    'SEXUAL-VIOLENCE': 0.03421034291386604,
#    'STEREOTYPING-DOMINANCE': 0.282461553812027}},
#  {'test_case': 'EXIST2025',
#   'id': '120101',
#   'value': {'NO': 0.42239832878112793,
#    'IDEOLOGICAL-INEQUALITY': 0.17486941814422607,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05501648411154747,
#    'OBJECTIFICATION': 0.0760853961110115,
#    'SEXUAL-VIOLENCE': 0.0552683100104332,
#    'STEREOTYPING-DOMINANCE': 0.12086305767297745}},
#  {'test_case': 'EXIST2025',
#   'id': '120102',
#   'value': {'NO': 0.6280221939086914,
#    'IDEOLOGICAL-INEQUALITY': 0.06500885635614395,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.030132321640849113,
#    'OBJECTIFICATION': 0.057528089731931686,
#    'SEXUAL-VIOLENCE': 0.02997891791164875,
#    'STEREOTYPING-DOMINANCE': 0.14136047661304474}},
#  {'test_case': 'EXIST2025',
#   'id': '120103',
#   'value': {'NO': 0.19849631190299988,
#    'IDEOLOGICAL-INEQUALITY': 0.3268304169178009,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08108397573232651,
#    'OBJECTIFICATION': 0.08926087617874146,
#    'SEXUAL-VIOLENCE': 0.06133652478456497,
#    'STEREOTYPING-DOMINANCE': 0.3042234480381012}},
#  {'test_case': 'EXIST2025',
#   'id': '120104',
#   'value': {'NO': 0.1978352963924408,
#    'IDEOLOGICAL-INEQUALITY': 0.2828367054462433,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.06972424685955048,
#    'OBJECTIFICATION': 0.08118943125009537,
#    'SEXUAL-VIOLENCE': 0.06471377611160278,
#    'STEREOTYPING-DOMINANCE': 0.2861754894256592}},
#  {'test_case': 'EXIST2025',
#   'id': '120105',
#   'value': {'NO': 0.12442702054977417,
#    'IDEOLOGICAL-INEQUALITY': 0.4737779498100281,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.10931509733200073,
#    'OBJECTIFICATION': 0.10150784999132156,
#    'SEXUAL-VIOLENCE': 0.08335705101490021,
#    'STEREOTYPING-DOMINANCE': 0.2814866006374359}},
#  {'test_case': 'EXIST2025',
#   'id': '120106',
#   'value': {'NO': 0.17741115391254425,
#    'IDEOLOGICAL-INEQUALITY': 0.3417874872684479,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0683266669511795,
#    'OBJECTIFICATION': 0.06631733477115631,
#    'SEXUAL-VIOLENCE': 0.049319859594106674,
#    'STEREOTYPING-DOMINANCE': 0.2859748899936676}},
#  {'test_case': 'EXIST2025',
#   'id': '120107',
#   'value': {'NO': 0.6537536978721619,
#    'IDEOLOGICAL-INEQUALITY': 0.0674579069018364,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.030671557411551476,
#    'OBJECTIFICATION': 0.055441975593566895,
#    'SEXUAL-VIOLENCE': 0.029695304110646248,
#    'STEREOTYPING-DOMINANCE': 0.19421999156475067}},
#  {'test_case': 'EXIST2025',
#   'id': '120108',
#   'value': {'NO': 0.11241205036640167,
#    'IDEOLOGICAL-INEQUALITY': 0.5048642754554749,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.11702284961938858,
#    'OBJECTIFICATION': 0.10521124303340912,
#    'SEXUAL-VIOLENCE': 0.09693558514118195,
#    'STEREOTYPING-DOMINANCE': 0.2706710994243622}},
#  {'test_case': 'EXIST2025',
#   'id': '120109',
#   'value': {'NO': 0.2351035624742508,
#    'IDEOLOGICAL-INEQUALITY': 0.13833679258823395,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04697376489639282,
#    'OBJECTIFICATION': 0.05306766927242279,
#    'SEXUAL-VIOLENCE': 0.03375355526804924,
#    'STEREOTYPING-DOMINANCE': 0.5397423505783081}},
#  {'test_case': 'EXIST2025',
#   'id': '120110',
#   'value': {'NO': 0.23082970082759857,
#    'IDEOLOGICAL-INEQUALITY': 0.13701269030570984,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0439104326069355,
#    'OBJECTIFICATION': 0.049580350518226624,
#    'SEXUAL-VIOLENCE': 0.03040158562362194,
#    'STEREOTYPING-DOMINANCE': 0.5092126131057739}},
#  {'test_case': 'EXIST2025',
#   'id': '120111',
#   'value': {'NO': 0.27890172600746155,
#    'IDEOLOGICAL-INEQUALITY': 0.1204177513718605,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.043554600328207016,
#    'OBJECTIFICATION': 0.05089426040649414,
#    'SEXUAL-VIOLENCE': 0.031905315816402435,
#    'STEREOTYPING-DOMINANCE': 0.50372314453125}},
#  {'test_case': 'EXIST2025',
#   'id': '120112',
#   'value': {'NO': 0.1964939832687378,
#    'IDEOLOGICAL-INEQUALITY': 0.16211703419685364,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04284731671214104,
#    'OBJECTIFICATION': 0.05246475338935852,
#    'SEXUAL-VIOLENCE': 0.032551415264606476,
#    'STEREOTYPING-DOMINANCE': 0.38787636160850525}},
#  {'test_case': 'EXIST2025',
#   'id': '120113',
#   'value': {'NO': 0.16726501286029816,
#    'IDEOLOGICAL-INEQUALITY': 0.17476430535316467,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05919191241264343,
#    'OBJECTIFICATION': 0.07293421775102615,
#    'SEXUAL-VIOLENCE': 0.03804062306880951,
#    'STEREOTYPING-DOMINANCE': 0.5301171541213989}},
#  {'test_case': 'EXIST2025',
#   'id': '120114',
#   'value': {'NO': 0.3506258726119995,
#    'IDEOLOGICAL-INEQUALITY': 0.09229520708322525,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04155813530087471,
#    'OBJECTIFICATION': 0.05255536735057831,
#    'SEXUAL-VIOLENCE': 0.027015728875994682,
#    'STEREOTYPING-DOMINANCE': 0.4927184283733368}},
#  {'test_case': 'EXIST2025',
#   'id': '120115',
#   'value': {'NO': 0.4092434346675873,
#    'IDEOLOGICAL-INEQUALITY': 0.10114108771085739,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05619466304779053,
#    'OBJECTIFICATION': 0.06171048805117607,
#    'SEXUAL-VIOLENCE': 0.03493461012840271,
#    'STEREOTYPING-DOMINANCE': 0.5277649164199829}},
#  {'test_case': 'EXIST2025',
#   'id': '120116',
#   'value': {'NO': 0.30107608437538147,
#    'IDEOLOGICAL-INEQUALITY': 0.12499848008155823,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.06021752953529358,
#    'OBJECTIFICATION': 0.06737639009952545,
#    'SEXUAL-VIOLENCE': 0.03742622211575508,
#    'STEREOTYPING-DOMINANCE': 0.6002271771430969}},
#  {'test_case': 'EXIST2025',
#   'id': '120117',
#   'value': {'NO': 0.8203489184379578,
#    'IDEOLOGICAL-INEQUALITY': 0.029333127662539482,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02333446592092514,
#    'OBJECTIFICATION': 0.06387909501791,
#    'SEXUAL-VIOLENCE': 0.0251548383384943,
#    'STEREOTYPING-DOMINANCE': 0.09599859267473221}},
#  {'test_case': 'EXIST2025',
#   'id': '120118',
#   'value': {'NO': 0.12092085927724838,
#    'IDEOLOGICAL-INEQUALITY': 0.3054219186306,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.06908748298883438,
#    'OBJECTIFICATION': 0.0629533976316452,
#    'SEXUAL-VIOLENCE': 0.05137447640299797,
#    'STEREOTYPING-DOMINANCE': 0.3660438060760498}},
#  {'test_case': 'EXIST2025',
#   'id': '120119',
#   'value': {'NO': 0.6611419916152954,
#    'IDEOLOGICAL-INEQUALITY': 0.04099692031741142,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.022429313510656357,
#    'OBJECTIFICATION': 0.04889213293790817,
#    'SEXUAL-VIOLENCE': 0.01871015504002571,
#    'STEREOTYPING-DOMINANCE': 0.16017462313175201}},
#  {'test_case': 'EXIST2025',
#   'id': '120120',
#   'value': {'NO': 0.5077101588249207,
#    'IDEOLOGICAL-INEQUALITY': 0.05839620903134346,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.030284853652119637,
#    'OBJECTIFICATION': 0.049770619720220566,
#    'SEXUAL-VIOLENCE': 0.02243545651435852,
#    'STEREOTYPING-DOMINANCE': 0.3342333734035492}},
#  {'test_case': 'EXIST2025',
#   'id': '120121',
#   'value': {'NO': 0.22942249476909637,
#    'IDEOLOGICAL-INEQUALITY': 0.14551715552806854,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.056040264666080475,
#    'OBJECTIFICATION': 0.060203395783901215,
#    'SEXUAL-VIOLENCE': 0.03724649176001549,
#    'STEREOTYPING-DOMINANCE': 0.6022422313690186}},
#  {'test_case': 'EXIST2025',
#   'id': '120122',
#   'value': {'NO': 0.7634350061416626,
#    'IDEOLOGICAL-INEQUALITY': 0.0446893647313118,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.024905430153012276,
#    'OBJECTIFICATION': 0.058476679027080536,
#    'SEXUAL-VIOLENCE': 0.03272104263305664,
#    'STEREOTYPING-DOMINANCE': 0.10162229835987091}},
#  {'test_case': 'EXIST2025',
#   'id': '120123',
#   'value': {'NO': 0.7450054883956909,
#    'IDEOLOGICAL-INEQUALITY': 0.035855524241924286,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.022585690021514893,
#    'OBJECTIFICATION': 0.053044840693473816,
#    'SEXUAL-VIOLENCE': 0.02207031100988388,
#    'STEREOTYPING-DOMINANCE': 0.11175496876239777}},
#  {'test_case': 'EXIST2025',
#   'id': '120124',
#   'value': {'NO': 0.31233081221580505,
#    'IDEOLOGICAL-INEQUALITY': 0.12365494668483734,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.060104601085186005,
#    'OBJECTIFICATION': 0.06402937322854996,
#    'SEXUAL-VIOLENCE': 0.038843121379613876,
#    'STEREOTYPING-DOMINANCE': 0.5990116596221924}},
#  {'test_case': 'EXIST2025',
#   'id': '120125',
#   'value': {'NO': 0.38367560505867004,
#    'IDEOLOGICAL-INEQUALITY': 0.08123083412647247,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03222920745611191,
#    'OBJECTIFICATION': 0.04562465101480484,
#    'SEXUAL-VIOLENCE': 0.0233995970338583,
#    'STEREOTYPING-DOMINANCE': 0.40876033902168274}},
#  {'test_case': 'EXIST2025',
#   'id': '120126',
#   'value': {'NO': 0.14512833952903748,
#    'IDEOLOGICAL-INEQUALITY': 0.22412419319152832,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05640808492898941,
#    'OBJECTIFICATION': 0.058210913091897964,
#    'SEXUAL-VIOLENCE': 0.0430864654481411,
#    'STEREOTYPING-DOMINANCE': 0.4341239333152771}},
#  {'test_case': 'EXIST2025',
#   'id': '120127',
#   'value': {'NO': 0.10879874974489212,
#    'IDEOLOGICAL-INEQUALITY': 0.5102477669715881,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.12311559170484543,
#    'OBJECTIFICATION': 0.11468633264303207,
#    'SEXUAL-VIOLENCE': 0.11122135072946548,
#    'STEREOTYPING-DOMINANCE': 0.268526166677475}},
#  {'test_case': 'EXIST2025',
#   'id': '120128',
#   'value': {'NO': 0.11460931599140167,
#    'IDEOLOGICAL-INEQUALITY': 0.4962877035140991,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.11581573635339737,
#    'OBJECTIFICATION': 0.10746729373931885,
#    'SEXUAL-VIOLENCE': 0.10615447908639908,
#    'STEREOTYPING-DOMINANCE': 0.2585512399673462}},
#  {'test_case': 'EXIST2025',
#   'id': '120129',
#   'value': {'NO': 0.10835926979780197,
#    'IDEOLOGICAL-INEQUALITY': 0.5478726625442505,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.137332484126091,
#    'OBJECTIFICATION': 0.13279026746749878,
#    'SEXUAL-VIOLENCE': 0.13155674934387207,
#    'STEREOTYPING-DOMINANCE': 0.25884366035461426}},
#  {'test_case': 'EXIST2025',
#   'id': '120130',
#   'value': {'NO': 0.23466365039348602,
#    'IDEOLOGICAL-INEQUALITY': 0.28028011322021484,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0800190195441246,
#    'OBJECTIFICATION': 0.07017477601766586,
#    'SEXUAL-VIOLENCE': 0.06215977668762207,
#    'STEREOTYPING-DOMINANCE': 0.33685263991355896}},
#  {'test_case': 'EXIST2025',
#   'id': '120131',
#   'value': {'NO': 0.1408407837152481,
#    'IDEOLOGICAL-INEQUALITY': 0.41021019220352173,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08863943070173264,
#    'OBJECTIFICATION': 0.08675654232501984,
#    'SEXUAL-VIOLENCE': 0.0784914419054985,
#    'STEREOTYPING-DOMINANCE': 0.23726557195186615}},
#  {'test_case': 'EXIST2025',
#   'id': '120132',
#   'value': {'NO': 0.11398172378540039,
#    'IDEOLOGICAL-INEQUALITY': 0.4993760585784912,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.12397267669439316,
#    'OBJECTIFICATION': 0.10796982795000076,
#    'SEXUAL-VIOLENCE': 0.10055229067802429,
#    'STEREOTYPING-DOMINANCE': 0.2852042019367218}},
#  {'test_case': 'EXIST2025',
#   'id': '120133',
#   'value': {'NO': 0.38827553391456604,
#    'IDEOLOGICAL-INEQUALITY': 0.13711687922477722,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04474479332566261,
#    'OBJECTIFICATION': 0.05191433057188988,
#    'SEXUAL-VIOLENCE': 0.034410420805215836,
#    'STEREOTYPING-DOMINANCE': 0.26336419582366943}},
#  {'test_case': 'EXIST2025',
#   'id': '120134',
#   'value': {'NO': 0.13182097673416138,
#    'IDEOLOGICAL-INEQUALITY': 0.48168522119522095,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.1123180091381073,
#    'OBJECTIFICATION': 0.0995815098285675,
#    'SEXUAL-VIOLENCE': 0.09360280632972717,
#    'STEREOTYPING-DOMINANCE': 0.2571978271007538}},
#  {'test_case': 'EXIST2025',
#   'id': '120135',
#   'value': {'NO': 0.268680602312088,
#    'IDEOLOGICAL-INEQUALITY': 0.1973942220211029,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05202728509902954,
#    'OBJECTIFICATION': 0.05536885932087898,
#    'SEXUAL-VIOLENCE': 0.0388319306075573,
#    'STEREOTYPING-DOMINANCE': 0.38007012009620667}},
#  {'test_case': 'EXIST2025',
#   'id': '120136',
#   'value': {'NO': 0.6850869655609131,
#    'IDEOLOGICAL-INEQUALITY': 0.05155665799975395,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.030657706782221794,
#    'OBJECTIFICATION': 0.05670573189854622,
#    'SEXUAL-VIOLENCE': 0.030186718329787254,
#    'STEREOTYPING-DOMINANCE': 0.12315060198307037}},
#  {'test_case': 'EXIST2025',
#   'id': '120137',
#   'value': {'NO': 0.26979440450668335,
#    'IDEOLOGICAL-INEQUALITY': 0.1864086091518402,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0541655533015728,
#    'OBJECTIFICATION': 0.0659131333231926,
#    'SEXUAL-VIOLENCE': 0.04347795993089676,
#    'STEREOTYPING-DOMINANCE': 0.3103483319282532}},
#  {'test_case': 'EXIST2025',
#   'id': '120138',
#   'value': {'NO': 0.4062451422214508,
#    'IDEOLOGICAL-INEQUALITY': 0.15378133952617645,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.058987077325582504,
#    'OBJECTIFICATION': 0.08586975187063217,
#    'SEXUAL-VIOLENCE': 0.0482892207801342,
#    'STEREOTYPING-DOMINANCE': 0.4579887390136719}},
#  {'test_case': 'EXIST2025',
#   'id': '120139',
#   'value': {'NO': 0.12151636183261871,
#    'IDEOLOGICAL-INEQUALITY': 0.48183009028434753,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.11120724678039551,
#    'OBJECTIFICATION': 0.1039671003818512,
#    'SEXUAL-VIOLENCE': 0.09616320580244064,
#    'STEREOTYPING-DOMINANCE': 0.24998998641967773}},
#  {'test_case': 'EXIST2025',
#   'id': '120140',
#   'value': {'NO': 0.114409901201725,
#    'IDEOLOGICAL-INEQUALITY': 0.4167202115058899,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08578271418809891,
#    'OBJECTIFICATION': 0.08887375146150589,
#    'SEXUAL-VIOLENCE': 0.06886265426874161,
#    'STEREOTYPING-DOMINANCE': 0.29928308725357056}},
#  {'test_case': 'EXIST2025',
#   'id': '120141',
#   'value': {'NO': 0.7798629403114319,
#    'IDEOLOGICAL-INEQUALITY': 0.03416283056139946,
# ...
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04878147691488266,
#    'OBJECTIFICATION': 0.05274994298815727,
#    'SEXUAL-VIOLENCE': 0.0334467887878418,
#    'STEREOTYPING-DOMINANCE': 0.4346691966056824}},
#  {'test_case': 'EXIST2025',
#   'id': '120953',
#   'value': {'NO': 0.2602342665195465,
#    'IDEOLOGICAL-INEQUALITY': 0.18965108692646027,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05378077179193497,
#    'OBJECTIFICATION': 0.06160447746515274,
#    'SEXUAL-VIOLENCE': 0.038094308227300644,
#    'STEREOTYPING-DOMINANCE': 0.3432067334651947}},
#  {'test_case': 'EXIST2025',
#   'id': '120954',
#   'value': {'NO': 0.2771027088165283,
#    'IDEOLOGICAL-INEQUALITY': 0.24666601419448853,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.061731066554784775,
#    'OBJECTIFICATION': 0.06158491224050522,
#    'SEXUAL-VIOLENCE': 0.05149757117033005,
#    'STEREOTYPING-DOMINANCE': 0.3200080692768097}},
#  {'test_case': 'EXIST2025',
#   'id': '120955',
#   'value': {'NO': 0.1729438751935959,
#    'IDEOLOGICAL-INEQUALITY': 0.23247218132019043,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.054945796728134155,
#    'OBJECTIFICATION': 0.06887947022914886,
#    'SEXUAL-VIOLENCE': 0.04273306205868721,
#    'STEREOTYPING-DOMINANCE': 0.4019530713558197}},
#  {'test_case': 'EXIST2025',
#   'id': '120956',
#   'value': {'NO': 0.31428062915802,
#    'IDEOLOGICAL-INEQUALITY': 0.19966353476047516,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.061409007757902145,
#    'OBJECTIFICATION': 0.06773795187473297,
#    'SEXUAL-VIOLENCE': 0.048403844237327576,
#    'STEREOTYPING-DOMINANCE': 0.2838953733444214}},
#  {'test_case': 'EXIST2025',
#   'id': '120957',
#   'value': {'NO': 0.1364872306585312,
#    'IDEOLOGICAL-INEQUALITY': 0.42991870641708374,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.10539177805185318,
#    'OBJECTIFICATION': 0.09774305671453476,
#    'SEXUAL-VIOLENCE': 0.09536951780319214,
#    'STEREOTYPING-DOMINANCE': 0.26652610301971436}},
#  {'test_case': 'EXIST2025',
#   'id': '120958',
#   'value': {'NO': 0.24713703989982605,
#    'IDEOLOGICAL-INEQUALITY': 0.23434577882289886,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.06227366253733635,
#    'OBJECTIFICATION': 0.06281008571386337,
#    'SEXUAL-VIOLENCE': 0.048201002180576324,
#    'STEREOTYPING-DOMINANCE': 0.36047691106796265}},
#  {'test_case': 'EXIST2025',
#   'id': '120959',
#   'value': {'NO': 0.21564309298992157,
#    'IDEOLOGICAL-INEQUALITY': 0.3166528344154358,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08622046560049057,
#    'OBJECTIFICATION': 0.07433849573135376,
#    'SEXUAL-VIOLENCE': 0.06842260807752609,
#    'STEREOTYPING-DOMINANCE': 0.33125314116477966}},
#  {'test_case': 'EXIST2025',
#   'id': '120960',
#   'value': {'NO': 0.11514998227357864,
#    'IDEOLOGICAL-INEQUALITY': 0.5251578092575073,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.12064024060964584,
#    'OBJECTIFICATION': 0.11869276314973831,
#    'SEXUAL-VIOLENCE': 0.1062861829996109,
#    'STEREOTYPING-DOMINANCE': 0.26537343859672546}},
#  {'test_case': 'EXIST2025',
#   'id': '120961',
#   'value': {'NO': 0.22634455561637878,
#    'IDEOLOGICAL-INEQUALITY': 0.3048374056816101,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.08291309326887131,
#    'OBJECTIFICATION': 0.07287256419658661,
#    'SEXUAL-VIOLENCE': 0.06175273284316063,
#    'STEREOTYPING-DOMINANCE': 0.34121015667915344}},
#  {'test_case': 'EXIST2025',
#   'id': '120962',
#   'value': {'NO': 0.12148413807153702,
#    'IDEOLOGICAL-INEQUALITY': 0.47910404205322266,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.10192961245775223,
#    'OBJECTIFICATION': 0.10051038861274719,
#    'SEXUAL-VIOLENCE': 0.08580449968576431,
#    'STEREOTYPING-DOMINANCE': 0.27736568450927734}},
#  {'test_case': 'EXIST2025',
#   'id': '120963',
#   'value': {'NO': 0.29342588782310486,
#    'IDEOLOGICAL-INEQUALITY': 0.21997694671154022,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05844109132885933,
#    'OBJECTIFICATION': 0.05622730404138565,
#    'SEXUAL-VIOLENCE': 0.04512602835893631,
#    'STEREOTYPING-DOMINANCE': 0.3148614466190338}},
#  {'test_case': 'EXIST2025',
#   'id': '120964',
#   'value': {'NO': 0.6170501112937927,
#    'IDEOLOGICAL-INEQUALITY': 0.04462156444787979,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.022803055122494698,
#    'OBJECTIFICATION': 0.05228668823838234,
#    'SEXUAL-VIOLENCE': 0.019555523991584778,
#    'STEREOTYPING-DOMINANCE': 0.1541173905134201}},
#  {'test_case': 'EXIST2025',
#   'id': '120965',
#   'value': {'NO': 0.5368756651878357,
#    'IDEOLOGICAL-INEQUALITY': 0.08758562058210373,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0395454540848732,
#    'OBJECTIFICATION': 0.05395042151212692,
#    'SEXUAL-VIOLENCE': 0.03333836793899536,
#    'STEREOTYPING-DOMINANCE': 0.1923564374446869}},
#  {'test_case': 'EXIST2025',
#   'id': '120966',
#   'value': {'NO': 0.36833831667900085,
#    'IDEOLOGICAL-INEQUALITY': 0.10557876527309418,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03542688488960266,
#    'OBJECTIFICATION': 0.05295649170875549,
#    'SEXUAL-VIOLENCE': 0.027276061475276947,
#    'STEREOTYPING-DOMINANCE': 0.4094869792461395}},
#  {'test_case': 'EXIST2025',
#   'id': '120967',
#   'value': {'NO': 0.6213505864143372,
#    'IDEOLOGICAL-INEQUALITY': 0.059085942804813385,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03309584781527519,
#    'OBJECTIFICATION': 0.08022622764110565,
#    'SEXUAL-VIOLENCE': 0.037712980061769485,
#    'STEREOTYPING-DOMINANCE': 0.12548679113388062}},
#  {'test_case': 'EXIST2025',
#   'id': '120968',
#   'value': {'NO': 0.24546487629413605,
#    'IDEOLOGICAL-INEQUALITY': 0.22445127367973328,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05729161575436592,
#    'OBJECTIFICATION': 0.059027787297964096,
#    'SEXUAL-VIOLENCE': 0.04799072816967964,
#    'STEREOTYPING-DOMINANCE': 0.4689302146434784}},
#  {'test_case': 'EXIST2025',
#   'id': '120969',
#   'value': {'NO': 0.3264327347278595,
#    'IDEOLOGICAL-INEQUALITY': 0.17471195757389069,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05017473176121712,
#    'OBJECTIFICATION': 0.05627649649977684,
#    'SEXUAL-VIOLENCE': 0.03599248453974724,
#    'STEREOTYPING-DOMINANCE': 0.3262117803096771}},
#  {'test_case': 'EXIST2025',
#   'id': '120970',
#   'value': {'NO': 0.770545244216919,
#    'IDEOLOGICAL-INEQUALITY': 0.04394369572401047,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.025241084396839142,
#    'OBJECTIFICATION': 0.05606084316968918,
#    'SEXUAL-VIOLENCE': 0.026099346578121185,
#    'STEREOTYPING-DOMINANCE': 0.14437279105186462}},
#  {'test_case': 'EXIST2025',
#   'id': '120971',
#   'value': {'NO': 0.37209486961364746,
#    'IDEOLOGICAL-INEQUALITY': 0.11694232374429703,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03759855777025223,
#    'OBJECTIFICATION': 0.05400743708014488,
#    'SEXUAL-VIOLENCE': 0.03125171363353729,
#    'STEREOTYPING-DOMINANCE': 0.4036458432674408}},
#  {'test_case': 'EXIST2025',
#   'id': '120972',
#   'value': {'NO': 0.23865671455860138,
#    'IDEOLOGICAL-INEQUALITY': 0.2172282189130783,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.057119399309158325,
#    'OBJECTIFICATION': 0.05617251992225647,
#    'SEXUAL-VIOLENCE': 0.04246897250413895,
#    'STEREOTYPING-DOMINANCE': 0.3603097200393677}},
#  {'test_case': 'EXIST2025',
#   'id': '120973',
#   'value': {'NO': 0.22038352489471436,
#    'IDEOLOGICAL-INEQUALITY': 0.20859798789024353,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.05504289269447327,
#    'OBJECTIFICATION': 0.053255073726177216,
#    'SEXUAL-VIOLENCE': 0.03862077370285988,
#    'STEREOTYPING-DOMINANCE': 0.4471507966518402}},
#  {'test_case': 'EXIST2025',
#   'id': '120974',
#   'value': {'NO': 0.8411708474159241,
#    'IDEOLOGICAL-INEQUALITY': 0.026844898238778114,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02485775575041771,
#    'OBJECTIFICATION': 0.06975755840539932,
#    'SEXUAL-VIOLENCE': 0.027225732803344727,
#    'STEREOTYPING-DOMINANCE': 0.08730015903711319}},
#  {'test_case': 'EXIST2025',
#   'id': '120975',
#   'value': {'NO': 0.6892863512039185,
#    'IDEOLOGICAL-INEQUALITY': 0.038641758263111115,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.023342512547969818,
#    'OBJECTIFICATION': 0.0469338558614254,
#    'SEXUAL-VIOLENCE': 0.018971361219882965,
#    'STEREOTYPING-DOMINANCE': 0.18172171711921692}},
#  {'test_case': 'EXIST2025',
#   'id': '120976',
#   'value': {'NO': 0.2874724864959717,
#    'IDEOLOGICAL-INEQUALITY': 0.1603933721780777,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.048032645136117935,
#    'OBJECTIFICATION': 0.0585872121155262,
#    'SEXUAL-VIOLENCE': 0.03543167933821678,
#    'STEREOTYPING-DOMINANCE': 0.4780523180961609}},
#  {'test_case': 'EXIST2025',
#   'id': '120977',
#   'value': {'NO': 0.2704315185546875,
#    'IDEOLOGICAL-INEQUALITY': 0.1614551991224289,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04923684522509575,
#    'OBJECTIFICATION': 0.061850082129240036,
#    'SEXUAL-VIOLENCE': 0.03943602740764618,
#    'STEREOTYPING-DOMINANCE': 0.42422735691070557}},
#  {'test_case': 'EXIST2025',
#   'id': '120978',
#   'value': {'NO': 0.6401914358139038,
#    'IDEOLOGICAL-INEQUALITY': 0.06698471307754517,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03570026904344559,
#    'OBJECTIFICATION': 0.05636707693338394,
#    'SEXUAL-VIOLENCE': 0.032219089567661285,
#    'STEREOTYPING-DOMINANCE': 0.1564314365386963}},
#  {'test_case': 'EXIST2025',
#   'id': '120979',
#   'value': {'NO': 0.7554264664649963,
#    'IDEOLOGICAL-INEQUALITY': 0.04390975087881088,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03034392185509205,
#    'OBJECTIFICATION': 0.06359899044036865,
#    'SEXUAL-VIOLENCE': 0.034728821367025375,
#    'STEREOTYPING-DOMINANCE': 0.10561507195234299}},
#  {'test_case': 'EXIST2025',
#   'id': '120980',
#   'value': {'NO': 0.24702335894107819,
#    'IDEOLOGICAL-INEQUALITY': 0.1886589229106903,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04646824300289154,
#    'OBJECTIFICATION': 0.052945468574762344,
#    'SEXUAL-VIOLENCE': 0.036198340356349945,
#    'STEREOTYPING-DOMINANCE': 0.3151204586029053}},
#  {'test_case': 'EXIST2025',
#   'id': '120981',
#   'value': {'NO': 0.6748638153076172,
#    'IDEOLOGICAL-INEQUALITY': 0.05083850398659706,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.029456933960318565,
#    'OBJECTIFICATION': 0.05342870578169823,
#    'SEXUAL-VIOLENCE': 0.02650764025747776,
#    'STEREOTYPING-DOMINANCE': 0.14164668321609497}},
#  {'test_case': 'EXIST2025',
#   'id': '120982',
#   'value': {'NO': 0.3420355021953583,
#    'IDEOLOGICAL-INEQUALITY': 0.0951155424118042,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.032940156757831573,
#    'OBJECTIFICATION': 0.060684606432914734,
#    'SEXUAL-VIOLENCE': 0.026450980454683304,
#    'STEREOTYPING-DOMINANCE': 0.37255293130874634}},
#  {'test_case': 'EXIST2025',
#   'id': '120983',
#   'value': {'NO': 0.7130110263824463,
#    'IDEOLOGICAL-INEQUALITY': 0.04386376962065697,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02419179491698742,
#    'OBJECTIFICATION': 0.049988314509391785,
#    'SEXUAL-VIOLENCE': 0.02561979368329048,
#    'STEREOTYPING-DOMINANCE': 0.12637893855571747}},
#  {'test_case': 'EXIST2025',
#   'id': '120984',
#   'value': {'NO': 0.2046433836221695,
#    'IDEOLOGICAL-INEQUALITY': 0.17537017166614532,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.04929732531309128,
#    'OBJECTIFICATION': 0.06782898306846619,
#    'SEXUAL-VIOLENCE': 0.0336775965988636,
#    'STEREOTYPING-DOMINANCE': 0.40639904141426086}},
#  {'test_case': 'EXIST2025',
#   'id': '120985',
#   'value': {'NO': 0.6552155613899231,
#    'IDEOLOGICAL-INEQUALITY': 0.04589579254388809,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02747204899787903,
#    'OBJECTIFICATION': 0.05534439906477928,
#    'SEXUAL-VIOLENCE': 0.025077814236283302,
#    'STEREOTYPING-DOMINANCE': 0.1529616266489029}},
#  {'test_case': 'EXIST2025',
#   'id': '120986',
#   'value': {'NO': 0.6227595210075378,
#    'IDEOLOGICAL-INEQUALITY': 0.054791159927845,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02413962036371231,
#    'OBJECTIFICATION': 0.04291193559765816,
#    'SEXUAL-VIOLENCE': 0.021598825231194496,
#    'STEREOTYPING-DOMINANCE': 0.1785915195941925}},
#  {'test_case': 'EXIST2025',
#   'id': '120987',
#   'value': {'NO': 0.7519803047180176,
#    'IDEOLOGICAL-INEQUALITY': 0.03615056723356247,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.024053864181041718,
#    'OBJECTIFICATION': 0.05373732000589371,
#    'SEXUAL-VIOLENCE': 0.023098483681678772,
#    'STEREOTYPING-DOMINANCE': 0.1294003278017044}},
#  {'test_case': 'EXIST2025',
#   'id': '120988',
#   'value': {'NO': 0.7284114956855774,
#    'IDEOLOGICAL-INEQUALITY': 0.048280246555805206,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03188810124993324,
#    'OBJECTIFICATION': 0.07975494116544724,
#    'SEXUAL-VIOLENCE': 0.039328206330537796,
#    'STEREOTYPING-DOMINANCE': 0.09188424050807953}},
#  {'test_case': 'EXIST2025',
#   'id': '120989',
#   'value': {'NO': 0.25977376103401184,
#    'IDEOLOGICAL-INEQUALITY': 0.17608791589736938,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0477091409265995,
#    'OBJECTIFICATION': 0.06475157290697098,
#    'SEXUAL-VIOLENCE': 0.03797893598675728,
#    'STEREOTYPING-DOMINANCE': 0.30586767196655273}},
#  {'test_case': 'EXIST2025',
#   'id': '120990',
#   'value': {'NO': 0.8361886143684387,
#    'IDEOLOGICAL-INEQUALITY': 0.03050473891198635,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.024845721200108528,
#    'OBJECTIFICATION': 0.06944578140974045,
#    'SEXUAL-VIOLENCE': 0.03027358092367649,
#    'STEREOTYPING-DOMINANCE': 0.08303729444742203}},
#  {'test_case': 'EXIST2025',
#   'id': '120991',
#   'value': {'NO': 0.7660011649131775,
#    'IDEOLOGICAL-INEQUALITY': 0.04180571809411049,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02460573986172676,
#    'OBJECTIFICATION': 0.05992570146918297,
#    'SEXUAL-VIOLENCE': 0.031752847135066986,
#    'STEREOTYPING-DOMINANCE': 0.09246720373630524}},
#  {'test_case': 'EXIST2025',
#   'id': '120992',
#   'value': {'NO': 0.6174501776695251,
#    'IDEOLOGICAL-INEQUALITY': 0.08080516010522842,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03193671256303787,
#    'OBJECTIFICATION': 0.05725224316120148,
#    'SEXUAL-VIOLENCE': 0.03265780210494995,
#    'STEREOTYPING-DOMINANCE': 0.1511438488960266}},
#  {'test_case': 'EXIST2025',
#   'id': '120993',
#   'value': {'NO': 0.7090761661529541,
#    'IDEOLOGICAL-INEQUALITY': 0.04953299090266228,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02394965849816799,
#    'OBJECTIFICATION': 0.05309254676103592,
#    'SEXUAL-VIOLENCE': 0.0263932254165411,
#    'STEREOTYPING-DOMINANCE': 0.13922148942947388}},
#  {'test_case': 'EXIST2025',
#   'id': '120994',
#   'value': {'NO': 0.5830296874046326,
#    'IDEOLOGICAL-INEQUALITY': 0.11983051896095276,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.06378789991140366,
#    'OBJECTIFICATION': 0.10364912450313568,
#    'SEXUAL-VIOLENCE': 0.06427951902151108,
#    'STEREOTYPING-DOMINANCE': 0.1675393283367157}},
#  {'test_case': 'EXIST2025',
#   'id': '120995',
#   'value': {'NO': 0.7570731043815613,
#    'IDEOLOGICAL-INEQUALITY': 0.053492531180381775,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03459295257925987,
#    'OBJECTIFICATION': 0.06625600904226303,
#    'SEXUAL-VIOLENCE': 0.042044080793857574,
#    'STEREOTYPING-DOMINANCE': 0.10399690270423889}},
#  {'test_case': 'EXIST2025',
#   'id': '120996',
#   'value': {'NO': 0.5657482147216797,
#    'IDEOLOGICAL-INEQUALITY': 0.07115321606397629,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.0336010605096817,
#    'OBJECTIFICATION': 0.06490685045719147,
#    'SEXUAL-VIOLENCE': 0.030780814588069916,
#    'STEREOTYPING-DOMINANCE': 0.14308926463127136}},
#  {'test_case': 'EXIST2025',
#   'id': '120997',
#   'value': {'NO': 0.1126922070980072,
#    'IDEOLOGICAL-INEQUALITY': 0.48326680064201355,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.10618031024932861,
#    'OBJECTIFICATION': 0.09986943006515503,
#    'SEXUAL-VIOLENCE': 0.09205438196659088,
#    'STEREOTYPING-DOMINANCE': 0.27358949184417725}},
#  {'test_case': 'EXIST2025',
#   'id': '120998',
#   'value': {'NO': 0.6805095076560974,
#    'IDEOLOGICAL-INEQUALITY': 0.04799390956759453,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.02242884412407875,
#    'OBJECTIFICATION': 0.04956181347370148,
#    'SEXUAL-VIOLENCE': 0.023942645639181137,
#    'STEREOTYPING-DOMINANCE': 0.13825161755084991}},
#  {'test_case': 'EXIST2025',
#   'id': '120999',
#   'value': {'NO': 0.6279057264328003,
#    'IDEOLOGICAL-INEQUALITY': 0.074952132999897,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.03466494753956795,
#    'OBJECTIFICATION': 0.06151443347334862,
#    'SEXUAL-VIOLENCE': 0.03766987472772598,
#    'STEREOTYPING-DOMINANCE': 0.12930503487586975}},
#  {'test_case': 'EXIST2025',
#   'id': '121000',
#   'value': {'NO': 0.11071523278951645,
#    'IDEOLOGICAL-INEQUALITY': 0.47157159447669983,
#    'MISOGYNY-NON-SEXUAL-VIOLENCE': 0.10909402370452881,
#    'OBJECTIFICATION': 0.10441036522388458,
#    'SEXUAL-VIOLENCE': 0.09979706257581711,
#    'STEREOTYPING-DOMINANCE': 0.2614101767539978}},
#  ...]

# %% [markdown]
# ## Hard

# %%
#liberate GPU RAM
import torch
torch.cuda.empty_cache()

# %%
bert1 = Test(soft=False, model_name="hate-speech-CNERG/bert-base-uncased-hatexplain", label_name="label1")
bert1.train(epochs=3)
bert1.build_submission(task_name="task3_1",run=2)
# Out:
# Map:   0%|          | 0/2131 [00:00<?, ? examples/s]
# Map:   0%|          | 0/377 [00:00<?, ? examples/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hate-speech-CNERG/bert-base-uncased-hatexplain and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([3, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([3]) in the checkpoint and torch.Size([2]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-4-54a9ba2e44c6>:136: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   self.trainer = Trainer(
#     <div>
#
#       <progress value='801' max='801' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [801/801 03:48, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.628192</td>
#       <td>0.652520</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.597600</td>
#       <td>0.642867</td>
#       <td>0.660477</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.597600</td>
#       <td>0.718777</td>
#       <td>0.633952</td>
#     </tr>
#   </tbody>
# </table><p>
# Submission saved to task3_1_hard_ScalaR_2.json
# [{'test_case': 'EXIST2025', 'id': '120001', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120002', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120003', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120004', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120005', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120006', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120007', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120008', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120009', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120010', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120011', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120012', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120013', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120014', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120015', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120016', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120017', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120018', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120019', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120020', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120021', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120022', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120023', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120024', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120025', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120026', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120027', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120028', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120029', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120030', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120031', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120032', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120033', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120034', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120035', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120036', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120037', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120038', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120039', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120040', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120041', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120042', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120043', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120044', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120045', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120046', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120047', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120048', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120049', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120050', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120051', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120052', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120053', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120054', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120055', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120056', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120057', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120058', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120059', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120060', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120061', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120062', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120063', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120064', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120065', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120066', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120067', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120068', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120069', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120070', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120071', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120072', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120073', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120074', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120075', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120076', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120077', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120078', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120079', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120080', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120081', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120082', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120083', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120084', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120085', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120086', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120087', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120088', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120089', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120090', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120091', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120092', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120093', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120094', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120095', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120096', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120097', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120098', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120099', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120100', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120101', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120102', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120103', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120104', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120105', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120106', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120107', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120108', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120109', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120110', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120111', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120112', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120113', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120114', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120115', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120116', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120117', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120118', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120119', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120120', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120121', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120122', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120123', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120124', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120125', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120126', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120127', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120128', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120129', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120130', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120131', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120132', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120133', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120134', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120135', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120136', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120137', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120138', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120139', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120140', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120141', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120142', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120143', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120144', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120145', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120146', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120147', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120148', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120149', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120150', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120151', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120152', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120153', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120154', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120155', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120156', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120157', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120158', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120159', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120160', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120161', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120162', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120163', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120164', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120165', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120166', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120167', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120168', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120169', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120170', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120171', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120172', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120173', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120174', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120175', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120176', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120177', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120178', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120179', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120180', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120181', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120182', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120183', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120184', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120185', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120186', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120187', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120188', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120189', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120190', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120191', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120192', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120193', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120194', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120195', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120196', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120197', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120198', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120199', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120200', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120201', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120202', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120203', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120204', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120205', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120206', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120207', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120208', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120209', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120210', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120211', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120212', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120213', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120214', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120215', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120216', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120217', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120218', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120219', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120220', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120221', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120222', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120223', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120224', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120225', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120226', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120227', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120228', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120229', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120230', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120231', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120232', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120233', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120234', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120235', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120236', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120237', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120238', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120239', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120240', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120241', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120242', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120243', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120244', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120245', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120246', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120247', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120248', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120249', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120250', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120251', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120252', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120253', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120254', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120255', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120256', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120257', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120258', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120259', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120260', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120261', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120262', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120263', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120264', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120265', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120266', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120267', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120268', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120269', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120270', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120271', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120272', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120273', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120274', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120275', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120276', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120277', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120278', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120279', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120280', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120281', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120282', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120283', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120284', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120285', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120286', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120287', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120288', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120289', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120290', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120291', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120292', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120293', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120294', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120295', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120296', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120297', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120298', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120299', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120300', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120301', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120302', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120303', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120304', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120305', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120306', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120307', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120308', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120309', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120310', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120311', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120312', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120313', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120314', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120315', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120316', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120317', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120318', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120319', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120320', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120321', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120322', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120323', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120324', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120325', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120326', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120327', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120328', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120329', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120330', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120331', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120332', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120333', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120334', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120335', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120336', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120337', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120338', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120339', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120340', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120341', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120342', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120343', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120344', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120345', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120346', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120347', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120348', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120349', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120350', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120351', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120352', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120353', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120354', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120355', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120356', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120357', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120358', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120359', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120360', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120361', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120362', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120363', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120364', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120365', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120366', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120367', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120368', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120369', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120370', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120371', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120372', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120373', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120374', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120375', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120376', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120377', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120378', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120379', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120380', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120381', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120382', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120383', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120384', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120385', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120386', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120387', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120388', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120389', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120390', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120391', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120392', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120393', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120394', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120395', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120396', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120397', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120398', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120399', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120400', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120401', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120402', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120403', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120404', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120405', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120406', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120407', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120408', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120409', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120410', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120411', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120412', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120413', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120414', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120415', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120416', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120417', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120418', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120419', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120420', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120421', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120422', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120423', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120424', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120425', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120426', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120427', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120428', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120429', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120430', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120431', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120432', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120433', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120434', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120435', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120436', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120437', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120438', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120439', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120440', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120441', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120442', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120443', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120444', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120445', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120446', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120447', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120448', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120449', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120450', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120451', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120452', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120453', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120454', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120455', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120456', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120457', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120458', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120459', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120460', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120461', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120462', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120463', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120464', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120465', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120466', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120467', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120468', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120469', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120470', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120471', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120472', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120473', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120474', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120475', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120476', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120477', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120478', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120479', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120480', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120481', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120482', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120483', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120484', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120485', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120486', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120487', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120488', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120489', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120490', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120491', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120492', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120493', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120494', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120495', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120496', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120497', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120498', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120499', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120500', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120501', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120502', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120503', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120504', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120505', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120506', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120507', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120508', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120509', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120510', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120511', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120512', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120513', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120514', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120515', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120516', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120517', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120518', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120519', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120520', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120521', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120522', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120523', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120524', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120525', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120526', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120527', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120528', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120529', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120530', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120531', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120532', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120533', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120534', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120535', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120536', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120537', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120538', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120539', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120540', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120541', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120542', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120543', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120544', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120545', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120546', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120547', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120548', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120549', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120550', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120551', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120552', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120553', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120554', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120555', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120556', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120557', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120558', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120559', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120560', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120561', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120562', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120563', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120564', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120565', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120566', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120567', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120568', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120569', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120570', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120571', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120572', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120573', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120574', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120575', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120576', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120577', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120578', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120579', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120580', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120581', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120582', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120583', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120584', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120585', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120586', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120587', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120588', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120589', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120590', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120591', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120592', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120593', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120594', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120595', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120596', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120597', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120598', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120599', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120600', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120601', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120602', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120603', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120604', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120605', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120606', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120607', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120608', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120609', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120610', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120611', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120612', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120613', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120614', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120615', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120616', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120617', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120618', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120619', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120620', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120621', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120622', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120623', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120624', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120625', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120626', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120627', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120628', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120629', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120630', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120631', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120632', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120633', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120634', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120635', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120636', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120637', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120638', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120639', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120640', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120641', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120642', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120643', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120644', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120645', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120646', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120647', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120648', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120649', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120650', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120651', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120652', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120653', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120654', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120655', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120656', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120657', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120658', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120659', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120660', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120661', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120662', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120663', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120664', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120665', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120666', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120667', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120668', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120669', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120670', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120671', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120672', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120673', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120674', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120675', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120676', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120677', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120678', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120679', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120680', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120681', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120682', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120683', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120684', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120685', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120686', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120687', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120688', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120689', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120690', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120691', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120692', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120693', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120694', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120695', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120696', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120697', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120698', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120699', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120700', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120701', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120702', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120703', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120704', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120705', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120706', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120707', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120708', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120709', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120710', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120711', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120712', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120713', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120714', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120715', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120716', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120717', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120718', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120719', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120720', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120721', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120722', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120723', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120724', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120725', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120726', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120727', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120728', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120729', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120730', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120731', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120732', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120733', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120734', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120735', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120736', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120737', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120738', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120739', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120740', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120741', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120742', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120743', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120744', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120745', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120746', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120747', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120748', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120749', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120750', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120751', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120752', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120753', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120754', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120755', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120756', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120757', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120758', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120759', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120760', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120761', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120762', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120763', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120764', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120765', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120766', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120767', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120768', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120769', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120770', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120771', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120772', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120773', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120774', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120775', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120776', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120777', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120778', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120779', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120780', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120781', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120782', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120783', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120784', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120785', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120786', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120787', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120788', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120789', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120790', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120791', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120792', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120793', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120794', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120795', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120796', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120797', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120798', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120799', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120800', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120801', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120802', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120803', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120804', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120805', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120806', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120807', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120808', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120809', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120810', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120811', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120812', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120813', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120814', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120815', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120816', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120817', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120818', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120819', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120820', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120821', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120822', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120823', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120824', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120825', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120826', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120827', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120828', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120829', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120830', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120831', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120832', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120833', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120834', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120835', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120836', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120837', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120838', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120839', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120840', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120841', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120842', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120843', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120844', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120845', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120846', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120847', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120848', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120849', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120850', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120851', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120852', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120853', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120854', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120855', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120856', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120857', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120858', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120859', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120860', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120861', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120862', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120863', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120864', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120865', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120866', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120867', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120868', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120869', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120870', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120871', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120872', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120873', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120874', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120875', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120876', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120877', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120878', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120879', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120880', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120881', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120882', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120883', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120884', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120885', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120886', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120887', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120888', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120889', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120890', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120891', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120892', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120893', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120894', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120895', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120896', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120897', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120898', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120899', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120900', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120901', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120902', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120903', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120904', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120905', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120906', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120907', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120908', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120909', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120910', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120911', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120912', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120913', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120914', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120915', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120916', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120917', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120918', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120919', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120920', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120921', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120922', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120923', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120924', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120925', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120926', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120927', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120928', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120929', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120930', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120931', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120932', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120933', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120934', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120935', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120936', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120937', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120938', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120939', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120940', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120941', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120942', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120943', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120944', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120945', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120946', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120947', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120948', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120949', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120950', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120951', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120952', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120953', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120954', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120955', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120956', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120957', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120958', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120959', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120960', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120961', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120962', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120963', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120964', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120965', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120966', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120967', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120968', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120969', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120970', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120971', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120972', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120973', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120974', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120975', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120976', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120977', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120978', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120979', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120980', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120981', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120982', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120983', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120984', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120985', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120986', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120987', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120988', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120989', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120990', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120991', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120992', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120993', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120994', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120995', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120996', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120997', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '120998', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120999', 'value': 'YES'},
#  {'test_case': 'EXIST2025', 'id': '121000', 'value': 'YES'},
#  ...]

# %%
bert2 = Test(soft=False, model_name="hate-speech-CNERG/bert-base-uncased-hatexplain", label_name="label2")
bert2.train(epochs=3)
bert2.build_submission(task_name="task3_2",run=2)
# Out:
# Map:   0%|          | 0/2096 [00:00<?, ? examples/s]
# Map:   0%|          | 0/370 [00:00<?, ? examples/s]
# <ipython-input-4-54a9ba2e44c6>:136: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   self.trainer = Trainer(
#     <div>
#
#       <progress value='786' max='786' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [786/786 04:03, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.918856</td>
#       <td>0.589189</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.898600</td>
#       <td>0.905311</td>
#       <td>0.591892</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.898600</td>
#       <td>1.005541</td>
#       <td>0.581081</td>
#     </tr>
#   </tbody>
# </table><p>
# Submission saved to task3_2_hard_ScalaR_2.json
# [{'test_case': 'EXIST2025', 'id': '120001', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120002', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120003', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120004', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120005', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120006', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120007', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120008', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120009', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120010', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120011', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120012', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120013', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120014', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120015', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120016', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120017', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120018', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120019', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120020', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120021', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120022', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120023', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120024', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120025', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120026', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120027', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120028', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120029', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120030', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120031', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120032', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120033', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120034', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120035', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120036', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120037', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120038', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120039', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120040', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120041', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120042', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120043', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120044', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120045', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120046', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120047', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120048', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120049', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120050', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120051', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120052', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120053', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120054', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120055', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120056', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120057', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120058', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120059', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120060', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120061', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120062', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120063', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120064', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120065', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120066', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120067', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120068', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120069', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120070', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120071', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120072', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120073', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120074', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120075', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120076', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120077', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120078', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120079', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120080', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120081', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120082', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120083', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120084', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120085', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120086', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120087', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120088', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120089', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120090', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120091', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120092', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120093', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120094', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120095', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120096', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120097', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120098', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120099', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120100', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120101', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120102', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120103', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120104', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120105', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120106', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120107', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120108', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120109', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120110', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120111', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120112', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120113', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120114', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120115', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120116', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120117', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120118', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120119', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120120', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120121', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120122', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120123', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120124', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120125', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120126', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120127', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120128', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120129', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120130', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120131', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120132', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120133', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120134', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120135', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120136', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120137', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120138', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120139', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120140', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120141', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120142', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120143', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120144', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120145', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120146', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120147', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120148', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120149', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120150', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120151', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120152', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120153', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120154', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120155', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120156', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120157', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120158', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120159', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120160', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120161', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120162', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120163', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120164', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120165', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120166', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120167', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120168', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120169', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120170', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120171', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120172', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120173', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120174', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120175', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120176', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120177', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120178', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120179', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120180', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120181', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120182', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120183', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120184', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120185', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120186', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120187', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120188', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120189', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120190', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120191', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120192', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120193', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120194', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120195', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120196', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120197', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120198', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120199', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120200', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120201', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120202', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120203', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120204', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120205', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120206', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120207', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120208', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120209', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120210', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120211', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120212', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120213', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120214', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120215', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120216', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120217', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120218', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120219', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120220', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120221', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120222', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120223', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120224', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120225', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120226', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120227', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120228', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120229', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120230', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120231', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120232', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120233', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120234', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120235', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120236', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120237', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120238', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120239', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120240', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120241', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120242', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120243', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120244', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120245', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120246', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120247', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120248', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120249', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120250', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120251', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120252', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120253', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120254', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120255', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120256', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120257', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120258', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120259', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120260', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120261', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120262', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120263', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120264', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120265', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120266', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120267', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120268', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120269', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120270', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120271', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120272', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120273', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120274', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120275', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120276', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120277', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120278', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120279', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120280', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120281', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120282', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120283', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120284', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120285', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120286', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120287', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120288', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120289', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120290', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120291', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120292', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120293', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120294', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120295', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120296', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120297', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120298', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120299', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120300', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120301', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120302', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120303', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120304', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120305', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120306', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120307', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120308', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120309', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120310', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120311', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120312', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120313', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120314', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120315', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120316', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120317', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120318', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120319', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120320', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120321', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120322', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120323', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120324', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120325', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120326', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120327', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120328', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120329', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120330', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120331', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120332', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120333', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120334', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120335', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120336', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120337', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120338', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120339', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120340', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120341', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120342', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120343', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120344', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120345', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120346', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120347', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120348', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120349', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120350', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120351', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120352', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120353', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120354', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120355', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120356', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120357', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120358', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120359', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120360', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120361', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120362', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120363', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120364', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120365', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120366', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120367', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120368', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120369', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120370', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120371', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120372', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120373', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120374', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120375', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120376', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120377', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120378', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120379', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120380', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120381', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120382', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120383', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120384', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120385', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120386', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120387', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120388', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120389', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120390', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120391', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120392', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120393', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120394', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120395', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120396', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120397', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120398', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120399', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120400', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120401', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120402', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120403', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120404', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120405', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120406', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120407', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120408', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120409', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120410', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120411', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120412', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120413', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120414', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120415', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120416', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120417', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120418', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120419', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120420', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120421', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120422', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120423', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120424', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120425', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120426', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120427', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120428', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120429', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120430', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120431', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120432', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120433', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120434', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120435', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120436', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120437', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120438', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120439', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120440', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120441', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120442', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120443', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120444', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120445', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120446', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120447', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120448', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120449', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120450', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120451', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120452', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120453', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120454', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120455', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120456', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120457', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120458', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120459', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120460', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120461', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120462', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120463', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120464', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120465', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120466', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120467', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120468', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120469', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120470', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120471', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120472', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120473', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120474', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120475', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120476', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120477', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120478', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120479', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120480', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120481', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120482', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120483', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120484', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120485', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120486', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120487', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120488', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120489', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120490', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120491', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120492', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120493', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120494', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120495', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120496', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120497', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120498', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120499', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120500', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120501', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120502', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120503', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120504', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120505', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120506', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120507', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120508', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120509', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120510', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120511', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120512', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120513', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120514', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120515', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120516', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120517', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120518', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120519', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120520', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120521', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120522', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120523', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120524', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120525', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120526', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120527', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120528', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120529', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120530', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120531', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120532', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120533', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120534', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120535', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120536', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120537', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120538', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120539', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120540', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120541', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120542', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120543', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120544', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120545', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120546', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120547', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120548', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120549', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120550', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120551', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120552', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120553', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120554', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120555', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120556', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120557', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120558', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120559', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120560', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120561', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120562', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120563', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120564', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120565', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120566', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120567', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120568', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120569', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120570', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120571', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120572', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120573', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120574', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120575', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120576', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120577', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120578', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120579', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120580', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120581', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120582', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120583', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120584', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120585', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120586', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120587', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120588', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120589', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120590', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120591', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120592', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120593', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120594', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120595', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120596', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120597', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120598', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120599', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120600', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120601', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120602', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120603', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120604', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120605', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120606', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120607', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120608', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120609', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120610', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120611', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120612', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120613', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120614', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120615', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120616', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120617', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120618', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120619', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120620', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120621', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120622', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120623', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120624', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120625', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120626', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120627', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120628', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120629', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120630', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120631', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120632', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120633', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120634', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120635', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120636', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120637', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120638', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120639', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120640', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120641', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120642', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120643', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120644', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120645', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120646', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120647', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120648', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120649', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120650', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120651', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120652', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120653', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120654', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120655', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120656', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120657', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120658', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120659', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120660', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120661', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120662', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120663', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120664', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120665', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120666', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120667', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120668', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120669', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120670', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120671', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120672', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120673', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120674', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120675', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120676', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120677', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120678', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120679', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120680', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120681', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120682', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120683', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120684', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120685', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120686', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120687', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120688', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120689', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120690', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120691', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120692', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120693', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120694', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120695', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120696', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120697', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120698', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120699', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120700', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120701', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120702', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120703', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120704', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120705', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120706', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120707', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120708', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120709', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120710', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120711', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120712', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120713', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120714', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120715', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120716', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120717', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120718', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120719', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120720', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120721', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120722', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120723', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120724', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120725', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120726', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120727', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120728', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120729', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120730', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120731', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120732', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120733', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120734', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120735', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120736', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120737', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120738', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120739', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120740', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120741', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120742', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120743', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120744', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120745', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120746', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120747', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120748', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120749', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120750', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120751', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120752', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120753', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120754', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120755', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120756', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120757', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120758', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120759', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120760', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120761', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120762', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120763', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120764', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120765', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120766', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120767', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120768', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120769', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120770', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120771', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120772', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120773', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120774', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120775', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120776', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120777', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120778', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120779', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120780', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120781', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120782', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120783', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120784', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120785', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120786', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120787', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120788', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120789', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120790', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120791', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120792', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120793', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120794', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120795', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120796', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120797', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120798', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120799', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120800', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120801', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120802', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120803', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120804', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120805', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120806', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120807', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120808', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120809', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120810', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120811', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120812', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120813', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120814', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120815', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120816', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120817', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120818', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120819', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120820', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120821', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120822', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120823', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120824', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120825', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120826', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120827', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120828', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120829', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120830', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120831', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120832', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120833', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120834', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120835', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120836', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120837', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120838', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120839', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120840', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120841', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120842', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120843', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120844', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120845', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120846', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120847', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120848', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120849', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120850', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120851', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120852', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120853', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120854', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120855', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120856', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120857', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120858', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120859', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120860', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120861', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120862', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120863', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120864', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120865', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120866', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120867', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120868', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120869', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120870', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120871', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120872', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120873', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120874', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120875', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120876', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120877', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120878', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120879', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120880', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120881', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120882', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120883', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120884', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120885', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120886', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120887', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120888', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120889', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120890', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120891', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120892', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120893', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120894', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120895', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120896', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120897', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120898', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120899', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120900', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120901', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120902', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120903', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120904', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120905', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120906', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120907', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120908', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120909', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120910', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120911', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120912', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120913', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120914', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120915', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120916', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120917', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120918', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120919', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120920', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120921', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120922', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120923', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120924', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120925', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120926', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120927', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120928', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120929', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120930', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120931', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120932', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120933', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120934', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120935', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120936', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120937', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120938', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120939', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120940', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120941', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120942', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120943', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120944', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120945', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120946', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120947', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120948', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120949', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120950', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120951', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120952', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120953', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120954', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120955', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120956', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120957', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120958', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120959', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120960', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120961', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120962', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120963', 'value': 'JUDGEMENTAL'},
#  {'test_case': 'EXIST2025', 'id': '120964', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120965', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120966', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120967', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120968', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120969', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120970', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120971', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120972', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120973', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120974', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120975', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120976', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120977', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120978', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120979', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120980', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120981', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120982', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120983', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120984', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120985', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120986', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120987', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120988', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120989', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120990', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120991', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120992', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120993', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120994', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120995', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120996', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120997', 'value': 'DIRECT'},
#  {'test_case': 'EXIST2025', 'id': '120998', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '120999', 'value': 'NO'},
#  {'test_case': 'EXIST2025', 'id': '121000', 'value': 'DIRECT'},
#  ...]

# %%
bert3 = Test(soft=False, model_name="hate-speech-CNERG/bert-base-uncased-hatexplain", label_name="label3")
bert3.train(epochs=3)
bert3.build_submission(task_name="task3_3",run=2)
# Out:
# Map:   0%|          | 0/1937 [00:00<?, ? examples/s]
# Map:   0%|          | 0/342 [00:00<?, ? examples/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hate-speech-CNERG/bert-base-uncased-hatexplain and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([3, 768]) in the checkpoint and torch.Size([6, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([3]) in the checkpoint and torch.Size([6]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-4-54a9ba2e44c6>:136: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   self.trainer = Trainer(
#     <div>
#
#       <progress value='729' max='729' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [729/729 03:41, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1 Micro</th>
#       <th>F1 Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.328574</td>
#       <td>0.863548</td>
#       <td>0.126233</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.332288</td>
#       <td>0.866959</td>
#       <td>0.175042</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.323500</td>
#       <td>0.331233</td>
#       <td>0.864035</td>
#       <td>0.207232</td>
#     </tr>
#   </tbody>
# </table><p>
# Submission saved to task3_3_hard_ScalaR_2.json
# [{'test_case': 'EXIST2025', 'id': '120001', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120002', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120003',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120004',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120005', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120006', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120007',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120008',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120009', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120010',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120011', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120012', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120013',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120014', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120015', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120016',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120017', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120018', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120019', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120020', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120021',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120022',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120023', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120024', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120025', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120026',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120027',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120028', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120029',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120030',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120031',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120032', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120033', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120034',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120035',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120036', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120037', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120038', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120039', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120040',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120041', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120042',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120043', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120044',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120045',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120046', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120047',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120048',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120049', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120050',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120051',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120052', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120053', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120054', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120055', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120056',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120057',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120058',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120059', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120060',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120061',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120062',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120063',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120064',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120065',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120066',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120067',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120068', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120069',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120070',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120071',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120072', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120073', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120074', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120075', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120076', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120077',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120078',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120079',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120080',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120081', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120082', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120083', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120084', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120085', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120086', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120087', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120088',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120089',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120090',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120091',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120092',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120093', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120094', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120095',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120096',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120097', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120098',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120099', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120100', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120101',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120102', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120103', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120104',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120105',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120106',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120107', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120108',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120109',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120110',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120111',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120112',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120113',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120114',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120115',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120116',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120117', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120118',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120119', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120120',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120121',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120122',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120123', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120124',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120125',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120126',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120127',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120128',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120129',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120130',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120131',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120132',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120133', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120134',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120135', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120136', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120137',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120138', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120139',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120140',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120141', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120142', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120143',
#   'value': [['IDEOLOGICAL-INEQUALITY', 'STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120144', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120145',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120146', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120147', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120148', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120149', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120150', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120151', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120152', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120153', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120154', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120155', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120156',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120157', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120158', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120159', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120160',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120161', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120162',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120163', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120164', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120165', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120166', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120167', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120168',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120169',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120170', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120171', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120172',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120173', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120174',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120175', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120176', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120177', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120178', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120179', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120180', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120181', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120182', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120183', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120184', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120185', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120186', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120187', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120188',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120189', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120190', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120191', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120192', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120193', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120194',
#   'value': [['IDEOLOGICAL-INEQUALITY', 'STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120195', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120196',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120197', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120198',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120199', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120200',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120201', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120202', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120203', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120204',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120205', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120206',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120207', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120208', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120209',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120210',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120211', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120212', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120213', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120214',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120215',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120216', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120217', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120218',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120219', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120220',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120221',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120222',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120223', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120224', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120225',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120226',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120227', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120228', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120229', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120230', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120231',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120232',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120233', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120234', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120235',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120236',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120237',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120238',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120239',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120240',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120241',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120242',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120243', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120244',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120245', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120246',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120247',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120248',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120249',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120250',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120251',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120252',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120253',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120254',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120255',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120256',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120257', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120258',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120259',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120260', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120261',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120262', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120263', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120264',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120265',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120266',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120267', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120268', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120269', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120270', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120271', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120272',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120273', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120274', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120275', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120276', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120277',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120278', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120279',
#   'value': [['-', 'STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120280', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120281',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120282',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120283',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120284', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120285', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120286',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120287', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120288', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120289', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120290',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120291', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120292', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120293', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120294', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120295', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120296', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120297', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120298',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120299', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120300',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120301', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120302', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120303', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120304', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120305', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120306', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120307', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120308', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120309',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120310',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120311',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120312',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120313', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120314', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120315', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120316', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120317',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120318',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120319',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120320', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120321',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120322', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120323', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120324', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120325', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120326', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120327', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120328',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120329', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120330', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120331', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120332',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120333',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120334', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120335',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120336',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120337', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120338',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120339',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120340',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120341', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120342', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120343',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120344', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120345', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120346', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120347', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120348', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120349', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120350', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120351',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120352',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120353',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120354',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120355', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120356',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120357',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120358',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120359',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120360', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120361',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120362', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120363', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120364',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120365', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120366',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120367',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120368', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120369', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120370', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120371', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120372', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120373', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120374', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120375', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120376', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120377', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120378', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120379', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120380', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120381', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120382',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120383', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120384',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120385',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120386', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120387', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120388',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120389', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120390', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120391', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120392', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120393',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120394', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120395',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120396', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120397',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120398', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120399', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120400', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120401',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120402',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120403', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120404', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120405', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120406', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120407',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120408', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120409',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120410', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120411',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120412', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120413', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120414', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120415', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120416', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120417', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120418', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120419', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120420', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120421', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120422', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120423', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120424', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120425',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120426', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120427', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120428', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120429', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120430', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120431', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120432', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120433',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120434',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120435', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120436', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120437', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120438', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120439', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120440', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120441', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120442', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120443', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120444',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120445', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120446', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120447', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120448', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120449', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120450', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120451', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120452', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120453', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120454', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120455', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120456', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120457', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120458',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120459', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120460', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120461', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120462', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120463',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120464', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120465', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120466', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120467', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120468', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120469', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120470', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120471', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120472', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120473', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120474', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120475', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120476', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120477', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120478',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120479', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120480', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120481', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120482',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120483', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120484',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120485', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120486', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120487', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120488', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120489',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120490', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120491',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120492', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120493', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120494', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120495',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120496', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120497',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120498', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120499',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120500', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120501', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120502',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120503', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120504', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120505', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120506', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120507', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120508', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120509', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120510', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120511', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120512', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120513', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120514',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120515', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120516',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120517',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120518',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120519', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120520',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120521',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120522', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120523', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120524', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120525', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120526', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120527', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120528', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120529', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120530', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120531', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120532', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120533', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120534', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120535', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120536', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120537',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120538', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120539', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120540', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120541',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120542', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120543',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120544', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120545', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120546', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120547', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120548', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120549', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120550',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120551',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120552', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120553', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120554', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120555', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120556', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120557', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120558', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120559', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120560',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120561', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120562',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120563', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120564', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120565', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120566', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120567', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120568', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120569', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120570', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120571',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120572', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120573',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120574', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120575', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120576', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120577',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120578', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120579', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120580', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120581', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120582', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120583', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120584', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120585', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120586', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120587', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120588', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120589', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120590', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120591', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120592', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120593', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120594', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120595', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120596',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120597',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120598', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120599', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120600', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120601',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120602', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120603', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120604', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120605',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120606', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120607', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120608', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120609', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120610', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120611', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120612', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120613', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120614', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120615', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120616', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120617', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120618',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120619', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120620', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120621', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120622', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120623', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120624', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120625', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120626', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120627', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120628', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120629', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120630', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120631',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120632', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120633', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120634', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120635', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120636', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120637', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120638',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120639', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120640',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120641',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120642', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120643', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120644', 'value': [['-']]},
# ...
#  {'test_case': 'EXIST2025', 'id': '120783', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120784', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120785',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120786', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120787', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120788', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120789', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120790',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120791',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120792', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120793',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120794', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120795', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120796', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120797', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120798', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120799', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120800',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120801', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120802', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120803', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120804', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120805', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120806', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120807', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120808',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120809', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120810', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120811',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120812', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120813',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120814',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120815', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120816', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120817', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120818',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120819', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120820',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120821', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120822', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120823', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120824',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120825',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120826', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120827', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120828', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120829', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120830', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120831', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120832', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120833', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120834', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120835', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120836', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120837', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120838', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120839', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120840',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120841', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120842',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120843',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120844', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120845', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120846',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120847', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120848',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120849',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120850', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120851',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120852',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120853',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120854', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120855',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120856',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120857', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120858', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120859', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120860', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120861', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120862', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120863', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120864', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120865', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120866', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120867',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120868',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120869',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120870',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120871',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120872',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120873',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120874',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120875',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120876',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120877', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120878', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120879',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120880', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120881',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120882',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120883', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120884',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120885', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120886',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120887',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120888', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120889', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120890',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120891',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120892',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120893',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120894', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120895', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120896', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120897', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120898',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120899', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120900',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120901', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120902', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120903', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120904', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120905', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120906',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120907', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120908', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120909',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120910', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120911',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120912',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120913', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120914',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120915',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120916',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120917', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120918', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120919',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120920',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120921', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120922', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120923', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120924', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120925',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120926', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120927', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120928', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120929',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120930',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120931', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120932', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120933',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120934', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120935',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120936',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120937',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120938', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120939',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120940',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120941', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120942',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120943',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120944',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120945', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120946', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120947', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120948', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120949',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120950',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120951', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120952',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120953',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120954',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120955', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120956', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120957',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120958', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120959', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120960',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120961',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120962',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025',
#   'id': '120963',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120964', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120965', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120966', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120967',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120968',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120969', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120970', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120971',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120972',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120973',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120974', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120975', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120976', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120977', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120978', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120979', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120980',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120981', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120982', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120983', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120984',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120985', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120986',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120987', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120988', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120989',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025', 'id': '120990', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120991', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120992', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120993', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120994', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120995', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '120996',
#   'value': [['STEREOTYPING-DOMINANCE']]},
#  {'test_case': 'EXIST2025',
#   'id': '120997',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  {'test_case': 'EXIST2025', 'id': '120998', 'value': [['-']]},
#  {'test_case': 'EXIST2025', 'id': '120999', 'value': [['-']]},
#  {'test_case': 'EXIST2025',
#   'id': '121000',
#   'value': [['IDEOLOGICAL-INEQUALITY']]},
#  ...]
